# %% [markdown]
# # Compilation Tutorial
# ## Hailo Compilation Example from Hailo Archive Quantized Model to HEF
# This tutorial will describe how to convert the model into the HEF executable format
#
# **Requirements:**
#
# * Run the codes below in Jupyter notebook, see the Introduction tutorial for more details.
# * A quantized HAR file.
#
# Note:
# This section demonstrates the Python APIs for Hailo Compiler.
# You could also use the CLI: try `hailo compiler --help`.
# More details on Dataflow Compiler User Guide / Building Models / Profiler and other command line tools.

# %%
from hailo_sdk_client import ClientRunner

# %% [markdown]
# Choose the quantized model Hailo Archive file to use throughout the example:

# %%
model_name = "resnet_v1_18"
quantized_model_har_path = f"{model_name}_quantized_model.har"

# %% [markdown]
# Load the network to the ClientRunner:

# %%
runner = ClientRunner(har=quantized_model_har_path)
# By default it uses the hw_arch that is saved on the HAR. It is not recommended to change the hw_arch after Optimization.

# %% [markdown]
# Run compilation (This method can take a couple of minutes):
#
# Note: The `hailo compiler` CLI tool can also be used.

# %%
hef = runner.compile()

file_name = f"{model_name}.hef"
with open(file_name, "wb") as f:
    f.write(hef)
# Out:
# [info] To achieve optimal performance, set the compiler_optimization_level to "max" by adding performance_param(compiler_optimization_level=max) to the model script. Note that this may increase compilation time.
# [info] Loading network parameters
# [info] Starting Hailo allocation and compilation flow
# [info] Using Single-context flow
# [info] Resources optimization guidelines: Strategy -> GREEDY Objective -> MAX_FPS
# [info] Resources optimization params: max_control_utilization=75%, max_compute_utilization=75%, max_compute_16bit_utilization=75%, max_memory_utilization (weights)=75%, max_input_aligner_utilization=75%, max_apu_utilization=75%
# [info] Using Single-context flow
# [info] Resources optimization guidelines: Strategy -> GREEDY Objective -> MAX_FPS
# [info] Resources optimization params: max_control_utilization=75%, max_compute_utilization=75%, max_compute_16bit_utilization=75%, max_memory_utilization (weights)=75%, max_input_aligner_utilization=75%, max_apu_utilization=75%
# [info] output_layer1: Pass
# [info] input_layer1: Pass
# [info] normalization1: Pass
# [info] conv1_sdc: Pass
# [info] maxpool1_d4: Pass
# [info] sh_from_normalization1_to_conv1_sd0-3: Pass
# [info] maxpool1_d3: Pass
# [info] conv1_sd2: Pass
# [info] maxpool1_d0: Pass
# [info] maxpool1_d2: Pass
# [info] conv1_sd0: Pass
# [info] concat_from_maxpool1_d0-3_to_maxpool1_dc: Pass
# [info] conv1_sd1: Pass
# [info] conv2_sd1: Pass
# [info] maxpool1_d1: Pass
# [info] conv1_sd4: Pass
# [info] conv2_sd0: Pass
# [info] maxpool1_dc: Pass
# [info] fs_from_maxpool1_fs_to_maxpool1_d0-3: Pass
# [info] maxpool1_fs: Pass
# [info] conv1_sd3: Pass
# [info] concat_from_conv1_sd0-3_to_conv1_sdc: Pass
# [info] conv2_sdc: Pass
# [info] conv15_d0: Pass
# [info] conv5_sd2: Pass
# [info] conv14_dc: Pass
# [info] conv3_sd0: Pass
# [info] conv10_d1: Pass
# [info] conv3_sd2: Pass
# [info] conv6_sdc: Pass
# [info] conv4_sd1: Pass
# [info] smuffers_shortcut_conv3_to_conv4: Pass
# [info] softmax1: Pass
# [info] conv5_sd0: Pass
# [info] concat_from_conv18_d0-1_to_conv18_dc: Pass
# [info] conv3_sd3: Pass
# [info] conv15_d2: Pass
# [info] concat_from_conv19_d0-1_to_conv19_dc: Pass
# [info] auto_reshape_from_input_layer1_to_normalization1: Pass
# [info] sh_from_conv8_sdc_to_conv9_d0-3: Pass
# [info] conv19_d0: Pass
# [info] sh_from_conv13_dc_to_conv15_d0-2: Pass
# [info] smuffers_shortcut_conv4_to_conv5: Pass
# [info] conv8_sdc: Pass
# [info] conv20_d0: Pass
# [info] conv19_d2: Pass
# [info] conv16_d0: Pass
# [info] conv9_dc: Pass
# [info] sh_from_sh_from_conv18_dc_to_conv19_d0-2_conv20_d0_to_conv19_d0-2: Pass
# [info] conv10_dc: Pass
# [info] conv8_sd2: Pass
# [info] conv15_dc: Pass
# [info] conv12: Pass
# [info] conv9_d3: Pass
# [info] conv6_sd0: Pass
# [info] concat_from_conv20_d0-1_to_conv20_dc: Pass
# [info] conv15_d1: Pass
# [info] conv18_dc: Pass
# [info] conv20_dc: Pass
# [info] sh_from_maxpool1_dc_to_conv3_sd0-3: Pass
# [info] conv9_d2: Pass
# [info] conv4_sdc: Pass
# [info] smuffers_shortcut_conv3_to_conv5: Pass
# [info] conv8_sd0: Pass
# [info] sh_from_conv8_sdc_to_conv10_d0-3: Pass
# [info] conv8_sd1: Pass
# [info] conv7: Pass
# [info] conv19_dc: Pass
# [info] conv9_d1: Pass
# [info] conv8_sd3: Pass
# [info] conv13_d1: Pass
# [info] conv6_sd1: Pass
# [info] conv10_d3: Pass
# [info] avgpool1: Pass
# [info] conv13_dc: Pass
# [info] conv16_dc: Pass
# [info] conv17: Pass
# [info] conv11: Pass
# [info] sh_from_conv18_dc_to_conv19_d0-2_conv20_d0: Pass
# [info] conv9_d0: Pass
# [info] conv14_d0: Pass
# [info] conv10_d0: Pass
# [info] conv5_sdc: Pass
# [info] conv13_d0: Pass
# [info] conv19_d1: Pass
# [info] conv20_d1: Pass
# [info] conv4_sd0: Pass
# [info] conv3_sdc: Pass
# [info] conv5_sd1: Pass
# [info] conv18_d1: Pass
# [info] conv16_d1: Pass
# [info] conv3_sd1: Pass
# [info] conv10_d2: Pass
# [info] conv14_d1: Pass
# [info] fc1: Pass
# [info] conv18_d2: Pass
# [info] conv20_d2: Pass
# [info] conv18_d0: Pass
# [info] Solving the allocation (Mapping), time per context: 59m 59s
#
#
# [info] Context:0/0 Iteration 0: Mapping prepost...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2
#  worker3
#
#   00:00
# [info] Context:0/0 Iteration 0: Trying parallel splits...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0
#  worker1
#  worker2
#  worker3
#
#   00:05
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2
#  worker3
#
#   00:07
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:08
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  *          *          *          *          *          *          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:08
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  *          *          *          *          *          *          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:08
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          V          *          *          *          *          V
#  worker1
#  worker2  *          *          *          *          *          *          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:08
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          V          *          *          *          *          V
#  worker1
#  worker2  *          *          *          *          *          *          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:08
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          V          *          *          *          *          V
#  worker1
#  worker2  V          *          *          *          *          *          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:08
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          V          *          *          *          *          V
#  worker1
#  worker2  V          *          *          *          *          *          V          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:08
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          V          *          *          *          *          V
#  worker1
#  worker2  V          *          V          *          *          *          V          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:08
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          V          *          *          *          *          V
#  worker1
#  worker2  V          *          V          *          *          *          V          V          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:08
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          V          *          *          *          *          V
#  worker1
#  worker2  V          *          V          *          *          *          V          V          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:09
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          V          *          *          *          *          V
#  worker1
#  worker2  V          *          V          *          *          *          V          V          V
#  worker3  *          *          *          *          *          V          *          *          V
#
#   00:09
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          V          *          *          *          *          V
#  worker1
#  worker2  V          *          V          *          *          *          V          V          V
#  worker3  *          *          V          *          *          V          *          *          V
#
#   00:09
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          V          *          *          *          *          V
#  worker1
#  worker2  V          *          V          *          *          *          V          V          V
#  worker3  V          *          V          *          *          V          *          *          V
#
#   00:09
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          V          *          V          *          *          V
#  worker1
#  worker2  V          *          V          *          *          *          V          V          V
#  worker3  V          *          V          *          *          V          *          *          V
#
#   00:10
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          V          *          V          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  V          *          V          *          *          *          V          V          V
#  worker3  V          *          V          *          *          V          *          *          V
#
#   00:10
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          V          V          *          V          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  V          *          V          *          *          *          V          V          V
#  worker3  V          *          V          *          *          V          *          *          V
#
#   00:10
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          *          V          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  V          *          V          *          *          *          V          V          V
#  worker3  V          *          V          *          *          V          *          *          V
#
#   00:10
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  V          *          V          *          *          *          V          V          V
#  worker3  V          *          V          *          *          V          *          *          V
#
#   00:10
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  V          *          V          *          *          *          V          V          V
#  worker3  V          *          V          *          *          V          *          *          V
#
#   00:11
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  V          *          V          *          V          *          V          V          V
#  worker3  V          *          V          *          *          V          *          *          V
#
#   00:11
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  V          V          V          *          V          *          V          V          V
#  worker3  V          *          V          *          *          V          *          *          V
#
#   00:11
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          *          *          V          *          *          V
#
#   00:11
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          V          *          V          *          *          V
#
#   00:12
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          V          V          V          *          *          V
#
#   00:12
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          V          V          V          *          *          V
#
#   00:12
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  *          *          *          *          *          *          V          *          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          V          V          V          *          *          V
#
#   00:12
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  *          *          *          *          *          *          V          *          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          V          V          V          *          V          V
#
#   00:13
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  *          *          *          *          *          *          V          *          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          V          V          V          V          V          V
#
#   00:13
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  V          *          *          *          *          *          V          *          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          V          V          V          V          V          V
#
#   00:14
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  V          *          *          *          *          V          V          *          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          V          V          V          V          V          V
#
#   00:14
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  V          *          *          *          V          V          V          *          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          V          V          V          V          V          V
#
#   00:14
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  V          V          *          *          V          V          V          *          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          V          V          V          V          V          V
#
#   00:14
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  V          V          *          V          V          V          V          *          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          V          V          V          V          V          V
#
#   00:14
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  V          V          V          V          V          V          V          *          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          V          V          V          V          V          V
#
#   00:15
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          V          V          V          V          V          *          V
#  worker1  V          V          V          V          V          V          V          V          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          V          V          V          V          V          V
#
#   00:19
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  X          V          V          V          V          V          V          *          V
#  worker1  V          V          V          V          V          V          V          V          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          V          V          V          V          V          V
#
#   00:26
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  X          V          V          V          V          V          V          X          V
#  worker1  V          V          V          V          V          V          V          V          V
#  worker2  V          V          V          *          V          V          V          V          V
#  worker3  V          *          V          V          V          V          V          V          V
#
#   00:41
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  X          V          V          V          V          V          V          X          V
#  worker1  V          V          V          V          V          V          V          V          V
#  worker2  V          V          V          X          V          V          V          V          V
#  worker3  V          *          V          V          V          V          V          V          V
#
#   00:41
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  X          V          V          V          V          V          V          X          V
#  worker1  V          V          V          V          V          V          V          V          V
#  worker2  V          V          V          X          V          V          V          V          V
#  worker3  V          X          V          V          V          V          V          V          V
#
#   00:43
#
# [info] Iterations: 4
# Reverts on cluster mapping: 1
# Reverts on inter-cluster connectivity: 0
# Reverts on pre-mapping validation: 0
# Reverts on split failed: 0
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 75%                 | 90.6%               | 58.6%              |
# [info] | cluster_1 | 75%                 | 42.2%               | 71.1%              |
# [info] | cluster_2 | 87.5%               | 70.3%               | 80.5%              |
# [info] | cluster_3 | 75%                 | 57.8%               | 69.5%              |
# [info] | cluster_4 | 81.3%               | 85.9%               | 51.6%              |
# [info] | cluster_5 | 75%                 | 95.3%               | 41.4%              |
# [info] | cluster_6 | 56.3%               | 64.1%               | 39.1%              |
# [info] | cluster_7 | 62.5%               | 100%                | 93%                |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 73.4%               | 75.8%               | 63.1%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] Successful Mapping (allocation time: 1m 18s)
# [info] Compiling context_0...
# [info] Bandwidth of model inputs: 1.14844 Mbps, outputs: 0.00762939 Mbps (for a single frame)
# [info] Bandwidth of DDR buffers: 0.0 Mbps (for a single frame)
# [info] Bandwidth of inter context tensors: 0.0 Mbps (for a single frame)
# [info] Building HEF...
# [info] Successful Compilation (compilation time: 4s)

# %% [markdown]
# ## Profiler tool
#
# Run the profiler tool:
#
# This command will pop-open the HTML report in the browser.

# %%
har_path = f"{model_name}_compiled_model.har"
runner.save_har(har_path)
# !hailo profiler {har_path}
# Out:
# [info] Saved HAR to: /local/workspace/hailo_virtualenv/lib/python3.10/site-packages/hailo_tutorials/notebooks/resnet_v1_18_compiled_model.har
# [info] Current Time: 21:44:57, 03/18/25
# [info] CPU: Architecture: x86_64, Model: 12th Gen Intel(R) Core(TM) i7-12700, Number Of Cores: 20, Utilization: 1.4%
# [info] Memory: Total: 62GB, Available: 44GB
# [info] System info: OS: Linux, Kernel: 5.15.0-134-generic
# [info] Hailo DFC Version: 3.30.0
# [info] HailoRT Version: 4.20.0
# [info] PCIe: No Hailo PCIe device was found
# [info] Running `hailo profiler resnet_v1_18_compiled_model.har`
# [info] Running profile for resnet_v1_18 in state compiled_model
# [info]
# Model Details
# --------------------------------  ----------
# Input Tensors Shapes              224x224x3
# Operations per Input Tensor       3.63 GOPs
# Operations per Input Tensor       1.82 GMACs
# Pure Operations per Input Tensor  3.63 GOPs
# Pure Operations per Input Tensor  1.82 GMACs
# Model Parameters                  12.50 M
# --------------------------------  ----------
#
# Profiler Input Settings
# -----------------  -----------------
# Optimization Goal  Reach Highest FPS
# Profiler Mode      Compiled
# -----------------  -----------------
#
# Performance Summary
# ----------------------  --------------------
# Number of Devices       1
# Number of Contexts      1
# Throughput              2534.93 FPS
# Latency                 1.26 ms
# Operations per Second   9197.88 GOP/s
# MACs per Second         4605.23 GMAC/s
# Total Input Bandwidth   363.90 Megabytes/sec
# Total Output Bandwidth  2.42 Megabytes/sec
# Context Switch Configs  N/A
# ----------------------  --------------------
# [info] Saved Profiler HTML Report to: /local/workspace/hailo_virtualenv/lib/python3.10/site-packages/hailo_tutorials/notebooks/resnet_v1_18_compiled_model.html
# Opening in existing browser session.

# %% [markdown]
# Note:
#
# The HTML profiler report could be augmented with runtime statistics, that are saved after the .hef ran on the device using hailortcli.
#
# For more information look under the section: Dataflow Compiler User Guide / Building Models / Profiler and other command line tools / Running the Profiler.
