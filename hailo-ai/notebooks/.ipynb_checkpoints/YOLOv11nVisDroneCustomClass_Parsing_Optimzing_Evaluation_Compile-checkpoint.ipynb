# %% [markdown]
# The following has been adapted from Hailo's DFC Tutorials 1 and 2 (Parsing and Optimizing with DFC). It was run from a docker container setup using Hailo AI SoftwareSuite

# %%
# General imports used throughout the tutorial
# file operations
import json
import os

import numpy as np
import tensorflow as tf
from IPython.display import SVG
from matplotlib import patches
from matplotlib import pyplot as plt
from PIL import Image
from tensorflow.python.eager.context import eager_mode

import torchvision as tv
import torch

import cv2

# import the hailo sdk client relevant classes
from hailo_sdk_client import ClientRunner, InferenceContext

# %matplotlib inline

IMAGES_TO_VISUALIZE = 5

# %%
chosen_hw_arch = "hailo8"

# %% [markdown]
# The ONNX model below was created using the `ultralytics` yolo11n.pt pretrained model, which was finetuned on a customised visdrone dataset (single class) and exported using:
# ```model.export(format='onnx', opset=14)```
#
# the onnx output model was copied to the docker container into /local/shared_with_docker/yolov11n_visdrone.onnx

# %%
onnx_model_name = "yolo11n_visdrone"
onnx_path = "/local/shared_with_docker/yolo11n_visdrone_2class.onnx"

# %% [markdown]
# The endnodes below were taken from the [yolov11n.yaml](https://github.com/hailo-ai/hailo_model_zoo/blob/master/hailo_model_zoo/cfg/networks/yolov11n.yaml) on the hailo_model_zoo github. The finetuned (on VisDroneCustomClass) onnx model was opened in netron to double check these end nodes
# ```
# - /model.23/cv2.0/cv2.0.2/Conv
# - /model.23/cv3.0/cv3.0.2/Conv
# - /model.23/cv2.1/cv2.1.2/Conv
# - /model.23/cv3.1/cv3.1.2/Conv
# - /model.23/cv2.2/cv2.2.2/Conv
# - /model.23/cv3.2/cv3.2.2/Conv
# ```

# %%
runner = ClientRunner(hw_arch=chosen_hw_arch)
hn, npz = runner.translate_onnx_model(
    onnx_path,
    onnx_model_name,
    start_node_names=["/model.0/conv/Conv"],
    end_node_names=["/model.23/cv2.0/cv2.0.2/Conv", 
                   "/model.23/cv3.0/cv3.0.2/Conv",
                   "/model.23/cv2.1/cv2.1.2/Conv",
                   "/model.23/cv3.1/cv3.1.2/Conv",
                   "/model.23/cv2.2/cv2.2.2/Conv",
                   "/model.23/cv3.2/cv3.2.2/Conv"],
    net_input_shapes={"/model.0/conv/Conv": [1, 3, 640, 640]},
)
# Out:
# [info] Translation started on ONNX model yolo11n_visdrone
# [info] Restored ONNX model yolo11n_visdrone (completion time: 00:00:00.04)
# [info] Extracted ONNXRuntime meta-data for Hailo model (completion time: 00:00:00.17)
# [info] NMS structure of yolov8 (or equivalent architecture) was detected.
# [info] In order to use HailoRT post-processing capabilities, these end node names should be used: /model.23/cv3.0/cv3.0.2/Conv /model.23/cv2.0/cv2.0.2/Conv /model.23/cv3.1/cv3.1.2/Conv /model.23/cv2.1/cv2.1.2/Conv /model.23/cv2.2/cv2.2.2/Conv /model.23/cv3.2/cv3.2.2/Conv.
# [info] Start nodes mapped from original model: 'images': 'yolo11n_visdrone/input_layer1'.
# [info] End nodes mapped from original model: '/model.23/cv2.0/cv2.0.2/Conv', '/model.23/cv3.0/cv3.0.2/Conv', '/model.23/cv2.1/cv2.1.2/Conv', '/model.23/cv3.1/cv3.1.2/Conv', '/model.23/cv2.2/cv2.2.2/Conv', '/model.23/cv3.2/cv3.2.2/Conv'.
# [info] Translation completed on ONNX model yolo11n_visdrone (completion time: 00:00:00.78)

# %%
#save the parsed model
hailo_model_har_name = f"{onnx_model_name}_hailo_model_op14.har"
runner.save_har(hailo_model_har_name)
# Out:
# [info] Saved HAR to: /local/workspace/hailo_virtualenv/lib/python3.10/site-packages/hailo_tutorials/notebooks/yolo11n_visdrone_hailo_model_op14.har

# %% [markdown]
# ## Model Optimization

# %%
def preproc(image, output_height=640, output_width=640):
    preprocess = tv.transforms.Compose([
        tv.transforms.Resize((output_height, output_width)),
    ])
    
    data = np.array(preprocess(image))
    
    return data

# %%
# quantization needs calibration data, use the training data for this
cal_images_path = "../data/visdrone/train/images/" # use training data for calib
cal_images_list = [img_name for img_name in os.listdir(cal_images_path) if os.path.splitext(img_name)[1] == ".jpg"]
dataset_sz = 4100 
calib_dataset = np.zeros((dataset_sz, 640, 640, 3))

for idx, img_name in enumerate(sorted(cal_images_list)):
    if idx==dataset_sz:
        break
    img = Image.open(os.path.join(images_path, img_name)).convert('RGB')
    img_preproc = preproc(img)
    calib_dataset[idx, :, :, :] = img_preproc
    
print(f"Calibration dataset size: {calib_dataset.shape}\
        \nValidation dataset shape: {val_dataset.shape}")

# %%
#load our parsed HAR from the Parsing Tutorial
assert os.path.isfile(hailo_model_har_name), "Please provide valid path for HAR file"
runner = ClientRunner(har=hailo_model_har_name)

# %%
# Now we will create a model script, that tells the compiler to add a normalization on the beginning
# of the model (that is why we didn't normalize the calibration set;
# Otherwise we would have to normalize it before using it)
alls =  """
normalization1 = normalization([0.0, 0.0, 0.0], [255.0, 255.0, 255.0])
change_output_activation(conv54, sigmoid)
change_output_activation(conv65, sigmoid)
change_output_activation(conv80, sigmoid)
nms_postprocess("../yolov11_nms_config_visdrone.json", meta_arch=yolov8, engine=cpu)

model_optimization_config(calibration, batch_size=16, calibset_size=1024)
post_quantization_optimization(finetune, policy=enabled, learning_rate=0.0001, epochs=8, dataset_size=3000)

allocator_param(width_splitter_defuse=disabled)
 """


# Load the model script to ClientRunner so it will be considered on optimization
runner.load_model_script(alls)
#runner.optimize_full_precision()
runner.optimize(calib_dataset)

# %%
model_name = "yolo11n_visdrone"
# fp_model_har_path = f"{model_name}_fp_opt_model_visdrone.har"
# runner.save_har(fp_model_har_path)

quant_model_har_path = f"{model_name}_quant_opt_model_visdrone.har"
runner.save_har(quant_model_har_path)

# %%
# load the model
quant_model_har_path = f"{model_name}_quant_opt_model_visdrone.har"
runner = ClientRunner(har=quant_model_har_path, hw_arch=chosen_hw_arch)

# fp_opt_model_har_path = 'yolo11n_visdrone_fp_opt_model_visdrone.har'
# runner = ClientRunner(har=fp_opt_model_har_path, hw_arch=chosen_hw_arch)

# %% [markdown]
# ## Model Inference and Evaluation

# %%
# get a list of images (filename) and the corresponding image_id from annotations file

annotations_file = '/local/shared_with_docker/visdrone/annotations_VisDroneHumans_val.json'
images_path = "/local/shared_with_docker/VisDrone2019-DET-val/images"

with open(annotations_file, 'r') as f:
    val_gt = json.load(f)
    f.close()
    
images = val_gt['images']
image_list = [(x['file_name'],x['id']) for x in images]

# %%
def run_inference(runner, sdk_type, input_data ):
    if sdk_type == 'quantized':
        with runner.infer_context(InferenceContext.SDK_QUANTIZED) as ctx:
            output = runner.infer(ctx, input_data)
    else:
        with runner.infer_context(InferenceContext.SDK_FP_OPTIMIZED) as ctx:
            output = runner.infer(ctx, input_data)
    return output  

def remove_zero_padding(output, imgid):
    # remove zero-padding and transpose detections into single array
    combined = np.empty((7, 0)) # 1 classid, xywh, score

    for i in range(output.shape[1]):
        print(f"processing class {i} for image {imgid}...")
        valid_mask = np.any(output[0,i,:,:] != 0, axis=(0))  # Check if any non-zero values exist in each column
        last_valid_indices = np.argmax(~valid_mask, axis=0) # First occurrence of zero padding

        dets = output[0, i, :, :last_valid_indices]
        class_col = np.full_like(dets[0,None], i) # add the classID into the array
        imgid_col = np.full_like(dets[0,None], imgid)
        dets = np.vstack((dets, class_col, imgid_col))
        combined = np.concatenate((combined, dets), axis=1)
        print(f"\tfound {dets.shape[1]} detections for class {i}...")

    dets = combined.T
    return dets


def swap_columns(detections):
    detections[:, [0, 1,2,3]] = detections[:, [1, 0, 3, 2]]
    return detections


def ltxy2xywh(xywh):
    xywh[:,0] = xywh[:,0] # x
    xywh[:,1] = xywh[:,1] # y
    xywh[:,2] = xywh[:,2] - xywh[:,0] # x2 - x1
    xywh[:,3] = xywh[:,3] - xywh[:,1] # y2 - y1

    return xywh

def rescale_bbox(detections, w, h):
    w_arr = np.full_like(detections[:,0], w)
    h_arr = np.full_like(detections[:,0], h)
    
    detections[:,0] = detections[:,0] * w_arr
    detections[:,1] = detections[:,1] * h_arr
    detections[:,2] = detections[:,2] * w_arr
    detections[:,3] = detections[:,3] * h_arr
    
    return detections


def get_image_metadata(images_dict, img_id):
    for img in images_dict:
        if img['id'] == img_id:
            w, h = img['width'], img['height']
            name = img["file_name"]

    return w,h, name

# %%
# create an np array for the validation dataset
dataset_sz = len(image_list)
val_dataset = np.zeros((dataset_sz, 640, 640, 3))
val_imageids = np.zeros((dataset_sz,1))
for idx, imagename_id in enumerate(image_list):
    imgname, imgid = imagename_id
    image_file = os.path.join(images_path, imgname)
    if idx==dataset_sz:
        break
    img = Image.open(image_file).convert('RGB')
    img_preproc = preproc(img)
    val_dataset[idx, :, :, :] = img_preproc
    val_imageids[idx] = imgid

# %%
def detections_batch_generation(dataset, dataset_id, images_dict):
    batch_dets = run_inference(runner=runner, sdk_type='quantized', input_data=dataset)
    all_dets = []
    for idx, output in enumerate(batch_dets):
        imgid = dataset_id[idx]
        
        # postprocessing steps
        # remove zero padding
        output = output.reshape(1,2,5,100) # expects a batch
        detections = remove_zero_padding(output, imgid)
        
        # convert to xywh
        xywh = np.full_like(detections, detections)
        xywh = swap_columns(xywh) # annoyingly, it is in yx, ont xy, what misery
        xywh = ltxy2xywh(xywh) # convert x2/y2 to w/h
        
        # rescale detections
        w,h, name = get_image_metadata(images_dict, imgid) # images 
        dets_scaled = rescale_bbox(xywh, w, h)
        
        all_dets.append(dets_scaled)
    return(all_dets)


def batch_detections_to_json(batch):
    class_remap = {0: 1, 1: 2}
    res = []
    annId = 1
    for detections in batch:
        for el in detections:
            x,y,w,h,conf,classid,imgid = el
            imgid = int(imgid)
            res.append({"image_id": imgid, "category_id": class_remap[classid], "bbox": [x,y,w,h], "score": conf, "id": annId, "segmentation": []}) 
            annId +=1
    return res


def save_json_file(filename, data):
    with open(outputfile, 'w') as outf:
        json.dump(data, outf)
        outf.close()

    print(f"Total of {len(processed_outputs)} annotations saved to {outputfile}")

# %%
batch_detections = detections_batch_generation(val_dataset, val_imageids, images)
processed_outputs = batch_detections_to_json(batch_detections)

outputfile = f"/local/shared_with_docker/visdrone/detections_VisDrone_val.json" 
save_json_file(outputfile, processed_outputs)
# Out:
# [info] Using 1 GPU for inference
# Inference: 536entries [00:42, 12.48entries/s]
# processing class 0 for image [1.]...
# 	found 8 detections for class 0...
# processing class 1 for image [1.]...
# 	found 0 detections for class 1...
# processing class 0 for image [2.]...
# 	found 8 detections for class 0...
# processing class 1 for image [2.]...
# 	found 16 detections for class 1...
# processing class 0 for image [3.]...
# 	found 7 detections for class 0...
# processing class 1 for image [3.]...
# 	found 10 detections for class 1...
# processing class 0 for image [4.]...
# 	found 15 detections for class 0...
# processing class 1 for image [4.]...
# 	found 24 detections for class 1...
# processing class 0 for image [5.]...
# 	found 41 detections for class 0...
# processing class 1 for image [5.]...
# 	found 5 detections for class 1...
# processing class 0 for image [6.]...
# 	found 3 detections for class 0...
# processing class 1 for image [6.]...
# 	found 1 detections for class 1...
# processing class 0 for image [7.]...
# 	found 3 detections for class 0...
# processing class 1 for image [7.]...
# 	found 1 detections for class 1...
# processing class 0 for image [8.]...
# 	found 29 detections for class 0...
# processing class 1 for image [8.]...
# 	found 0 detections for class 1...
# processing class 0 for image [9.]...
# 	found 44 detections for class 0...
# processing class 1 for image [9.]...
# 	found 7 detections for class 1...
# processing class 0 for image [10.]...
# 	found 51 detections for class 0...
# processing class 1 for image [10.]...
# 	found 9 detections for class 1...
# processing class 0 for image [11.]...
# 	found 21 detections for class 0...
# processing class 1 for image [11.]...
# 	found 2 detections for class 1...
# processing class 0 for image [12.]...
# 	found 9 detections for class 0...
# processing class 1 for image [12.]...
# 	found 5 detections for class 1...
# processing class 0 for image [13.]...
# 	found 5 detections for class 0...
# processing class 1 for image [13.]...
# 	found 6 detections for class 1...
# processing class 0 for image [14.]...
# 	found 31 detections for class 0...
# processing class 1 for image [14.]...
# 	found 6 detections for class 1...
# processing class 0 for image [15.]...
# 	found 35 detections for class 0...
# processing class 1 for image [15.]...
# 	found 7 detections for class 1...
# processing class 0 for image [16.]...
# 	found 6 detections for class 0...
# processing class 1 for image [16.]...
# 	found 0 detections for class 1...
# processing class 0 for image [17.]...
# 	found 31 detections for class 0...
# processing class 1 for image [17.]...
# 	found 6 detections for class 1...
# processing class 0 for image [18.]...
# 	found 25 detections for class 0...
# processing class 1 for image [18.]...
# 	found 3 detections for class 1...
# processing class 0 for image [19.]...
# 	found 15 detections for class 0...
# processing class 1 for image [19.]...
# 	found 1 detections for class 1...
# processing class 0 for image [20.]...
# 	found 15 detections for class 0...
# processing class 1 for image [20.]...
# 	found 2 detections for class 1...
# processing class 0 for image [21.]...
# 	found 18 detections for class 0...
# processing class 1 for image [21.]...
# 	found 5 detections for class 1...
# processing class 0 for image [22.]...
# 	found 2 detections for class 0...
# processing class 1 for image [22.]...
# 	found 0 detections for class 1...
# processing class 0 for image [23.]...
# 	found 3 detections for class 0...
# processing class 1 for image [23.]...
# 	found 0 detections for class 1...
# processing class 0 for image [24.]...
# 	found 7 detections for class 0...
# processing class 1 for image [24.]...
# 	found 0 detections for class 1...
# processing class 0 for image [25.]...
# 	found 1 detections for class 0...
# processing class 1 for image [25.]...
# 	found 0 detections for class 1...
# processing class 0 for image [26.]...
# 	found 5 detections for class 0...
# processing class 1 for image [26.]...
# 	found 0 detections for class 1...
# processing class 0 for image [27.]...
# 	found 2 detections for class 0...
# processing class 1 for image [27.]...
# 	found 0 detections for class 1...
# processing class 0 for image [28.]...
# 	found 0 detections for class 0...
# processing class 1 for image [28.]...
# 	found 0 detections for class 1...
# processing class 0 for image [29.]...
# 	found 8 detections for class 0...
# processing class 1 for image [29.]...
# 	found 0 detections for class 1...
# processing class 0 for image [30.]...
# 	found 1 detections for class 0...
# processing class 1 for image [30.]...
# 	found 0 detections for class 1...
# processing class 0 for image [31.]...
# 	found 0 detections for class 0...
# processing class 1 for image [31.]...
# 	found 0 detections for class 1...
# processing class 0 for image [32.]...
# 	found 40 detections for class 0...
# processing class 1 for image [32.]...
# 	found 1 detections for class 1...
# processing class 0 for image [33.]...
# 	found 79 detections for class 0...
# processing class 1 for image [33.]...
# 	found 1 detections for class 1...
# processing class 0 for image [34.]...
# 	found 24 detections for class 0...
# processing class 1 for image [34.]...
# 	found 3 detections for class 1...
# processing class 0 for image [35.]...
# 	found 35 detections for class 0...
# processing class 1 for image [35.]...
# 	found 1 detections for class 1...
# processing class 0 for image [36.]...
# 	found 64 detections for class 0...
# processing class 1 for image [36.]...
# 	found 4 detections for class 1...
# processing class 0 for image [37.]...
# 	found 23 detections for class 0...
# processing class 1 for image [37.]...
# 	found 1 detections for class 1...
# processing class 0 for image [38.]...
# 	found 35 detections for class 0...
# processing class 1 for image [38.]...
# 	found 5 detections for class 1...
# processing class 0 for image [39.]...
# 	found 43 detections for class 0...
# processing class 1 for image [39.]...
# 	found 1 detections for class 1...
# processing class 0 for image [40.]...
# 	found 32 detections for class 0...
# processing class 1 for image [40.]...
# 	found 1 detections for class 1...
# processing class 0 for image [41.]...
# 	found 99 detections for class 0...
# processing class 1 for image [41.]...
# 	found 1 detections for class 1...
# processing class 0 for image [42.]...
# 	found 5 detections for class 0...
# processing class 1 for image [42.]...
# 	found 2 detections for class 1...
# processing class 0 for image [43.]...
# 	found 97 detections for class 0...
# processing class 1 for image [43.]...
# 	found 3 detections for class 1...
# processing class 0 for image [44.]...
# 	found 38 detections for class 0...
# processing class 1 for image [44.]...
# 	found 0 detections for class 1...
# processing class 0 for image [45.]...
# 	found 33 detections for class 0...
# processing class 1 for image [45.]...
# 	found 2 detections for class 1...
# processing class 0 for image [46.]...
# 	found 0 detections for class 0...
# processing class 1 for image [46.]...
# 	found 0 detections for class 1...
# processing class 0 for image [47.]...
# 	found 0 detections for class 0...
# processing class 1 for image [47.]...
# 	found 0 detections for class 1...
# processing class 0 for image [48.]...
# 	found 0 detections for class 0...
# processing class 1 for image [48.]...
# 	found 0 detections for class 1...
# processing class 0 for image [49.]...
# 	found 2 detections for class 0...
# processing class 1 for image [49.]...
# 	found 0 detections for class 1...
# processing class 0 for image [50.]...
# 	found 0 detections for class 0...
# processing class 1 for image [50.]...
# 	found 0 detections for class 1...
# processing class 0 for image [51.]...
# 	found 3 detections for class 0...
# processing class 1 for image [51.]...
# 	found 1 detections for class 1...
# processing class 0 for image [52.]...
# 	found 2 detections for class 0...
# processing class 1 for image [52.]...
# 	found 0 detections for class 1...
# processing class 0 for image [53.]...
# 	found 0 detections for class 0...
# processing class 1 for image [53.]...
# 	found 0 detections for class 1...
# processing class 0 for image [54.]...
# 	found 2 detections for class 0...
# processing class 1 for image [54.]...
# 	found 0 detections for class 1...
# processing class 0 for image [55.]...
# 	found 3 detections for class 0...
# processing class 1 for image [55.]...
# 	found 0 detections for class 1...
# processing class 0 for image [56.]...
# 	found 1 detections for class 0...
# processing class 1 for image [56.]...
# 	found 0 detections for class 1...
# processing class 0 for image [57.]...
# 	found 3 detections for class 0...
# processing class 1 for image [57.]...
# 	found 12 detections for class 1...
# processing class 0 for image [58.]...
# 	found 68 detections for class 0...
# processing class 1 for image [58.]...
# 	found 16 detections for class 1...
# processing class 0 for image [59.]...
# 	found 21 detections for class 0...
# processing class 1 for image [59.]...
# 	found 9 detections for class 1...
# processing class 0 for image [60.]...
# 	found 12 detections for class 0...
# processing class 1 for image [60.]...
# 	found 0 detections for class 1...
# processing class 0 for image [61.]...
# 	found 2 detections for class 0...
# processing class 1 for image [61.]...
# 	found 4 detections for class 1...
# processing class 0 for image [62.]...
# 	found 89 detections for class 0...
# processing class 1 for image [62.]...
# 	found 4 detections for class 1...
# processing class 0 for image [63.]...
# 	found 20 detections for class 0...
# processing class 1 for image [63.]...
# 	found 15 detections for class 1...
# processing class 0 for image [64.]...
# 	found 3 detections for class 0...
# processing class 1 for image [64.]...
# 	found 20 detections for class 1...
# processing class 0 for image [65.]...
# 	found 5 detections for class 0...
# processing class 1 for image [65.]...
# 	found 4 detections for class 1...
# processing class 0 for image [66.]...
# 	found 6 detections for class 0...
# processing class 1 for image [66.]...
# 	found 3 detections for class 1...
# processing class 0 for image [67.]...
# 	found 42 detections for class 0...
# processing class 1 for image [67.]...
# 	found 0 detections for class 1...
# processing class 0 for image [68.]...
# 	found 0 detections for class 0...
# processing class 1 for image [68.]...
# 	found 0 detections for class 1...
# processing class 0 for image [69.]...
# 	found 3 detections for class 0...
# processing class 1 for image [69.]...
# 	found 2 detections for class 1...
# processing class 0 for image [70.]...
# 	found 1 detections for class 0...
# processing class 1 for image [70.]...
# 	found 1 detections for class 1...
# processing class 0 for image [71.]...
# 	found 13 detections for class 0...
# processing class 1 for image [71.]...
# 	found 6 detections for class 1...
# processing class 0 for image [72.]...
# 	found 6 detections for class 0...
# processing class 1 for image [72.]...
# 	found 4 detections for class 1...
# processing class 0 for image [73.]...
# 	found 4 detections for class 0...
# processing class 1 for image [73.]...
# 	found 8 detections for class 1...
# processing class 0 for image [74.]...
# 	found 19 detections for class 0...
# processing class 1 for image [74.]...
# 	found 14 detections for class 1...
# processing class 0 for image [75.]...
# 	found 15 detections for class 0...
# processing class 1 for image [75.]...
# 	found 8 detections for class 1...
# processing class 0 for image [76.]...
# 	found 92 detections for class 0...
# processing class 1 for image [76.]...
# 	found 4 detections for class 1...
# processing class 0 for image [77.]...
# 	found 33 detections for class 0...
# processing class 1 for image [77.]...
# 	found 0 detections for class 1...
# processing class 0 for image [78.]...
# 	found 30 detections for class 0...
# processing class 1 for image [78.]...
# 	found 7 detections for class 1...
# processing class 0 for image [79.]...
# 	found 75 detections for class 0...
# processing class 1 for image [79.]...
# 	found 5 detections for class 1...
# processing class 0 for image [80.]...
# 	found 45 detections for class 0...
# processing class 1 for image [80.]...
# 	found 5 detections for class 1...
# processing class 0 for image [81.]...
# 	found 7 detections for class 0...
# processing class 1 for image [81.]...
# 	found 1 detections for class 1...
# processing class 0 for image [82.]...
# 	found 8 detections for class 0...
# processing class 1 for image [82.]...
# 	found 17 detections for class 1...
# processing class 0 for image [83.]...
# 	found 11 detections for class 0...
# processing class 1 for image [83.]...
# 	found 15 detections for class 1...
# processing class 0 for image [84.]...
# 	found 2 detections for class 0...
# processing class 1 for image [84.]...
# 	found 15 detections for class 1...
# processing class 0 for image [85.]...
# 	found 1 detections for class 0...
# processing class 1 for image [85.]...
# 	found 18 detections for class 1...
# processing class 0 for image [86.]...
# 	found 3 detections for class 0...
# processing class 1 for image [86.]...
# 	found 16 detections for class 1...
# processing class 0 for image [87.]...
# 	found 4 detections for class 0...
# processing class 1 for image [87.]...
# 	found 14 detections for class 1...
# processing class 0 for image [88.]...
# 	found 4 detections for class 0...
# processing class 1 for image [88.]...
# 	found 28 detections for class 1...
# processing class 0 for image [89.]...
# 	found 10 detections for class 0...
# processing class 1 for image [89.]...
# 	found 18 detections for class 1...
# processing class 0 for image [90.]...
# 	found 8 detections for class 0...
# processing class 1 for image [90.]...
# 	found 20 detections for class 1...
# processing class 0 for image [91.]...
# 	found 12 detections for class 0...
# processing class 1 for image [91.]...
# 	found 13 detections for class 1...
# processing class 0 for image [92.]...
# 	found 18 detections for class 0...
# processing class 1 for image [92.]...
# 	found 25 detections for class 1...
# processing class 0 for image [93.]...
# 	found 17 detections for class 0...
# processing class 1 for image [93.]...
# 	found 28 detections for class 1...
# processing class 0 for image [94.]...
# 	found 20 detections for class 0...
# processing class 1 for image [94.]...
# 	found 35 detections for class 1...
# processing class 0 for image [95.]...
# 	found 26 detections for class 0...
# processing class 1 for image [95.]...
# 	found 24 detections for class 1...
# processing class 0 for image [96.]...
# 	found 13 detections for class 0...
# processing class 1 for image [96.]...
# 	found 43 detections for class 1...
# processing class 0 for image [97.]...
# 	found 8 detections for class 0...
# processing class 1 for image [97.]...
# 	found 34 detections for class 1...
# processing class 0 for image [98.]...
# 	found 5 detections for class 0...
# processing class 1 for image [98.]...
# 	found 20 detections for class 1...
# processing class 0 for image [99.]...
# 	found 3 detections for class 0...
# processing class 1 for image [99.]...
# 	found 9 detections for class 1...
# processing class 0 for image [100.]...
# 	found 13 detections for class 0...
# processing class 1 for image [100.]...
# 	found 16 detections for class 1...
# processing class 0 for image [101.]...
# 	found 14 detections for class 0...
# processing class 1 for image [101.]...
# 	found 9 detections for class 1...
# processing class 0 for image [102.]...
# 	found 5 detections for class 0...
# processing class 1 for image [102.]...
# 	found 17 detections for class 1...
# processing class 0 for image [103.]...
# 	found 0 detections for class 0...
# processing class 1 for image [103.]...
# 	found 9 detections for class 1...
# processing class 0 for image [104.]...
# 	found 1 detections for class 0...
# processing class 1 for image [104.]...
# 	found 5 detections for class 1...
# processing class 0 for image [105.]...
# 	found 27 detections for class 0...
# processing class 1 for image [105.]...
# 	found 2 detections for class 1...
# processing class 0 for image [106.]...
# 	found 19 detections for class 0...
# processing class 1 for image [106.]...
# 	found 8 detections for class 1...
# processing class 0 for image [107.]...
# 	found 22 detections for class 0...
# processing class 1 for image [107.]...
# 	found 26 detections for class 1...
# processing class 0 for image [108.]...
# 	found 25 detections for class 0...
# processing class 1 for image [108.]...
# 	found 33 detections for class 1...
# processing class 0 for image [109.]...
# 	found 22 detections for class 0...
# processing class 1 for image [109.]...
# 	found 21 detections for class 1...
# processing class 0 for image [110.]...
# 	found 16 detections for class 0...
# processing class 1 for image [110.]...
# 	found 40 detections for class 1...
# processing class 0 for image [111.]...
# 	found 32 detections for class 0...
# processing class 1 for image [111.]...
# 	found 18 detections for class 1...
# processing class 0 for image [112.]...
# 	found 13 detections for class 0...
# processing class 1 for image [112.]...
# 	found 11 detections for class 1...
# processing class 0 for image [113.]...
# 	found 8 detections for class 0...
# processing class 1 for image [113.]...
# 	found 9 detections for class 1...
# processing class 0 for image [114.]...
# 	found 4 detections for class 0...
# processing class 1 for image [114.]...
# 	found 13 detections for class 1...
# processing class 0 for image [115.]...
# 	found 17 detections for class 0...
# processing class 1 for image [115.]...
# 	found 15 detections for class 1...
# processing class 0 for image [116.]...
# 	found 18 detections for class 0...
# processing class 1 for image [116.]...
# 	found 29 detections for class 1...
# processing class 0 for image [117.]...
# 	found 15 detections for class 0...
# processing class 1 for image [117.]...
# 	found 19 detections for class 1...
# processing class 0 for image [118.]...
# 	found 9 detections for class 0...
# processing class 1 for image [118.]...
# 	found 16 detections for class 1...
# processing class 0 for image [119.]...
# 	found 4 detections for class 0...
# processing class 1 for image [119.]...
# 	found 9 detections for class 1...
# processing class 0 for image [120.]...
# 	found 3 detections for class 0...
# processing class 1 for image [120.]...
# 	found 6 detections for class 1...
# processing class 0 for image [121.]...
# 	found 16 detections for class 0...
# processing class 1 for image [121.]...
# 	found 9 detections for class 1...
# processing class 0 for image [122.]...
# 	found 0 detections for class 0...
# processing class 1 for image [122.]...
# 	found 1 detections for class 1...
# processing class 0 for image [123.]...
# 	found 3 detections for class 0...
# processing class 1 for image [123.]...
# 	found 3 detections for class 1...
# processing class 0 for image [124.]...
# 	found 7 detections for class 0...
# processing class 1 for image [124.]...
# 	found 7 detections for class 1...
# processing class 0 for image [125.]...
# 	found 24 detections for class 0...
# processing class 1 for image [125.]...
# 	found 6 detections for class 1...
# processing class 0 for image [126.]...
# 	found 40 detections for class 0...
# processing class 1 for image [126.]...
# 	found 7 detections for class 1...
# processing class 0 for image [127.]...
# 	found 21 detections for class 0...
# processing class 1 for image [127.]...
# 	found 0 detections for class 1...
# processing class 0 for image [128.]...
# 	found 42 detections for class 0...
# processing class 1 for image [128.]...
# 	found 6 detections for class 1...
# processing class 0 for image [129.]...
# 	found 36 detections for class 0...
# processing class 1 for image [129.]...
# 	found 3 detections for class 1...
# processing class 0 for image [130.]...
# 	found 33 detections for class 0...
# processing class 1 for image [130.]...
# 	found 1 detections for class 1...
# processing class 0 for image [131.]...
# 	found 11 detections for class 0...
# processing class 1 for image [131.]...
# 	found 0 detections for class 1...
# processing class 0 for image [132.]...
# 	found 21 detections for class 0...
# processing class 1 for image [132.]...
# 	found 6 detections for class 1...
# processing class 0 for image [133.]...
# 	found 12 detections for class 0...
# processing class 1 for image [133.]...
# 	found 3 detections for class 1...
# processing class 0 for image [134.]...
# 	found 28 detections for class 0...
# processing class 1 for image [134.]...
# 	found 4 detections for class 1...
# processing class 0 for image [135.]...
# 	found 25 detections for class 0...
# processing class 1 for image [135.]...
# 	found 3 detections for class 1...
# processing class 0 for image [136.]...
# 	found 28 detections for class 0...
# processing class 1 for image [136.]...
# 	found 3 detections for class 1...
# processing class 0 for image [137.]...
# 	found 11 detections for class 0...
# processing class 1 for image [137.]...
# 	found 1 detections for class 1...
# processing class 0 for image [138.]...
# 	found 11 detections for class 0...
# processing class 1 for image [138.]...
# 	found 0 detections for class 1...
# processing class 0 for image [139.]...
# 	found 2 detections for class 0...
# processing class 1 for image [139.]...
# 	found 3 detections for class 1...
# processing class 0 for image [140.]...
# 	found 2 detections for class 0...
# processing class 1 for image [140.]...
# 	found 1 detections for class 1...
# processing class 0 for image [141.]...
# 	found 2 detections for class 0...
# processing class 1 for image [141.]...
# 	found 3 detections for class 1...
# processing class 0 for image [142.]...
# 	found 0 detections for class 0...
# processing class 1 for image [142.]...
# 	found 0 detections for class 1...
# processing class 0 for image [143.]...
# 	found 4 detections for class 0...
# processing class 1 for image [143.]...
# 	found 1 detections for class 1...
# processing class 0 for image [144.]...
# 	found 1 detections for class 0...
# processing class 1 for image [144.]...
# 	found 2 detections for class 1...
# processing class 0 for image [145.]...
# 	found 0 detections for class 0...
# processing class 1 for image [145.]...
# 	found 0 detections for class 1...
# processing class 0 for image [146.]...
# 	found 0 detections for class 0...
# processing class 1 for image [146.]...
# 	found 0 detections for class 1...
# processing class 0 for image [147.]...
# 	found 5 detections for class 0...
# processing class 1 for image [147.]...
# 	found 4 detections for class 1...
# processing class 0 for image [148.]...
# 	found 6 detections for class 0...
# processing class 1 for image [148.]...
# 	found 1 detections for class 1...
# processing class 0 for image [149.]...
# 	found 9 detections for class 0...
# processing class 1 for image [149.]...
# 	found 4 detections for class 1...
# processing class 0 for image [150.]...
# 	found 4 detections for class 0...
# processing class 1 for image [150.]...
# 	found 3 detections for class 1...
# processing class 0 for image [151.]...
# 	found 0 detections for class 0...
# processing class 1 for image [151.]...
# 	found 0 detections for class 1...
# processing class 0 for image [152.]...
# 	found 2 detections for class 0...
# processing class 1 for image [152.]...
# 	found 0 detections for class 1...
# processing class 0 for image [153.]...
# 	found 2 detections for class 0...
# processing class 1 for image [153.]...
# 	found 4 detections for class 1...
# processing class 0 for image [154.]...
# 	found 1 detections for class 0...
# processing class 1 for image [154.]...
# 	found 4 detections for class 1...
# processing class 0 for image [155.]...
# 	found 1 detections for class 0...
# processing class 1 for image [155.]...
# 	found 3 detections for class 1...
# processing class 0 for image [156.]...
# 	found 0 detections for class 0...
# processing class 1 for image [156.]...
# 	found 0 detections for class 1...
# processing class 0 for image [157.]...
# 	found 1 detections for class 0...
# processing class 1 for image [157.]...
# 	found 2 detections for class 1...
# processing class 0 for image [158.]...
# 	found 6 detections for class 0...
# processing class 1 for image [158.]...
# 	found 1 detections for class 1...
# processing class 0 for image [159.]...
# 	found 1 detections for class 0...
# processing class 1 for image [159.]...
# 	found 0 detections for class 1...
# processing class 0 for image [160.]...
# 	found 0 detections for class 0...
# processing class 1 for image [160.]...
# 	found 1 detections for class 1...
# processing class 0 for image [161.]...
# 	found 9 detections for class 0...
# processing class 1 for image [161.]...
# 	found 1 detections for class 1...
# processing class 0 for image [162.]...
# 	found 0 detections for class 0...
# processing class 1 for image [162.]...
# 	found 1 detections for class 1...
# processing class 0 for image [163.]...
# 	found 7 detections for class 0...
# processing class 1 for image [163.]...
# 	found 2 detections for class 1...
# processing class 0 for image [164.]...
# 	found 9 detections for class 0...
# processing class 1 for image [164.]...
# 	found 2 detections for class 1...
# processing class 0 for image [165.]...
# 	found 18 detections for class 0...
# processing class 1 for image [165.]...
# 	found 1 detections for class 1...
# processing class 0 for image [166.]...
# 	found 5 detections for class 0...
# processing class 1 for image [166.]...
# 	found 4 detections for class 1...
# processing class 0 for image [167.]...
# 	found 5 detections for class 0...
# processing class 1 for image [167.]...
# 	found 2 detections for class 1...
# processing class 0 for image [168.]...
# 	found 0 detections for class 0...
# processing class 1 for image [168.]...
# 	found 3 detections for class 1...
# processing class 0 for image [169.]...
# 	found 1 detections for class 0...
# processing class 1 for image [169.]...
# 	found 1 detections for class 1...
# processing class 0 for image [170.]...
# 	found 4 detections for class 0...
# processing class 1 for image [170.]...
# 	found 2 detections for class 1...
# processing class 0 for image [171.]...
# 	found 2 detections for class 0...
# processing class 1 for image [171.]...
# 	found 0 detections for class 1...
# processing class 0 for image [172.]...
# 	found 1 detections for class 0...
# processing class 1 for image [172.]...
# 	found 0 detections for class 1...
# processing class 0 for image [173.]...
# 	found 1 detections for class 0...
# processing class 1 for image [173.]...
# 	found 0 detections for class 1...
# processing class 0 for image [174.]...
# 	found 8 detections for class 0...
# processing class 1 for image [174.]...
# 	found 1 detections for class 1...
# processing class 0 for image [175.]...
# 	found 1 detections for class 0...
# processing class 1 for image [175.]...
# 	found 3 detections for class 1...
# processing class 0 for image [176.]...
# 	found 1 detections for class 0...
# processing class 1 for image [176.]...
# 	found 1 detections for class 1...
# processing class 0 for image [177.]...
# 	found 3 detections for class 0...
# processing class 1 for image [177.]...
# 	found 4 detections for class 1...
# processing class 0 for image [178.]...
# 	found 8 detections for class 0...
# processing class 1 for image [178.]...
# 	found 4 detections for class 1...
# processing class 0 for image [179.]...
# 	found 0 detections for class 0...
# processing class 1 for image [179.]...
# 	found 1 detections for class 1...
# processing class 0 for image [180.]...
# 	found 1 detections for class 0...
# processing class 1 for image [180.]...
# 	found 2 detections for class 1...
# processing class 0 for image [181.]...
# 	found 2 detections for class 0...
# processing class 1 for image [181.]...
# 	found 2 detections for class 1...
# processing class 0 for image [182.]...
# 	found 5 detections for class 0...
# processing class 1 for image [182.]...
# 	found 2 detections for class 1...
# processing class 0 for image [183.]...
# 	found 1 detections for class 0...
# processing class 1 for image [183.]...
# 	found 0 detections for class 1...
# processing class 0 for image [184.]...
# 	found 15 detections for class 0...
# processing class 1 for image [184.]...
# 	found 4 detections for class 1...
# processing class 0 for image [185.]...
# 	found 8 detections for class 0...
# processing class 1 for image [185.]...
# 	found 5 detections for class 1...
# processing class 0 for image [186.]...
# 	found 18 detections for class 0...
# processing class 1 for image [186.]...
# 	found 6 detections for class 1...
# processing class 0 for image [187.]...
# 	found 26 detections for class 0...
# processing class 1 for image [187.]...
# 	found 9 detections for class 1...
# processing class 0 for image [188.]...
# 	found 5 detections for class 0...
# processing class 1 for image [188.]...
# 	found 0 detections for class 1...
# processing class 0 for image [189.]...
# 	found 18 detections for class 0...
# processing class 1 for image [189.]...
# 	found 5 detections for class 1...
# processing class 0 for image [190.]...
# 	found 31 detections for class 0...
# processing class 1 for image [190.]...
# 	found 6 detections for class 1...
# processing class 0 for image [191.]...
# 	found 16 detections for class 0...
# processing class 1 for image [191.]...
# 	found 3 detections for class 1...
# processing class 0 for image [192.]...
# 	found 19 detections for class 0...
# processing class 1 for image [192.]...
# 	found 3 detections for class 1...
# processing class 0 for image [193.]...
# 	found 10 detections for class 0...
# processing class 1 for image [193.]...
# 	found 3 detections for class 1...
# processing class 0 for image [194.]...
# 	found 20 detections for class 0...
# processing class 1 for image [194.]...
# 	found 0 detections for class 1...
# processing class 0 for image [195.]...
# 	found 15 detections for class 0...
# processing class 1 for image [195.]...
# 	found 3 detections for class 1...
# processing class 0 for image [196.]...
# 	found 18 detections for class 0...
# processing class 1 for image [196.]...
# 	found 8 detections for class 1...
# processing class 0 for image [197.]...
# 	found 13 detections for class 0...
# processing class 1 for image [197.]...
# 	found 6 detections for class 1...
# processing class 0 for image [198.]...
# 	found 26 detections for class 0...
# processing class 1 for image [198.]...
# 	found 9 detections for class 1...
# processing class 0 for image [199.]...
# 	found 11 detections for class 0...
# processing class 1 for image [199.]...
# 	found 7 detections for class 1...
# processing class 0 for image [200.]...
# 	found 3 detections for class 0...
# processing class 1 for image [200.]...
# 	found 6 detections for class 1...
# processing class 0 for image [201.]...
# 	found 12 detections for class 0...
# processing class 1 for image [201.]...
# 	found 1 detections for class 1...
# processing class 0 for image [202.]...
# 	found 12 detections for class 0...
# processing class 1 for image [202.]...
# 	found 1 detections for class 1...
# processing class 0 for image [203.]...
# 	found 11 detections for class 0...
# processing class 1 for image [203.]...
# 	found 3 detections for class 1...
# processing class 0 for image [204.]...
# 	found 12 detections for class 0...
# processing class 1 for image [204.]...
# 	found 4 detections for class 1...
# processing class 0 for image [205.]...
# 	found 20 detections for class 0...
# processing class 1 for image [205.]...
# 	found 5 detections for class 1...
# processing class 0 for image [206.]...
# 	found 18 detections for class 0...
# processing class 1 for image [206.]...
# 	found 3 detections for class 1...
# processing class 0 for image [207.]...
# 	found 13 detections for class 0...
# processing class 1 for image [207.]...
# 	found 2 detections for class 1...
# processing class 0 for image [208.]...
# 	found 23 detections for class 0...
# processing class 1 for image [208.]...
# 	found 6 detections for class 1...
# processing class 0 for image [209.]...
# 	found 6 detections for class 0...
# processing class 1 for image [209.]...
# 	found 8 detections for class 1...
# processing class 0 for image [210.]...
# 	found 7 detections for class 0...
# processing class 1 for image [210.]...
# 	found 6 detections for class 1...
# processing class 0 for image [211.]...
# 	found 5 detections for class 0...
# processing class 1 for image [211.]...
# 	found 0 detections for class 1...
# processing class 0 for image [212.]...
# 	found 0 detections for class 0...
# processing class 1 for image [212.]...
# 	found 0 detections for class 1...
# processing class 0 for image [213.]...
# 	found 7 detections for class 0...
# processing class 1 for image [213.]...
# 	found 3 detections for class 1...
# processing class 0 for image [214.]...
# 	found 0 detections for class 0...
# processing class 1 for image [214.]...
# 	found 1 detections for class 1...
# processing class 0 for image [215.]...
# 	found 4 detections for class 0...
# processing class 1 for image [215.]...
# 	found 3 detections for class 1...
# processing class 0 for image [216.]...
# 	found 0 detections for class 0...
# processing class 1 for image [216.]...
# 	found 2 detections for class 1...
# processing class 0 for image [217.]...
# 	found 0 detections for class 0...
# processing class 1 for image [217.]...
# 	found 0 detections for class 1...
# processing class 0 for image [218.]...
# 	found 0 detections for class 0...
# processing class 1 for image [218.]...
# 	found 2 detections for class 1...
# processing class 0 for image [219.]...
# 	found 0 detections for class 0...
# processing class 1 for image [219.]...
# 	found 2 detections for class 1...
# processing class 0 for image [220.]...
# 	found 0 detections for class 0...
# processing class 1 for image [220.]...
# 	found 4 detections for class 1...
# processing class 0 for image [221.]...
# 	found 0 detections for class 0...
# processing class 1 for image [221.]...
# 	found 1 detections for class 1...
# processing class 0 for image [222.]...
# 	found 0 detections for class 0...
# processing class 1 for image [222.]...
# 	found 4 detections for class 1...
# processing class 0 for image [223.]...
# 	found 0 detections for class 0...
# processing class 1 for image [223.]...
# 	found 4 detections for class 1...
# processing class 0 for image [224.]...
# 	found 2 detections for class 0...
# processing class 1 for image [224.]...
# 	found 3 detections for class 1...
# processing class 0 for image [225.]...
# 	found 0 detections for class 0...
# processing class 1 for image [225.]...
# 	found 1 detections for class 1...
# processing class 0 for image [226.]...
# 	found 1 detections for class 0...
# processing class 1 for image [226.]...
# 	found 1 detections for class 1...
# processing class 0 for image [227.]...
# 	found 7 detections for class 0...
# processing class 1 for image [227.]...
# 	found 0 detections for class 1...
# processing class 0 for image [228.]...
# 	found 0 detections for class 0...
# processing class 1 for image [228.]...
# 	found 0 detections for class 1...
# processing class 0 for image [229.]...
# 	found 2 detections for class 0...
# processing class 1 for image [229.]...
# 	found 1 detections for class 1...
# processing class 0 for image [230.]...
# 	found 0 detections for class 0...
# processing class 1 for image [230.]...
# 	found 2 detections for class 1...
# processing class 0 for image [231.]...
# 	found 0 detections for class 0...
# processing class 1 for image [231.]...
# 	found 2 detections for class 1...
# processing class 0 for image [232.]...
# 	found 0 detections for class 0...
# processing class 1 for image [232.]...
# 	found 0 detections for class 1...
# processing class 0 for image [233.]...
# 	found 9 detections for class 0...
# processing class 1 for image [233.]...
# 	found 3 detections for class 1...
# processing class 0 for image [234.]...
# 	found 6 detections for class 0...
# processing class 1 for image [234.]...
# 	found 4 detections for class 1...
# processing class 0 for image [235.]...
# 	found 4 detections for class 0...
# processing class 1 for image [235.]...
# 	found 3 detections for class 1...
# processing class 0 for image [236.]...
# 	found 15 detections for class 0...
# processing class 1 for image [236.]...
# 	found 10 detections for class 1...
# processing class 0 for image [237.]...
# 	found 10 detections for class 0...
# processing class 1 for image [237.]...
# 	found 6 detections for class 1...
# processing class 0 for image [238.]...
# 	found 24 detections for class 0...
# processing class 1 for image [238.]...
# 	found 5 detections for class 1...
# processing class 0 for image [239.]...
# 	found 16 detections for class 0...
# processing class 1 for image [239.]...
# 	found 4 detections for class 1...
# processing class 0 for image [240.]...
# 	found 11 detections for class 0...
# processing class 1 for image [240.]...
# 	found 7 detections for class 1...
# processing class 0 for image [241.]...
# 	found 16 detections for class 0...
# processing class 1 for image [241.]...
# 	found 13 detections for class 1...
# processing class 0 for image [242.]...
# 	found 20 detections for class 0...
# processing class 1 for image [242.]...
# 	found 8 detections for class 1...
# processing class 0 for image [243.]...
# 	found 13 detections for class 0...
# processing class 1 for image [243.]...
# 	found 6 detections for class 1...
# processing class 0 for image [244.]...
# 	found 22 detections for class 0...
# processing class 1 for image [244.]...
# 	found 3 detections for class 1...
# processing class 0 for image [245.]...
# 	found 41 detections for class 0...
# processing class 1 for image [245.]...
# 	found 2 detections for class 1...
# processing class 0 for image [246.]...
# 	found 32 detections for class 0...
# processing class 1 for image [246.]...
# 	found 1 detections for class 1...
# processing class 0 for image [247.]...
# 	found 11 detections for class 0...
# processing class 1 for image [247.]...
# 	found 12 detections for class 1...
# processing class 0 for image [248.]...
# 	found 15 detections for class 0...
# processing class 1 for image [248.]...
# 	found 11 detections for class 1...
# processing class 0 for image [249.]...
# 	found 24 detections for class 0...
# processing class 1 for image [249.]...
# 	found 6 detections for class 1...
# processing class 0 for image [250.]...
# 	found 19 detections for class 0...
# processing class 1 for image [250.]...
# 	found 11 detections for class 1...
# processing class 0 for image [251.]...
# 	found 16 detections for class 0...
# processing class 1 for image [251.]...
# 	found 3 detections for class 1...
# processing class 0 for image [252.]...
# 	found 12 detections for class 0...
# processing class 1 for image [252.]...
# 	found 8 detections for class 1...
# processing class 0 for image [253.]...
# 	found 9 detections for class 0...
# processing class 1 for image [253.]...
# 	found 9 detections for class 1...
# processing class 0 for image [254.]...
# 	found 11 detections for class 0...
# processing class 1 for image [254.]...
# 	found 10 detections for class 1...
# processing class 0 for image [255.]...
# 	found 16 detections for class 0...
# processing class 1 for image [255.]...
# 	found 5 detections for class 1...
# processing class 0 for image [256.]...
# 	found 15 detections for class 0...
# processing class 1 for image [256.]...
# 	found 6 detections for class 1...
# processing class 0 for image [257.]...
# 	found 25 detections for class 0...
# processing class 1 for image [257.]...
# 	found 3 detections for class 1...
# processing class 0 for image [258.]...
# 	found 7 detections for class 0...
# processing class 1 for image [258.]...
# 	found 4 detections for class 1...
# processing class 0 for image [259.]...
# 	found 4 detections for class 0...
# processing class 1 for image [259.]...
# 	found 0 detections for class 1...
# processing class 0 for image [260.]...
# 	found 3 detections for class 0...
# processing class 1 for image [260.]...
# 	found 3 detections for class 1...
# processing class 0 for image [261.]...
# 	found 1 detections for class 0...
# processing class 1 for image [261.]...
# 	found 5 detections for class 1...
# processing class 0 for image [262.]...
# 	found 1 detections for class 0...
# processing class 1 for image [262.]...
# 	found 11 detections for class 1...
# processing class 0 for image [263.]...
# 	found 5 detections for class 0...
# processing class 1 for image [263.]...
# 	found 8 detections for class 1...
# processing class 0 for image [264.]...
# 	found 9 detections for class 0...
# processing class 1 for image [264.]...
# 	found 12 detections for class 1...
# processing class 0 for image [265.]...
# 	found 8 detections for class 0...
# processing class 1 for image [265.]...
# 	found 4 detections for class 1...
# processing class 0 for image [266.]...
# 	found 3 detections for class 0...
# processing class 1 for image [266.]...
# 	found 7 detections for class 1...
# processing class 0 for image [267.]...
# 	found 0 detections for class 0...
# processing class 1 for image [267.]...
# 	found 0 detections for class 1...
# processing class 0 for image [268.]...
# 	found 0 detections for class 0...
# processing class 1 for image [268.]...
# 	found 0 detections for class 1...
# processing class 0 for image [269.]...
# 	found 4 detections for class 0...
# processing class 1 for image [269.]...
# 	found 3 detections for class 1...
# processing class 0 for image [270.]...
# 	found 2 detections for class 0...
# processing class 1 for image [270.]...
# 	found 3 detections for class 1...
# processing class 0 for image [271.]...
# 	found 5 detections for class 0...
# processing class 1 for image [271.]...
# 	found 1 detections for class 1...
# processing class 0 for image [272.]...
# 	found 4 detections for class 0...
# processing class 1 for image [272.]...
# 	found 3 detections for class 1...
# processing class 0 for image [273.]...
# 	found 6 detections for class 0...
# processing class 1 for image [273.]...
# 	found 6 detections for class 1...
# processing class 0 for image [274.]...
# 	found 8 detections for class 0...
# processing class 1 for image [274.]...
# 	found 3 detections for class 1...
# processing class 0 for image [275.]...
# 	found 17 detections for class 0...
# processing class 1 for image [275.]...
# 	found 2 detections for class 1...
# processing class 0 for image [276.]...
# 	found 14 detections for class 0...
# processing class 1 for image [276.]...
# 	found 1 detections for class 1...
# processing class 0 for image [277.]...
# 	found 12 detections for class 0...
# processing class 1 for image [277.]...
# 	found 5 detections for class 1...
# processing class 0 for image [278.]...
# 	found 10 detections for class 0...
# processing class 1 for image [278.]...
# 	found 2 detections for class 1...
# processing class 0 for image [279.]...
# 	found 3 detections for class 0...
# processing class 1 for image [279.]...
# 	found 0 detections for class 1...
# processing class 0 for image [280.]...
# 	found 5 detections for class 0...
# processing class 1 for image [280.]...
# 	found 0 detections for class 1...
# processing class 0 for image [281.]...
# 	found 2 detections for class 0...
# processing class 1 for image [281.]...
# 	found 2 detections for class 1...
# processing class 0 for image [282.]...
# 	found 5 detections for class 0...
# processing class 1 for image [282.]...
# 	found 4 detections for class 1...
# processing class 0 for image [283.]...
# 	found 4 detections for class 0...
# processing class 1 for image [283.]...
# 	found 0 detections for class 1...
# processing class 0 for image [284.]...
# 	found 3 detections for class 0...
# processing class 1 for image [284.]...
# 	found 7 detections for class 1...
# processing class 0 for image [285.]...
# 	found 7 detections for class 0...
# processing class 1 for image [285.]...
# 	found 3 detections for class 1...
# processing class 0 for image [286.]...
# 	found 7 detections for class 0...
# processing class 1 for image [286.]...
# 	found 0 detections for class 1...
# processing class 0 for image [287.]...
# 	found 11 detections for class 0...
# processing class 1 for image [287.]...
# 	found 6 detections for class 1...
# processing class 0 for image [288.]...
# 	found 10 detections for class 0...
# processing class 1 for image [288.]...
# 	found 1 detections for class 1...
# processing class 0 for image [289.]...
# 	found 19 detections for class 0...
# processing class 1 for image [289.]...
# 	found 0 detections for class 1...
# processing class 0 for image [290.]...
# 	found 7 detections for class 0...
# processing class 1 for image [290.]...
# 	found 0 detections for class 1...
# processing class 0 for image [291.]...
# 	found 4 detections for class 0...
# processing class 1 for image [291.]...
# 	found 0 detections for class 1...
# processing class 0 for image [292.]...
# 	found 9 detections for class 0...
# processing class 1 for image [292.]...
# 	found 2 detections for class 1...
# processing class 0 for image [293.]...
# 	found 7 detections for class 0...
# processing class 1 for image [293.]...
# 	found 3 detections for class 1...
# processing class 0 for image [294.]...
# 	found 5 detections for class 0...
# processing class 1 for image [294.]...
# 	found 3 detections for class 1...
# processing class 0 for image [295.]...
# 	found 2 detections for class 0...
# processing class 1 for image [295.]...
# 	found 4 detections for class 1...
# processing class 0 for image [296.]...
# 	found 6 detections for class 0...
# processing class 1 for image [296.]...
# 	found 0 detections for class 1...
# processing class 0 for image [297.]...
# 	found 9 detections for class 0...
# processing class 1 for image [297.]...
# 	found 5 detections for class 1...
# processing class 0 for image [298.]...
# 	found 4 detections for class 0...
# processing class 1 for image [298.]...
# 	found 2 detections for class 1...
# processing class 0 for image [299.]...
# 	found 5 detections for class 0...
# processing class 1 for image [299.]...
# 	found 4 detections for class 1...
# processing class 0 for image [300.]...
# 	found 6 detections for class 0...
# processing class 1 for image [300.]...
# 	found 3 detections for class 1...
# processing class 0 for image [301.]...
# 	found 15 detections for class 0...
# processing class 1 for image [301.]...
# 	found 6 detections for class 1...
# processing class 0 for image [302.]...
# 	found 15 detections for class 0...
# processing class 1 for image [302.]...
# 	found 8 detections for class 1...
# processing class 0 for image [303.]...
# 	found 14 detections for class 0...
# processing class 1 for image [303.]...
# 	found 2 detections for class 1...
# processing class 0 for image [304.]...
# 	found 37 detections for class 0...
# processing class 1 for image [304.]...
# 	found 11 detections for class 1...
# processing class 0 for image [305.]...
# 	found 35 detections for class 0...
# processing class 1 for image [305.]...
# 	found 7 detections for class 1...
# processing class 0 for image [306.]...
# 	found 36 detections for class 0...
# processing class 1 for image [306.]...
# 	found 4 detections for class 1...
# processing class 0 for image [307.]...
# 	found 15 detections for class 0...
# processing class 1 for image [307.]...
# 	found 2 detections for class 1...
# processing class 0 for image [308.]...
# 	found 20 detections for class 0...
# processing class 1 for image [308.]...
# 	found 10 detections for class 1...
# processing class 0 for image [309.]...
# 	found 19 detections for class 0...
# processing class 1 for image [309.]...
# 	found 2 detections for class 1...
# processing class 0 for image [310.]...
# 	found 15 detections for class 0...
# processing class 1 for image [310.]...
# 	found 1 detections for class 1...
# processing class 0 for image [311.]...
# 	found 26 detections for class 0...
# processing class 1 for image [311.]...
# 	found 4 detections for class 1...
# processing class 0 for image [312.]...
# 	found 16 detections for class 0...
# processing class 1 for image [312.]...
# 	found 1 detections for class 1...
# processing class 0 for image [313.]...
# 	found 11 detections for class 0...
# processing class 1 for image [313.]...
# 	found 1 detections for class 1...
# processing class 0 for image [314.]...
# 	found 14 detections for class 0...
# processing class 1 for image [314.]...
# 	found 0 detections for class 1...
# processing class 0 for image [315.]...
# 	found 11 detections for class 0...
# processing class 1 for image [315.]...
# 	found 1 detections for class 1...
# processing class 0 for image [316.]...
# 	found 12 detections for class 0...
# processing class 1 for image [316.]...
# 	found 2 detections for class 1...
# processing class 0 for image [317.]...
# 	found 4 detections for class 0...
# processing class 1 for image [317.]...
# 	found 5 detections for class 1...
# processing class 0 for image [318.]...
# 	found 4 detections for class 0...
# processing class 1 for image [318.]...
# 	found 1 detections for class 1...
# processing class 0 for image [319.]...
# 	found 7 detections for class 0...
# processing class 1 for image [319.]...
# 	found 3 detections for class 1...
# processing class 0 for image [320.]...
# 	found 3 detections for class 0...
# processing class 1 for image [320.]...
# 	found 0 detections for class 1...
# processing class 0 for image [321.]...
# 	found 15 detections for class 0...
# processing class 1 for image [321.]...
# 	found 2 detections for class 1...
# processing class 0 for image [322.]...
# 	found 11 detections for class 0...
# processing class 1 for image [322.]...
# 	found 2 detections for class 1...
# processing class 0 for image [323.]...
# 	found 14 detections for class 0...
# processing class 1 for image [323.]...
# 	found 1 detections for class 1...
# processing class 0 for image [324.]...
# 	found 21 detections for class 0...
# processing class 1 for image [324.]...
# ...
# 	found 1 detections for class 0...
# processing class 1 for image [426.]...
# 	found 2 detections for class 1...
# processing class 0 for image [427.]...
# 	found 0 detections for class 0...
# processing class 1 for image [427.]...
# 	found 1 detections for class 1...
# processing class 0 for image [428.]...
# 	found 0 detections for class 0...
# processing class 1 for image [428.]...
# 	found 3 detections for class 1...
# processing class 0 for image [429.]...
# 	found 5 detections for class 0...
# processing class 1 for image [429.]...
# 	found 4 detections for class 1...
# processing class 0 for image [430.]...
# 	found 8 detections for class 0...
# processing class 1 for image [430.]...
# 	found 3 detections for class 1...
# processing class 0 for image [431.]...
# 	found 10 detections for class 0...
# processing class 1 for image [431.]...
# 	found 6 detections for class 1...
# processing class 0 for image [432.]...
# 	found 15 detections for class 0...
# processing class 1 for image [432.]...
# 	found 2 detections for class 1...
# processing class 0 for image [433.]...
# 	found 7 detections for class 0...
# processing class 1 for image [433.]...
# 	found 1 detections for class 1...
# processing class 0 for image [434.]...
# 	found 4 detections for class 0...
# processing class 1 for image [434.]...
# 	found 3 detections for class 1...
# processing class 0 for image [435.]...
# 	found 3 detections for class 0...
# processing class 1 for image [435.]...
# 	found 4 detections for class 1...
# processing class 0 for image [436.]...
# 	found 8 detections for class 0...
# processing class 1 for image [436.]...
# 	found 0 detections for class 1...
# processing class 0 for image [437.]...
# 	found 25 detections for class 0...
# processing class 1 for image [437.]...
# 	found 6 detections for class 1...
# processing class 0 for image [438.]...
# 	found 2 detections for class 0...
# processing class 1 for image [438.]...
# 	found 0 detections for class 1...
# processing class 0 for image [439.]...
# 	found 7 detections for class 0...
# processing class 1 for image [439.]...
# 	found 3 detections for class 1...
# processing class 0 for image [440.]...
# 	found 17 detections for class 0...
# processing class 1 for image [440.]...
# 	found 2 detections for class 1...
# processing class 0 for image [441.]...
# 	found 13 detections for class 0...
# processing class 1 for image [441.]...
# 	found 8 detections for class 1...
# processing class 0 for image [442.]...
# 	found 1 detections for class 0...
# processing class 1 for image [442.]...
# 	found 0 detections for class 1...
# processing class 0 for image [443.]...
# 	found 54 detections for class 0...
# processing class 1 for image [443.]...
# 	found 3 detections for class 1...
# processing class 0 for image [444.]...
# 	found 61 detections for class 0...
# processing class 1 for image [444.]...
# 	found 4 detections for class 1...
# processing class 0 for image [445.]...
# 	found 12 detections for class 0...
# processing class 1 for image [445.]...
# 	found 1 detections for class 1...
# processing class 0 for image [446.]...
# 	found 13 detections for class 0...
# processing class 1 for image [446.]...
# 	found 1 detections for class 1...
# processing class 0 for image [447.]...
# 	found 19 detections for class 0...
# processing class 1 for image [447.]...
# 	found 9 detections for class 1...
# processing class 0 for image [448.]...
# 	found 40 detections for class 0...
# processing class 1 for image [448.]...
# 	found 8 detections for class 1...
# processing class 0 for image [449.]...
# 	found 5 detections for class 0...
# processing class 1 for image [449.]...
# 	found 1 detections for class 1...
# processing class 0 for image [450.]...
# 	found 12 detections for class 0...
# processing class 1 for image [450.]...
# 	found 3 detections for class 1...
# processing class 0 for image [451.]...
# 	found 6 detections for class 0...
# processing class 1 for image [451.]...
# 	found 4 detections for class 1...
# processing class 0 for image [452.]...
# 	found 32 detections for class 0...
# processing class 1 for image [452.]...
# 	found 9 detections for class 1...
# processing class 0 for image [453.]...
# 	found 8 detections for class 0...
# processing class 1 for image [453.]...
# 	found 11 detections for class 1...
# processing class 0 for image [454.]...
# 	found 14 detections for class 0...
# processing class 1 for image [454.]...
# 	found 9 detections for class 1...
# processing class 0 for image [455.]...
# 	found 4 detections for class 0...
# processing class 1 for image [455.]...
# 	found 17 detections for class 1...
# processing class 0 for image [456.]...
# 	found 5 detections for class 0...
# processing class 1 for image [456.]...
# 	found 14 detections for class 1...
# processing class 0 for image [457.]...
# 	found 11 detections for class 0...
# processing class 1 for image [457.]...
# 	found 12 detections for class 1...
# processing class 0 for image [458.]...
# 	found 13 detections for class 0...
# processing class 1 for image [458.]...
# 	found 15 detections for class 1...
# processing class 0 for image [459.]...
# 	found 14 detections for class 0...
# processing class 1 for image [459.]...
# 	found 12 detections for class 1...
# processing class 0 for image [460.]...
# 	found 23 detections for class 0...
# processing class 1 for image [460.]...
# 	found 9 detections for class 1...
# processing class 0 for image [461.]...
# 	found 6 detections for class 0...
# processing class 1 for image [461.]...
# 	found 5 detections for class 1...
# processing class 0 for image [462.]...
# 	found 12 detections for class 0...
# processing class 1 for image [462.]...
# 	found 2 detections for class 1...
# processing class 0 for image [463.]...
# 	found 6 detections for class 0...
# processing class 1 for image [463.]...
# 	found 2 detections for class 1...
# processing class 0 for image [464.]...
# 	found 11 detections for class 0...
# processing class 1 for image [464.]...
# 	found 2 detections for class 1...
# processing class 0 for image [465.]...
# 	found 4 detections for class 0...
# processing class 1 for image [465.]...
# 	found 2 detections for class 1...
# processing class 0 for image [466.]...
# 	found 5 detections for class 0...
# processing class 1 for image [466.]...
# 	found 0 detections for class 1...
# processing class 0 for image [467.]...
# 	found 0 detections for class 0...
# processing class 1 for image [467.]...
# 	found 0 detections for class 1...
# processing class 0 for image [468.]...
# 	found 4 detections for class 0...
# processing class 1 for image [468.]...
# 	found 0 detections for class 1...
# processing class 0 for image [469.]...
# 	found 34 detections for class 0...
# processing class 1 for image [469.]...
# 	found 9 detections for class 1...
# processing class 0 for image [470.]...
# 	found 36 detections for class 0...
# processing class 1 for image [470.]...
# 	found 9 detections for class 1...
# processing class 0 for image [471.]...
# 	found 16 detections for class 0...
# processing class 1 for image [471.]...
# 	found 2 detections for class 1...
# processing class 0 for image [472.]...
# 	found 16 detections for class 0...
# processing class 1 for image [472.]...
# 	found 7 detections for class 1...
# processing class 0 for image [473.]...
# 	found 18 detections for class 0...
# processing class 1 for image [473.]...
# 	found 5 detections for class 1...
# processing class 0 for image [474.]...
# 	found 20 detections for class 0...
# processing class 1 for image [474.]...
# 	found 3 detections for class 1...
# processing class 0 for image [475.]...
# 	found 31 detections for class 0...
# processing class 1 for image [475.]...
# 	found 12 detections for class 1...
# processing class 0 for image [476.]...
# 	found 17 detections for class 0...
# processing class 1 for image [476.]...
# 	found 3 detections for class 1...
# processing class 0 for image [477.]...
# 	found 14 detections for class 0...
# processing class 1 for image [477.]...
# 	found 3 detections for class 1...
# processing class 0 for image [478.]...
# 	found 37 detections for class 0...
# processing class 1 for image [478.]...
# 	found 17 detections for class 1...
# processing class 0 for image [479.]...
# 	found 44 detections for class 0...
# processing class 1 for image [479.]...
# 	found 6 detections for class 1...
# processing class 0 for image [480.]...
# 	found 37 detections for class 0...
# processing class 1 for image [480.]...
# 	found 8 detections for class 1...
# processing class 0 for image [481.]...
# 	found 24 detections for class 0...
# processing class 1 for image [481.]...
# 	found 7 detections for class 1...
# processing class 0 for image [482.]...
# 	found 32 detections for class 0...
# processing class 1 for image [482.]...
# 	found 8 detections for class 1...
# processing class 0 for image [483.]...
# 	found 30 detections for class 0...
# processing class 1 for image [483.]...
# 	found 8 detections for class 1...
# processing class 0 for image [484.]...
# 	found 37 detections for class 0...
# processing class 1 for image [484.]...
# 	found 1 detections for class 1...
# processing class 0 for image [485.]...
# 	found 30 detections for class 0...
# processing class 1 for image [485.]...
# 	found 5 detections for class 1...
# processing class 0 for image [486.]...
# 	found 29 detections for class 0...
# processing class 1 for image [486.]...
# 	found 5 detections for class 1...
# processing class 0 for image [487.]...
# 	found 35 detections for class 0...
# processing class 1 for image [487.]...
# 	found 8 detections for class 1...
# processing class 0 for image [488.]...
# 	found 25 detections for class 0...
# processing class 1 for image [488.]...
# 	found 2 detections for class 1...
# processing class 0 for image [489.]...
# 	found 37 detections for class 0...
# processing class 1 for image [489.]...
# 	found 8 detections for class 1...
# processing class 0 for image [490.]...
# 	found 27 detections for class 0...
# processing class 1 for image [490.]...
# 	found 10 detections for class 1...
# processing class 0 for image [491.]...
# 	found 28 detections for class 0...
# processing class 1 for image [491.]...
# 	found 3 detections for class 1...
# processing class 0 for image [492.]...
# 	found 33 detections for class 0...
# processing class 1 for image [492.]...
# 	found 6 detections for class 1...
# processing class 0 for image [493.]...
# 	found 43 detections for class 0...
# processing class 1 for image [493.]...
# 	found 0 detections for class 1...
# processing class 0 for image [494.]...
# 	found 30 detections for class 0...
# processing class 1 for image [494.]...
# 	found 5 detections for class 1...
# processing class 0 for image [495.]...
# 	found 11 detections for class 0...
# processing class 1 for image [495.]...
# 	found 6 detections for class 1...
# processing class 0 for image [496.]...
# 	found 18 detections for class 0...
# processing class 1 for image [496.]...
# 	found 6 detections for class 1...
# processing class 0 for image [497.]...
# 	found 5 detections for class 0...
# processing class 1 for image [497.]...
# 	found 6 detections for class 1...
# processing class 0 for image [498.]...
# 	found 7 detections for class 0...
# processing class 1 for image [498.]...
# 	found 1 detections for class 1...
# processing class 0 for image [499.]...
# 	found 11 detections for class 0...
# processing class 1 for image [499.]...
# 	found 3 detections for class 1...
# processing class 0 for image [500.]...
# 	found 4 detections for class 0...
# processing class 1 for image [500.]...
# 	found 0 detections for class 1...
# processing class 0 for image [501.]...
# 	found 0 detections for class 0...
# processing class 1 for image [501.]...
# 	found 0 detections for class 1...
# processing class 0 for image [502.]...
# 	found 3 detections for class 0...
# processing class 1 for image [502.]...
# 	found 0 detections for class 1...
# processing class 0 for image [503.]...
# 	found 8 detections for class 0...
# processing class 1 for image [503.]...
# 	found 1 detections for class 1...
# processing class 0 for image [504.]...
# 	found 3 detections for class 0...
# processing class 1 for image [504.]...
# 	found 3 detections for class 1...
# processing class 0 for image [505.]...
# 	found 1 detections for class 0...
# processing class 1 for image [505.]...
# 	found 8 detections for class 1...
# processing class 0 for image [506.]...
# 	found 17 detections for class 0...
# processing class 1 for image [506.]...
# 	found 14 detections for class 1...
# processing class 0 for image [507.]...
# 	found 10 detections for class 0...
# processing class 1 for image [507.]...
# 	found 9 detections for class 1...
# processing class 0 for image [508.]...
# 	found 9 detections for class 0...
# processing class 1 for image [508.]...
# 	found 11 detections for class 1...
# processing class 0 for image [509.]...
# 	found 11 detections for class 0...
# processing class 1 for image [509.]...
# 	found 8 detections for class 1...
# processing class 0 for image [510.]...
# 	found 5 detections for class 0...
# processing class 1 for image [510.]...
# 	found 7 detections for class 1...
# processing class 0 for image [511.]...
# 	found 10 detections for class 0...
# processing class 1 for image [511.]...
# 	found 7 detections for class 1...
# processing class 0 for image [512.]...
# 	found 13 detections for class 0...
# processing class 1 for image [512.]...
# 	found 1 detections for class 1...
# processing class 0 for image [513.]...
# 	found 6 detections for class 0...
# processing class 1 for image [513.]...
# 	found 6 detections for class 1...
# processing class 0 for image [514.]...
# 	found 12 detections for class 0...
# processing class 1 for image [514.]...
# 	found 4 detections for class 1...
# processing class 0 for image [515.]...
# 	found 11 detections for class 0...
# processing class 1 for image [515.]...
# 	found 8 detections for class 1...
# processing class 0 for image [516.]...
# 	found 6 detections for class 0...
# processing class 1 for image [516.]...
# 	found 7 detections for class 1...
# processing class 0 for image [517.]...
# 	found 8 detections for class 0...
# processing class 1 for image [517.]...
# 	found 4 detections for class 1...
# processing class 0 for image [518.]...
# 	found 7 detections for class 0...
# processing class 1 for image [518.]...
# 	found 2 detections for class 1...
# processing class 0 for image [519.]...
# 	found 2 detections for class 0...
# processing class 1 for image [519.]...
# 	found 3 detections for class 1...
# processing class 0 for image [520.]...
# 	found 5 detections for class 0...
# processing class 1 for image [520.]...
# 	found 4 detections for class 1...
# processing class 0 for image [521.]...
# 	found 10 detections for class 0...
# processing class 1 for image [521.]...
# 	found 5 detections for class 1...
# processing class 0 for image [522.]...
# 	found 8 detections for class 0...
# processing class 1 for image [522.]...
# 	found 2 detections for class 1...
# processing class 0 for image [523.]...
# 	found 9 detections for class 0...
# processing class 1 for image [523.]...
# 	found 6 detections for class 1...
# processing class 0 for image [524.]...
# 	found 3 detections for class 0...
# processing class 1 for image [524.]...
# 	found 3 detections for class 1...
# processing class 0 for image [525.]...
# 	found 0 detections for class 0...
# processing class 1 for image [525.]...
# 	found 4 detections for class 1...
# processing class 0 for image [526.]...
# 	found 4 detections for class 0...
# processing class 1 for image [526.]...
# 	found 6 detections for class 1...
# processing class 0 for image [527.]...
# 	found 4 detections for class 0...
# processing class 1 for image [527.]...
# 	found 0 detections for class 1...
# processing class 0 for image [528.]...
# 	found 7 detections for class 0...
# processing class 1 for image [528.]...
# 	found 12 detections for class 1...
# processing class 0 for image [529.]...
# 	found 23 detections for class 0...
# processing class 1 for image [529.]...
# 	found 10 detections for class 1...
# processing class 0 for image [530.]...
# 	found 14 detections for class 0...
# processing class 1 for image [530.]...
# 	found 19 detections for class 1...
# processing class 0 for image [531.]...
# 	found 23 detections for class 0...
# processing class 1 for image [531.]...
# 	found 22 detections for class 1...
# processing class 0 for image [532.]...
# 	found 25 detections for class 0...
# processing class 1 for image [532.]...
# 	found 16 detections for class 1...
# Total of 10872 annotations saved to /local/shared_with_docker/visdrone/detections_VisDrone_val.json

# %% [markdown]
# ## Redundant functions and code
# This was used for single image inference, e.g. for iterating over each image

# %%
# these functions are used for single image evaluation
# intented for use when iterating over the dataset
def get_input_data(image_dataset, image_id):
    assert image_id >0, f"Image id should be >0 as per coco formatting"

    imgname, imgid = image_dataset[image_id-1]
    imgfile = os.path.join(images_path, imgname)
    print(f"opening image at {imgfile}")
    img = Image.open(imgfile).convert('RGB')
    img_preproc = preproc(img)
    img_input = img_preproc.reshape(1,640,640,3)
    
    return img_input, imgid, img

def get_single_image(image_rootpath, image_file):
    imgfile = os.path.join(image_rootpath, imgname)
    print(f"opening image at {imgfile}")
    img = Image.open(imgfile).convert('RGB')
    img_preproc = preproc(img)
    img_input = img_preproc.reshape(1,640,640,3)
    
    return img_input, img

def detections_to_json(detections):
    class_remap = {0: 1, 1: 2}
    res = []
    annId = 1
    for el in detections:
        x,y,w,h,conf,classid,imgid = el
        imgid = int(imgid)
        res.append({"image_id": imgid, "category_id": class_remap[classid], "bbox": [x,y,w,h], "score": conf, "id": annId, "segmentation": []}) 
        annId +=1
    return res

def get_single_image(image_rootpath, image_file):
    imgfile = os.path.join(image_rootpath, image_file)
    print(f"opening image at {imgfile}")
    img = Image.open(imgfile).convert('RGB')
    img_preproc = preproc(img)
    img_input = img_preproc.reshape(1,640,640,3)
    
    return img_input, img

def generate_detections_file(image_list, image_dir):
    all_dets = []
    for idx, imgdata in enumerate(image_list):
        imgname, imgid = imgdata
        img_input, img = get_single_image(image_dir, imgname)
        
        output = run_inference(runner=runner, sdk_type='x', input_data=img_input)
        detections = remove_zero_padding(output, imgid)

        xywh = np.full_like(detections, detections)
        xywh = swap_columns(xywh) # annoyingly, it is in yx, ont xy, what misery
        xywh = ltxy2xywh(xywh) # convert x2/y2 to w/h


        w,h, name = get_image_metadata(images, imgid)

        dets_scaled = rescale_bbox(xywh, w, h)
        all_dets.append(dets_scaled)
    return(all_dets)
# full_data_dets = generate_detections_file(image_list, images_path)

    

# img_input, imgid, img = get_input_data(image_list, 1)
# output = run_inference(runner=runner, sdk_type='opt', input_data=img_input)
# detections = remove_zero_padding(output, imgid)

# xywh = np.full_like(detections, detections)
# xywh = swap_columns(xywh) # annoyingly, it is in yx, ont xy, what misery
# xywh = ltxy2xywh(xywh) # convert x2/y2 to w/h


# w,h, name = get_image_metadata(images, imgid)

# dets_scaled = rescale_bbox(xywh, w, h)

# processed_outputs = detections_to_json(dets_scaled)
# outputfile = f"/local/shared_with_docker/visdrone/detections_VisDrone_quant_dets.json" 
# with open(outputfile, 'w') as outf:
#     json.dump(processed_outputs, outf)
#     outf.close()
    
# print(f"Total of {len(processed_outputs)} annotations saved to {outputfile}")
