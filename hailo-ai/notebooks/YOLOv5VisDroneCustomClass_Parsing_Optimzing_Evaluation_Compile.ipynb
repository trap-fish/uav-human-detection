# %% [markdown]
# The following has been adapted from Hailo's DFC Tutorials 1 and 2 (Parsing and Optimizing with DFC). It was run from a docker container setup using Hailo AI SoftwareSuite

# %%
# General imports used throughout the tutorial
# file operations
import json
import os

import numpy as np
import tensorflow as tf
from IPython.display import SVG
from matplotlib import patches
from matplotlib import pyplot as plt
from PIL import Image
from tensorflow.python.eager.context import eager_mode

import torchvision as tv
import torch

import cv2

# import the hailo sdk client relevant classes
from hailo_sdk_client import ClientRunner, InferenceContext

# %matplotlib inline

IMAGES_TO_VISUALIZE = 5
# Out:
# 2025-04-18 20:39:05.021853: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-18 20:39:05.048132: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-18 20:39:05.422477: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
chosen_hw_arch = "hailo8l"

# %% [markdown]
# ## Model Optimization

# %%
def resize_with_letterbox(image_path, target_shape=(1,640,640,3), padding_value=(0, 0, 0)):
    """
    Resizes an image with letterboxing to fit the target size, preserving aspect ratio.
    
    Parameters:
        image_path (str): Path to the input image.
        target_shape (tuple): Target shape in NHWC format (batch_size, target_height, target_width, channels).
        padding_value (tuple): RGB values for padding (default is black padding).
        
    Returns:
        letterboxed_image (ndarray): The resized image with letterboxing.
        scale (float): Scaling ratio applied to the original image.
        pad_top (int): Padding applied to the top.
        pad_left (int): Padding applied to the left.
    """
    # Load the image from the given path
    image = cv2.imread(image_path)
    
    # Check if the image was loaded successfully
    if image is None:
        raise ValueError(f"Error: Unable to load image from path: {image_path}")
    
#     # Convert the image from BGR to RGB
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Get the original image dimensions (height, width, channels)
    h, w, c = image.shape
    
    # Extract target height and width from target_shape (NHWC format)
    target_height, target_width = target_shape[1], target_shape[2]
    
    # Calculate the scaling factors for width and height
    scale_x = target_width / w
    scale_y = target_height / h
    
    # Choose the smaller scale factor to preserve the aspect ratio
    scale = min(scale_x, scale_y)
    
    # Calculate the new dimensions based on the scaling factor
    new_w = int(w * scale)
    new_h = int(h * scale)

    # Resize the image to the new dimensions
    resized_image = cv2.resize(image, (new_w, new_h),interpolation=cv2.INTER_LINEAR)
    
    # Create a new image with the target size, filled with the padding value
    letterboxed_image = np.full((target_height, target_width, c), padding_value, dtype=np.uint8)
    
    # Compute the position where the resized image should be placed (padding)
    pad_top = (target_height - new_h) // 2
    pad_left = (target_width - new_w) // 2
    
    # Place the resized image onto the letterbox background
    letterboxed_image[pad_top:pad_top+new_h, pad_left:pad_left+new_w] = resized_image

    
    # Return the letterboxed image, scaling ratio, and padding (top, left)
    return letterboxed_image, scale, pad_top, pad_left

# %%
# quantization needs calibration data, use the training data for this
cal_images_path = "../data/visdrone/train/images/" # use training data for calib
cal_images_list = [img_name for img_name in os.listdir(cal_images_path) if os.path.splitext(img_name)[1] == ".jpg"]
dataset_sz = 3000
calib_dataset = np.zeros((dataset_sz, 640, 640, 3))

for idx, img_name in enumerate(sorted(cal_images_list)):
    if idx==dataset_sz:
        break
    imgpth = os.path.join(cal_images_path, img_name)
    img_preproc, _, _, _ = resize_with_letterbox(imgpth, (1,640,640,3))
    calib_dataset[idx, :, :, :] = img_preproc
    
print(f"Calibration dataset size: {calib_dataset.shape}")
# Out:
# Calibration dataset size: (3000, 640, 640, 3)

# %%
onnx_model_name = "yolov5n_visdrone"
onnx_path = '/local/shared_with_docker/visdrone/models/best/onnx/exp_1_yolov5sv6_singlecls.onnx'

runner = ClientRunner(hw_arch=chosen_hw_arch)
hn, npz = runner.translate_onnx_model(
    onnx_path,
    onnx_model_name,
    start_node_names=["/model.0/conv/Conv"],
#     start_node_names=['images'],
    end_node_names=["/model.24/m.2/Conv", 
                   "/model.24/m.1/Conv",
                   "/model.24/m.0/Conv"],
#     end_node_names=['Transpose_217', 'Transpose_233', 'Transpose_249'],
    net_input_shapes={"/model.0/conv/Conv": [1, 3, 640, 640]},
)
#save the parsed model
hailo_model_har_name = f"{onnx_model_name}_{str.split(os.path.basename(onnx_path),'.')[0]}_hailo_model_singlecls.har"
runner.save_har(hailo_model_har_name)

#load our parsed HAR from the Parsing Tutorial
assert os.path.isfile(hailo_model_har_name), "Please provide valid path for HAR file"
runner = ClientRunner(har=hailo_model_har_name)
print(f"\n\n{'='*100}\nloaded {hailo_model_har_name}\n{'='*100}\n\n")

alls =  """
normalization1 = normalization([0.0, 0.0, 0.0], [255.0, 255.0, 255.0])
change_output_activation(sigmoid)
model_optimization_config(calibration, batch_size=8, calibset_size=256)
post_quantization_optimization(finetune, policy=enabled, learning_rate=0.00001, epochs=8, batch_size=16, dataset_size=3000)
nms_postprocess("/local/shared_with_docker/visdrone/postprocess_config/yolov5nv6_nms_config_custom.json", yolov5, engine=cpu)
allocator_param(width_splitter_defuse=disabled)

"""
# nms_postprocess("/local/shared_with_docker/visdrone/postprocess_config/yolov5s_nms_config.json", yolov5, engine=cpu)

runner.load_model_script(alls)
# runner.optimize_full_precision()

runner.optimize(calib_dataset)

# model_name = "yolov5s_visdrone_singlecls"
# quant_model_har_path = f"{model_name}_quant_model.har"
# runner.save_har(quant_model_har_path)
# print(f"\n\n{'='*100}\nsaving {quant_model_har_path}\n{'='*100}\n\n")
# Out:
# [info] Translation started on ONNX model yolov5n_visdrone
# [info] Restored ONNX model yolov5n_visdrone (completion time: 00:00:00.07)
# [info] Extracted ONNXRuntime meta-data for Hailo model (completion time: 00:00:00.27)
# [info] NMS structure of yolov5 (or equivalent architecture) was detected.
# [info] Start nodes mapped from original model: 'images': 'yolov5n_visdrone/input_layer1'.
# [info] End nodes mapped from original model: '/model.24/m.2/Conv', '/model.24/m.1/Conv', '/model.24/m.0/Conv'.
# [info] Translation completed on ONNX model yolov5n_visdrone (completion time: 00:00:00.71)
# [info] Saved HAR to: /local/workspace/hailo_virtualenv/lib/python3.10/site-packages/hailo_tutorials/notebooks/yolov5n_visdrone_exp_1_yolov5sv6_singlecls_hailo_model_singlecls.har
#
#
# ====================================================================================================
# loaded yolov5n_visdrone_exp_1_yolov5sv6_singlecls_hailo_model_singlecls.har
# ====================================================================================================
#
#
# [info] Loading model script commands to yolov5n_visdrone from string
# [info] Starting Model Optimization
# 2025-04-18 20:42:12.688016: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:12.703924: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:12.704062: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:12.704840: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:12.704932: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:12.704991: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:12.749434: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:12.749557: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:12.749616: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:12.749663: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-04-18 20:42:12.749680: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /device:GPU:0 with 13916 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2025-04-18 20:42:13.160595: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.175856: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.175994: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.176873: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.176950: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.177001: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.222833: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.222935: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.222993: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.223038: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-04-18 20:42:13.223057: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13908 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080, pci bus id: 0000:01:00.0, compute capability: 8.9
# [info] Using default optimization level of 2
# [info] Model received quantization params from the hn
# 2025-04-18 20:42:13.697889: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.714053: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.714195: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.714915: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.714987: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.715037: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.770089: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.770217: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.770275: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:13.770319: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-04-18 20:42:13.770335: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /device:GPU:0 with 13908 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2025-04-18 20:42:14.164545: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:14.179875: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:14.180017: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:14.180770: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:14.180869: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:14.180918: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:14.221431: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:14.221554: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:14.221611: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:14.221657: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-04-18 20:42:14.221672: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13908 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080, pci bus id: 0000:01:00.0, compute capability: 8.9
# [info] MatmulDecompose skipped
# [info] Starting Mixed Precision
# [info] Model Optimization Algorithm Mixed Precision is done (completion time is 00:00:00.47)
# [info] LayerNorm Decomposition skipped
# [info] Starting Statistics Collector
# [info] Using dataset with 256 entries for calibration
# Calibration:   0%|                                                                                                                                                            | 0/256 [00:00<?, ?entries/s]2025-04-18 20:42:20.054530: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:20.138094: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:30.089125: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8906
# 2025-04-18 20:42:30.337761: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Calibration:   9%|█████████████▊                                                                                                                                     | 24/256 [00:13<01:38,  2.36entries/s]2025-04-18 20:42:30.768993: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:30.840230: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:30.907483: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# Calibration:  22%|████████████████████████████████▏                                                                                                                  | 56/256 [00:13<00:24,  8.01entries/s]2025-04-18 20:42:30.975594: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:31.043383: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:31.112228: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# Calibration:  28%|█████████████████████████████████████████▎                                                                                                         | 72/256 [00:13<00:14, 12.35entries/s]2025-04-18 20:42:31.179867: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:31.247481: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:31.316163: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# Calibration:  41%|███████████████████████████████████████████████████████████▎                                                                                      | 104/256 [00:13<00:06, 25.04entries/s]2025-04-18 20:42:31.383984: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:31.453454: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:31.521420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# Calibration:  47%|████████████████████████████████████████████████████████████████████▍                                                                             | 120/256 [00:13<00:04, 33.55entries/s]2025-04-18 20:42:31.590463: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:31.658980: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:31.727477: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# Calibration:  59%|██████████████████████████████████████████████████████████████████████████████████████▋                                                           | 152/256 [00:14<00:01, 53.79entries/s]2025-04-18 20:42:31.795785: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:31.864596: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:31.931750: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# Calibration:  66%|███████████████████████████████████████████████████████████████████████████████████████████████▊                                                  | 168/256 [00:14<00:01, 64.68entries/s]2025-04-18 20:42:32.000743: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:32.067937: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:32.135242: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# Calibration:  78%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                | 200/256 [00:14<00:00, 84.02entries/s]2025-04-18 20:42:32.204131: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:32.272900: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:32.341090: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# Calibration:  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                      | 216/256 [00:14<00:00, 92.29entries/s]2025-04-18 20:42:32.409480: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:32.476591: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:32.544055: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# Calibration:  97%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍    | 248/256 [00:14<00:00, 103.80entries/s]2025-04-18 20:42:32.613206: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:32.681576: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:32.748749: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# Calibration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 256/256 [00:14<00:00, 17.07entries/s]
# 2025-04-18 20:42:32.821798: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# [info] Model Optimization Algorithm Statistics Collector is done (completion time is 00:00:15.89)
# [info] Starting Fix zp_comp Encoding
# [info] Model Optimization Algorithm Fix zp_comp Encoding is done (completion time is 00:00:00.00)
# [info] Matmul Equalization skipped
# 2025-04-18 20:42:41.933322: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:41.955157: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:41.955300: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:41.956135: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:41.956233: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:41.956282: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:42.000022: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:42.000144: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:42.000202: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:42.000247: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-04-18 20:42:42.000264: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /device:GPU:0 with 13908 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2025-04-18 20:42:42.980713: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:42.995137: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:42.995239: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:42.995971: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:42.996049: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:42.996099: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:43.039348: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:43.039478: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:43.039537: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:42:43.039581: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-04-18 20:42:43.039596: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13908 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080, pci bus id: 0000:01:00.0, compute capability: 8.9
# [info] Finetune encoding skipped
# [info] Bias Correction skipped
# [info] Adaround skipped
# [info] Starting Quantization-Aware Fine-Tuning
# [info] Using dataset with 3000 entries for finetune
# Epoch 1/8
# 2025-04-18 20:42:47.794495: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:42:47.794659: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:43:33.479685: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inSelectV2_20-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-04-18 20:43:38.674470: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8906
# 2025-04-18 20:43:39.300089: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-04-18 20:43:40.213222: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x563bd6d2dd80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-04-18 20:43:40.213235: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 4080, Compute Capability 8.9
# 2025-04-18 20:43:40.215809: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-04-18 20:43:40.291649: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 187/187 [==============================] - 164s 554ms/step - total_distill_loss: 0.5968 - _distill_loss_yolov5n_visdrone/conv47: 0.0457 - _distill_loss_yolov5n_visdrone/conv54: 0.0555 - _distill_loss_yolov5n_visdrone/conv60: 0.0699 - _distill_loss_yolov5n_visdrone/conv45: 0.1927 - _distill_loss_yolov5n_visdrone/conv52: 0.2331
# Epoch 2/8
# 187/187 [==============================] - 104s 557ms/step - total_distill_loss: 0.4864 - _distill_loss_yolov5n_visdrone/conv47: 0.0400 - _distill_loss_yolov5n_visdrone/conv54: 0.0481 - _distill_loss_yolov5n_visdrone/conv60: 0.0600 - _distill_loss_yolov5n_visdrone/conv45: 0.1533 - _distill_loss_yolov5n_visdrone/conv52: 0.1850
# Epoch 3/8
# 187/187 [==============================] - 104s 556ms/step - total_distill_loss: 0.4503 - _distill_loss_yolov5n_visdrone/conv47: 0.0383 - _distill_loss_yolov5n_visdrone/conv54: 0.0458 - _distill_loss_yolov5n_visdrone/conv60: 0.0571 - _distill_loss_yolov5n_visdrone/conv45: 0.1413 - _distill_loss_yolov5n_visdrone/conv52: 0.1677
# Epoch 4/8
# 187/187 [==============================] - 103s 551ms/step - total_distill_loss: 0.4434 - _distill_loss_yolov5n_visdrone/conv47: 0.0378 - _distill_loss_yolov5n_visdrone/conv54: 0.0452 - _distill_loss_yolov5n_visdrone/conv60: 0.0563 - _distill_loss_yolov5n_visdrone/conv45: 0.1395 - _distill_loss_yolov5n_visdrone/conv52: 0.1645
# Epoch 5/8
# 187/187 [==============================] - 104s 554ms/step - total_distill_loss: 0.4335 - _distill_loss_yolov5n_visdrone/conv47: 0.0374 - _distill_loss_yolov5n_visdrone/conv54: 0.0446 - _distill_loss_yolov5n_visdrone/conv60: 0.0556 - _distill_loss_yolov5n_visdrone/conv45: 0.1361 - _distill_loss_yolov5n_visdrone/conv52: 0.1598
# Epoch 6/8
# 187/187 [==============================] - 104s 555ms/step - total_distill_loss: 0.4266 - _distill_loss_yolov5n_visdrone/conv47: 0.0372 - _distill_loss_yolov5n_visdrone/conv54: 0.0442 - _distill_loss_yolov5n_visdrone/conv60: 0.0552 - _distill_loss_yolov5n_visdrone/conv45: 0.1332 - _distill_loss_yolov5n_visdrone/conv52: 0.1568
# Epoch 7/8
# 187/187 [==============================] - 104s 554ms/step - total_distill_loss: 0.4247 - _distill_loss_yolov5n_visdrone/conv47: 0.0371 - _distill_loss_yolov5n_visdrone/conv54: 0.0443 - _distill_loss_yolov5n_visdrone/conv60: 0.0552 - _distill_loss_yolov5n_visdrone/conv45: 0.1329 - _distill_loss_yolov5n_visdrone/conv52: 0.1553
# Epoch 8/8
# 187/187 [==============================] - 104s 555ms/step - total_distill_loss: 0.4314 - _distill_loss_yolov5n_visdrone/conv47: 0.0372 - _distill_loss_yolov5n_visdrone/conv54: 0.0443 - _distill_loss_yolov5n_visdrone/conv60: 0.0556 - _distill_loss_yolov5n_visdrone/conv45: 0.1352 - _distill_loss_yolov5n_visdrone/conv52: 0.1590
# [info] Model Optimization Algorithm Quantization-Aware Fine-Tuning is done (completion time is 00:14:51.13)
# 2025-04-18 20:57:44.985201: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:45.007190: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:45.007323: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:45.008185: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:45.008287: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:45.008337: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:45.057868: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:45.057977: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:45.058041: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:45.058086: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-04-18 20:57:45.058103: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /device:GPU:0 with 13895 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2025-04-18 20:57:46.048877: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:46.063425: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:46.063561: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:46.064277: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:46.064354: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:46.064404: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:46.099425: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:46.099569: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:46.099633: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 20:57:46.099681: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-04-18 20:57:46.099697: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13895 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080, pci bus id: 0000:01:00.0, compute capability: 8.9
# [info] Starting Layer Noise Analysis
# Full Quant Analysis:  50%|█████████████████████████████████████████████████████████████████████▌                                                                     | 1/2 [00:00<00:00,  1.58iterations/s]2025-04-18 20:57:51.116179: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:57:51.223493: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 20:58:57.062597: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8906
# 2025-04-18 20:58:57.282377: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Full Quant Analysis: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [01:07<00:00, 39.67s/iterations]2025-04-18 20:58:58.200343: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [8,640,640,3]
# 	 [[{{node Placeholder/_0}}]]
# Full Quant Analysis: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [01:08<00:00, 34.13s/iterations]
# [info] Model Optimization Algorithm Layer Noise Analysis is done (completion time is 00:01:09.58)
# [info] Model Optimization is done

# %%
model_name = onnx_path.split('.onnx')[0].split('/')[-1]
quant_model_har_path = model_name + '_quant_model.har'
runner.save_har(quant_model_har_path)
print(f"\n\n{'='*100}\nsaving {quant_model_har_path}\n{'='*100}\n\n")
# Out:
# [info] Saved HAR to: /local/workspace/hailo_virtualenv/lib/python3.10/site-packages/hailo_tutorials/notebooks/exp_1_yolov5sv6_singlecls_quant_model.har
#
#
# ====================================================================================================
# saving exp_1_yolov5sv6_singlecls_quant_model.har
# ====================================================================================================

# %%
onnx_model_name = "yolo5_visdrone"
onnx_path = "/local/shared_with_docker/visdrone/models/yolov5v0_exp5_singlecls_export/weights/best.onnx"

runner = ClientRunner(hw_arch=chosen_hw_arch)
hn, npz = runner.translate_onnx_model(
    onnx_path,
    onnx_model_name,
#     start_node_names=["/model.0/conv/Conv"],
    start_node_names=['images'],
#     end_node_names=["/model.24/m.2/Conv", 
#                    "/model.24/m.1/Conv",
#                    "/model.24/m.0/Conv"],
    end_node_names=['Transpose_217', 'Transpose_233', 'Transpose_249'],
    net_input_shapes={"images": [1, 3, 640, 640]},
)
#save the parsed model
hailo_model_har_name = f"{onnx_model_name}_{str.split(os.path.basename(onnx_path),'.')[0]}_hailo_model_singlecls.har"
runner.save_har(hailo_model_har_name)

#load our parsed HAR from the Parsing Tutorial
assert os.path.isfile(hailo_model_har_name), "Please provide valid path for HAR file"
runner = ClientRunner(har=hailo_model_har_name)
print(f"\n\n{'='*100}\nloaded {hailo_model_har_name}\n{'='*100}\n\n")

alls =  """
normalization1 = normalization([0.0, 0.0, 0.0], [255.0, 255.0, 255.0])
change_output_activation(sigmoid)
model_optimization_config(calibration, batch_size=8, calibset_size=256)
post_quantization_optimization(finetune, policy=enabled, learning_rate=0.00001, epochs=8, batch_size=16, dataset_size=1024)
nms_postprocess("/local/shared_with_docker/visdrone/postprocess_config/yolov5s_2cls_nms_config.json", yolov5, engine=cpu)
allocator_param(width_splitter_defuse=disabled)

"""
# nms_postprocess("/local/shared_with_docker/visdrone/postprocess_config/yolov5s_nms_config.json", yolov5, engine=cpu)

runner.load_model_script(alls)
# runner.optimize_full_precision()

runner.optimize(calib_dataset)

model_name = "yolov5s_visdrone_singlecls"
quant_model_har_path = f"{model_name}_quant_model.har"
runner.save_har(quant_model_har_path)
print(f"\n\n{'='*100}\nsaving {quant_model_har_path}\n{'='*100}\n\n")

# %%
from hailo_sdk_client import ClientRunner

# Load the HAR file
# har_path = "/local/shared_with_docker/visdrone/models/yolov5s_hmz_2cls_coco_quant.har"
har_path = 'yolov5s_parsed.har'
runner = ClientRunner(har=har_path)

from pprint import pprint

try:
    # Access the HailoNet as an OrderedDict
    hn_dict = runner.get_hn()  # Or use runner._hn if get_hn() is unavailable
    print("Inspecting layers from HailoNet (OrderedDict):")

    # Pretty-print each layer
    for key, value in hn_dict.items():
        print(f"Key: {key}")
        pprint(value)
        print("\n" + "="*80 + "\n")  # Add a separator between layers for clarity

except Exception as e:
    print(f"Error while inspecting hn_dict: {e}")
# Out:
# Inspecting layers from HailoNet (OrderedDict):
# Key: name
# 'yolov5s'
#
# ================================================================================
#
# Key: net_params
# OrderedDict([('version', '1.0'),
#              ('stage', 'HN'),
#              ('clusters_placement', [[]]),
#              ('clusters_to_skip', []),
#              ('output_layers_order',
#               ['yolov5s/conv55', 'yolov5s/conv63', 'yolov5s/conv70']),
#              ('is_transformer', False),
#              ('transposed_net', False),
#              ('net_scopes', ['yolov5s']),
#              ('lora_adapters', [])])
#
# ================================================================================
#
# Key: layers
# OrderedDict([('yolov5s/input_layer1',
#               OrderedDict([('type', 'input_layer'),
#                            ('input', []),
#                            ('output', ['yolov5s/space_to_depth1']),
#                            ('input_shapes', [[-1, 640, 640, 3]]),
#                            ('output_shapes', [[-1, 640, 640, 3]]),
#                            ('original_names', ['images']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('transposed', False),
#                            ('engine', 'nn_core'),
#                            ('io_type', 'standard')])),
#              ('yolov5s/space_to_depth1',
#               OrderedDict([('type', 'space_to_depth'),
#                            ('input', ['yolov5s/input_layer1']),
#                            ('output', ['yolov5s/conv1']),
#                            ('input_shapes', [[-1, 640, 640, 3]]),
#                            ('output_shapes', [[-1, 320, 320, 12]]),
#                            ('original_names',
#                             ['Slice_14',
#                              'Slice_4',
#                              'Slice_9',
#                              'Slice_19',
#                              'Slice_24',
#                              'Slice_29',
#                              'Slice_34',
#                              'Slice_39',
#                              'Concat_40']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('block_sizes', [2, 2]),
#                                          ('space_to_depth_type', 'focus')]))])),
#              ('yolov5s/conv1',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/space_to_depth1']),
#                            ('output', ['yolov5s/conv2']),
#                            ('input_shapes', [[-1, 320, 320, 12]]),
#                            ('output_shapes', [[-1, 320, 320, 32]]),
#                            ('original_names', ['Conv_41', 'LeakyRelu_42']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [3, 3, 12, 32]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'SAME_TENSORFLOW'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv2',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv1']),
#                            ('output', ['yolov5s/conv3', 'yolov5s/conv4']),
#                            ('input_shapes', [[-1, 320, 320, 32]]),
#                            ('output_shapes',
#                             [[-1, 160, 160, 64], [-1, 160, 160, 64]]),
#                            ('original_names', ['Conv_43', 'LeakyRelu_44']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [3, 3, 32, 64]),
#                                          ('strides', [1, 2, 2, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'SAME'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv3',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv2']),
#                            ('output', ['yolov5s/conv5', 'yolov5s/ew_add1']),
#                            ('input_shapes', [[-1, 160, 160, 64]]),
#                            ('output_shapes',
#                             [[-1, 160, 160, 32], [-1, 160, 160, 32]]),
#                            ('original_names', ['Conv_45', 'LeakyRelu_46']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 64, 32]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv4',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv2']),
#                            ('output', ['yolov5s/concat1']),
#                            ('input_shapes', [[-1, 160, 160, 64]]),
#                            ('output_shapes', [[-1, 160, 160, 32]]),
#                            ('original_names', ['Conv_53']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 64, 32]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'linear')]))])),
#              ('yolov5s/conv5',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv3']),
#                            ('output', ['yolov5s/conv6']),
#                            ('input_shapes', [[-1, 160, 160, 32]]),
#                            ('output_shapes', [[-1, 160, 160, 32]]),
#                            ('original_names', ['Conv_47', 'LeakyRelu_48']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 32, 32]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv6',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv5']),
#                            ('output', ['yolov5s/ew_add1']),
#                            ('input_shapes', [[-1, 160, 160, 32]]),
#                            ('output_shapes', [[-1, 160, 160, 32]]),
#                            ('original_names', ['Conv_49', 'LeakyRelu_50']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [3, 3, 32, 32]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'SAME_TENSORFLOW'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/ew_add1',
#               OrderedDict([('type', 'ew_add'),
#                            ('input', ['yolov5s/conv3', 'yolov5s/conv6']),
#                            ('output', ['yolov5s/conv7']),
#                            ('input_shapes',
#                             [[-1, 160, 160, 32], [-1, 160, 160, 32]]),
#                            ('output_shapes', [[-1, 160, 160, 32]]),
#                            ('original_names', ['Add_51']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('activation', 'linear')]))])),
#              ('yolov5s/conv7',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/ew_add1']),
#                            ('output', ['yolov5s/concat1']),
#                            ('input_shapes', [[-1, 160, 160, 32]]),
#                            ('output_shapes', [[-1, 160, 160, 32]]),
#                            ('original_names', ['Conv_52']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 32, 32]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'linear')]))])),
#              ('yolov5s/concat1',
#               OrderedDict([('type', 'concat'),
#                            ('input', ['yolov5s/conv7', 'yolov5s/conv4']),
#                            ('output', ['yolov5s/batch_norm1']),
#                            ('input_shapes',
#                             [[-1, 160, 160, 32], [-1, 160, 160, 32]]),
#                            ('output_shapes', [[-1, 160, 160, 64]]),
#                            ('original_names', ['Concat_54']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('concat_axis', 'features')]))])),
#              ('yolov5s/batch_norm1',
#               OrderedDict([('type', 'batch_norm'),
#                            ('input', ['yolov5s/concat1']),
#                            ('output', ['yolov5s/conv8']),
#                            ('input_shapes', [[-1, 160, 160, 64]]),
#                            ('output_shapes', [[-1, 160, 160, 64]]),
#                            ('original_names',
#                             ['BatchNormalization_55', 'LeakyRelu_56']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('activation', 'leaky'),
#                                          ('elementwise_add', False)]))])),
#              ('yolov5s/conv8',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/batch_norm1']),
#                            ('output', ['yolov5s/conv9']),
#                            ('input_shapes', [[-1, 160, 160, 64]]),
#                            ('output_shapes', [[-1, 160, 160, 64]]),
#                            ('original_names', ['Conv_57', 'LeakyRelu_58']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 64, 64]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv9',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv8']),
#                            ('output', ['yolov5s/conv10', 'yolov5s/conv11']),
#                            ('input_shapes', [[-1, 160, 160, 64]]),
#                            ('output_shapes',
#                             [[-1, 80, 80, 128], [-1, 80, 80, 128]]),
#                            ('original_names', ['Conv_59', 'LeakyRelu_60']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [3, 3, 64, 128]),
#                                          ('strides', [1, 2, 2, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'SAME'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv10',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv9']),
#                            ('output', ['yolov5s/conv12', 'yolov5s/ew_add2']),
#                            ('input_shapes', [[-1, 80, 80, 128]]),
#                            ('output_shapes',
#                             [[-1, 80, 80, 64], [-1, 80, 80, 64]]),
#                            ('original_names', ['Conv_61', 'LeakyRelu_62']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 128, 64]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv11',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv9']),
#                            ('output', ['yolov5s/concat2']),
#                            ('input_shapes', [[-1, 80, 80, 128]]),
#                            ('output_shapes', [[-1, 80, 80, 64]]),
#                            ('original_names', ['Conv_79']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 128, 64]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'linear')]))])),
#              ('yolov5s/conv12',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv10']),
#                            ('output', ['yolov5s/conv13']),
#                            ('input_shapes', [[-1, 80, 80, 64]]),
#                            ('output_shapes', [[-1, 80, 80, 64]]),
#                            ('original_names', ['Conv_63', 'LeakyRelu_64']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 64, 64]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv13',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv12']),
#                            ('output', ['yolov5s/ew_add2']),
#                            ('input_shapes', [[-1, 80, 80, 64]]),
#                            ('output_shapes', [[-1, 80, 80, 64]]),
#                            ('original_names', ['Conv_65', 'LeakyRelu_66']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [3, 3, 64, 64]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'SAME_TENSORFLOW'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/ew_add2',
#               OrderedDict([('type', 'ew_add'),
#                            ('input', ['yolov5s/conv10', 'yolov5s/conv13']),
#                            ('output', ['yolov5s/conv14', 'yolov5s/ew_add3']),
#                            ('input_shapes',
#                             [[-1, 80, 80, 64], [-1, 80, 80, 64]]),
#                            ('output_shapes',
#                             [[-1, 80, 80, 64], [-1, 80, 80, 64]]),
#                            ('original_names', ['Add_67']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('activation', 'linear')]))])),
#              ('yolov5s/conv14',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/ew_add2']),
#                            ('output', ['yolov5s/conv15']),
#                            ('input_shapes', [[-1, 80, 80, 64]]),
#                            ('output_shapes', [[-1, 80, 80, 64]]),
#                            ('original_names', ['Conv_68', 'LeakyRelu_69']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 64, 64]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv15',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv14']),
#                            ('output', ['yolov5s/ew_add3']),
#                            ('input_shapes', [[-1, 80, 80, 64]]),
#                            ('output_shapes', [[-1, 80, 80, 64]]),
#                            ('original_names', ['Conv_70', 'LeakyRelu_71']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [3, 3, 64, 64]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'SAME_TENSORFLOW'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/ew_add3',
#               OrderedDict([('type', 'ew_add'),
#                            ('input', ['yolov5s/ew_add2', 'yolov5s/conv15']),
#                            ('output', ['yolov5s/conv16', 'yolov5s/ew_add4']),
#                            ('input_shapes',
#                             [[-1, 80, 80, 64], [-1, 80, 80, 64]]),
#                            ('output_shapes',
#                             [[-1, 80, 80, 64], [-1, 80, 80, 64]]),
#                            ('original_names', ['Add_72']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('activation', 'linear')]))])),
#              ('yolov5s/conv16',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/ew_add3']),
#                            ('output', ['yolov5s/conv17']),
#                            ('input_shapes', [[-1, 80, 80, 64]]),
#                            ('output_shapes', [[-1, 80, 80, 64]]),
#                            ('original_names', ['Conv_73', 'LeakyRelu_74']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 64, 64]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv17',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv16']),
#                            ('output', ['yolov5s/ew_add4']),
#                            ('input_shapes', [[-1, 80, 80, 64]]),
#                            ('output_shapes', [[-1, 80, 80, 64]]),
#                            ('original_names', ['Conv_75', 'LeakyRelu_76']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [3, 3, 64, 64]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'SAME_TENSORFLOW'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/ew_add4',
#               OrderedDict([('type', 'ew_add'),
#                            ('input', ['yolov5s/ew_add3', 'yolov5s/conv17']),
#                            ('output', ['yolov5s/conv18']),
#                            ('input_shapes',
#                             [[-1, 80, 80, 64], [-1, 80, 80, 64]]),
#                            ('output_shapes', [[-1, 80, 80, 64]]),
#                            ('original_names', ['Add_77']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('activation', 'linear')]))])),
#              ('yolov5s/conv18',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/ew_add4']),
#                            ('output', ['yolov5s/concat2']),
#                            ('input_shapes', [[-1, 80, 80, 64]]),
#                            ('output_shapes', [[-1, 80, 80, 64]]),
#                            ('original_names', ['Conv_78']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 64, 64]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'linear')]))])),
#              ('yolov5s/concat2',
#               OrderedDict([('type', 'concat'),
#                            ('input', ['yolov5s/conv18', 'yolov5s/conv11']),
#                            ('output', ['yolov5s/batch_norm2']),
#                            ('input_shapes',
#                             [[-1, 80, 80, 64], [-1, 80, 80, 64]]),
#                            ('output_shapes', [[-1, 80, 80, 128]]),
#                            ('original_names', ['Concat_80']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('concat_axis', 'features')]))])),
#              ('yolov5s/batch_norm2',
#               OrderedDict([('type', 'batch_norm'),
#                            ('input', ['yolov5s/concat2']),
#                            ('output', ['yolov5s/conv19']),
#                            ('input_shapes', [[-1, 80, 80, 128]]),
#                            ('output_shapes', [[-1, 80, 80, 128]]),
#                            ('original_names',
#                             ['BatchNormalization_81', 'LeakyRelu_82']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('activation', 'leaky'),
#                                          ('elementwise_add', False)]))])),
#              ('yolov5s/conv19',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/batch_norm2']),
#                            ('output', ['yolov5s/conv20', 'yolov5s/concat8']),
#                            ('input_shapes', [[-1, 80, 80, 128]]),
#                            ('output_shapes',
#                             [[-1, 80, 80, 128], [-1, 80, 80, 128]]),
#                            ('original_names', ['Conv_83', 'LeakyRelu_84']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 128, 128]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv20',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv19']),
#                            ('output', ['yolov5s/conv21', 'yolov5s/conv22']),
#                            ('input_shapes', [[-1, 80, 80, 128]]),
#                            ('output_shapes',
#                             [[-1, 40, 40, 256], [-1, 40, 40, 256]]),
#                            ('original_names', ['Conv_85', 'LeakyRelu_86']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [3, 3, 128, 256]),
#                                          ('strides', [1, 2, 2, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'SAME'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv21',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv20']),
#                            ('output', ['yolov5s/concat3']),
#                            ('input_shapes', [[-1, 40, 40, 256]]),
#                            ('output_shapes', [[-1, 40, 40, 128]]),
#                            ('original_names', ['Conv_105']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 256, 128]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'linear')]))])),
#              ('yolov5s/conv22',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv20']),
#                            ('output', ['yolov5s/conv23', 'yolov5s/ew_add5']),
#                            ('input_shapes', [[-1, 40, 40, 256]]),
#                            ('output_shapes',
#                             [[-1, 40, 40, 128], [-1, 40, 40, 128]]),
#                            ('original_names', ['Conv_87', 'LeakyRelu_88']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 256, 128]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv23',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv22']),
#                            ('output', ['yolov5s/conv24']),
#                            ('input_shapes', [[-1, 40, 40, 128]]),
#                            ('output_shapes', [[-1, 40, 40, 128]]),
#                            ('original_names', ['Conv_89', 'LeakyRelu_90']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 128, 128]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv24',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv23']),
#                            ('output', ['yolov5s/ew_add5']),
#                            ('input_shapes', [[-1, 40, 40, 128]]),
#                            ('output_shapes', [[-1, 40, 40, 128]]),
#                            ('original_names', ['Conv_91', 'LeakyRelu_92']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [3, 3, 128, 128]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'SAME_TENSORFLOW'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/ew_add5',
#               OrderedDict([('type', 'ew_add'),
#                            ('input', ['yolov5s/conv22', 'yolov5s/conv24']),
#                            ('output', ['yolov5s/conv25', 'yolov5s/ew_add6']),
#                            ('input_shapes',
#                             [[-1, 40, 40, 128], [-1, 40, 40, 128]]),
#                            ('output_shapes',
#                             [[-1, 40, 40, 128], [-1, 40, 40, 128]]),
#                            ('original_names', ['Add_93']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('activation', 'linear')]))])),
#              ('yolov5s/conv25',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/ew_add5']),
#                            ('output', ['yolov5s/conv26']),
#                            ('input_shapes', [[-1, 40, 40, 128]]),
#                            ('output_shapes', [[-1, 40, 40, 128]]),
#                            ('original_names', ['Conv_94', 'LeakyRelu_95']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 128, 128]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv26',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv25']),
#                            ('output', ['yolov5s/ew_add6']),
#                            ('input_shapes', [[-1, 40, 40, 128]]),
#                            ('output_shapes', [[-1, 40, 40, 128]]),
#                            ('original_names', ['Conv_96', 'LeakyRelu_97']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [3, 3, 128, 128]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'SAME_TENSORFLOW'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/ew_add6',
#               OrderedDict([('type', 'ew_add'),
#                            ('input', ['yolov5s/ew_add5', 'yolov5s/conv26']),
#                            ('output', ['yolov5s/conv27', 'yolov5s/ew_add7']),
#                            ('input_shapes',
#                             [[-1, 40, 40, 128], [-1, 40, 40, 128]]),
#                            ('output_shapes',
#                             [[-1, 40, 40, 128], [-1, 40, 40, 128]]),
#                            ('original_names', ['Add_98']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('activation', 'linear')]))])),
#              ('yolov5s/conv27',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/ew_add6']),
#                            ('output', ['yolov5s/conv28']),
#                            ('input_shapes', [[-1, 40, 40, 128]]),
#                            ('output_shapes', [[-1, 40, 40, 128]]),
#                            ('original_names', ['Conv_99', 'LeakyRelu_100']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 128, 128]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv28',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv27']),
#                            ('output', ['yolov5s/ew_add7']),
#                            ('input_shapes', [[-1, 40, 40, 128]]),
#                            ('output_shapes', [[-1, 40, 40, 128]]),
#                            ('original_names', ['Conv_101', 'LeakyRelu_102']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [3, 3, 128, 128]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'SAME_TENSORFLOW'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/ew_add7',
#               OrderedDict([('type', 'ew_add'),
#                            ('input', ['yolov5s/ew_add6', 'yolov5s/conv28']),
#                            ('output', ['yolov5s/conv29']),
#                            ('input_shapes',
#                             [[-1, 40, 40, 128], [-1, 40, 40, 128]]),
#                            ('output_shapes', [[-1, 40, 40, 128]]),
#                            ('original_names', ['Add_103']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('activation', 'linear')]))])),
#              ('yolov5s/conv29',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/ew_add7']),
#                            ('output', ['yolov5s/concat3']),
#                            ('input_shapes', [[-1, 40, 40, 128]]),
#                            ('output_shapes', [[-1, 40, 40, 128]]),
#                            ('original_names', ['Conv_104']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 128, 128]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'linear')]))])),
#              ('yolov5s/concat3',
#               OrderedDict([('type', 'concat'),
#                            ('input', ['yolov5s/conv29', 'yolov5s/conv21']),
#                            ('output', ['yolov5s/batch_norm3']),
#                            ('input_shapes',
#                             [[-1, 40, 40, 128], [-1, 40, 40, 128]]),
#                            ('output_shapes', [[-1, 40, 40, 256]]),
#                            ('original_names', ['Concat_106']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('concat_axis', 'features')]))])),
#              ('yolov5s/batch_norm3',
#               OrderedDict([('type', 'batch_norm'),
#                            ('input', ['yolov5s/concat3']),
#                            ('output', ['yolov5s/conv30']),
#                            ('input_shapes', [[-1, 40, 40, 256]]),
#                            ('output_shapes', [[-1, 40, 40, 256]]),
#                            ('original_names',
#                             ['BatchNormalization_107', 'LeakyRelu_108']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('activation', 'leaky'),
#                                          ('elementwise_add', False)]))])),
#              ('yolov5s/conv30',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/batch_norm3']),
#                            ('output', ['yolov5s/conv31', 'yolov5s/concat6']),
#                            ('input_shapes', [[-1, 40, 40, 256]]),
#                            ('output_shapes',
#                             [[-1, 40, 40, 256], [-1, 40, 40, 256]]),
# ...
#                             OrderedDict([('kernel_shape', [1, 1, 256, 256]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv62',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv61']),
#                            ('output', ['yolov5s/concat12']),
#                            ('input_shapes', [[-1, 40, 40, 256]]),
#                            ('output_shapes', [[-1, 20, 20, 256]]),
#                            ('original_names', ['Conv_186', 'LeakyRelu_187']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [3, 3, 256, 256]),
#                                          ('strides', [1, 2, 2, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'SAME'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/concat12',
#               OrderedDict([('type', 'concat'),
#                            ('input', ['yolov5s/conv62', 'yolov5s/conv40']),
#                            ('output', ['yolov5s/conv64', 'yolov5s/conv65']),
#                            ('input_shapes',
#                             [[-1, 20, 20, 256], [-1, 20, 20, 256]]),
#                            ('output_shapes',
#                             [[-1, 20, 20, 512], [-1, 20, 20, 512]]),
#                            ('original_names', ['Concat_188']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('concat_axis', 'features')]))])),
#              ('yolov5s/conv63',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv61']),
#                            ('output', ['yolov5s/output_layer2']),
#                            ('input_shapes', [[-1, 40, 40, 256]]),
#                            ('output_shapes', [[-1, 40, 40, 24]]),
#                            ('original_names',
#                             ['Conv_218', 'Reshape_232', 'Transpose_233']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 256, 24]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'linear')]))])),
#              ('yolov5s/conv64',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/concat12']),
#                            ('output', ['yolov5s/conv66']),
#                            ('input_shapes', [[-1, 20, 20, 512]]),
#                            ('output_shapes', [[-1, 20, 20, 256]]),
#                            ('original_names', ['Conv_189', 'LeakyRelu_190']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 512, 256]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv65',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/concat12']),
#                            ('output', ['yolov5s/concat13']),
#                            ('input_shapes', [[-1, 20, 20, 512]]),
#                            ('output_shapes', [[-1, 20, 20, 256]]),
#                            ('original_names', ['Conv_196']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 512, 256]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'linear')]))])),
#              ('yolov5s/conv66',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv64']),
#                            ('output', ['yolov5s/conv67']),
#                            ('input_shapes', [[-1, 20, 20, 256]]),
#                            ('output_shapes', [[-1, 20, 20, 256]]),
#                            ('original_names', ['Conv_191', 'LeakyRelu_192']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 256, 256]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv67',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv66']),
#                            ('output', ['yolov5s/conv68']),
#                            ('input_shapes', [[-1, 20, 20, 256]]),
#                            ('output_shapes', [[-1, 20, 20, 256]]),
#                            ('original_names', ['Conv_193', 'LeakyRelu_194']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [3, 3, 256, 256]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'SAME_TENSORFLOW'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv68',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv67']),
#                            ('output', ['yolov5s/concat13']),
#                            ('input_shapes', [[-1, 20, 20, 256]]),
#                            ('output_shapes', [[-1, 20, 20, 256]]),
#                            ('original_names', ['Conv_195']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 256, 256]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'linear')]))])),
#              ('yolov5s/concat13',
#               OrderedDict([('type', 'concat'),
#                            ('input', ['yolov5s/conv68', 'yolov5s/conv65']),
#                            ('output', ['yolov5s/batch_norm8']),
#                            ('input_shapes',
#                             [[-1, 20, 20, 256], [-1, 20, 20, 256]]),
#                            ('output_shapes', [[-1, 20, 20, 512]]),
#                            ('original_names', ['Concat_197']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('concat_axis', 'features')]))])),
#              ('yolov5s/batch_norm8',
#               OrderedDict([('type', 'batch_norm'),
#                            ('input', ['yolov5s/concat13']),
#                            ('output', ['yolov5s/conv69']),
#                            ('input_shapes', [[-1, 20, 20, 512]]),
#                            ('output_shapes', [[-1, 20, 20, 512]]),
#                            ('original_names',
#                             ['BatchNormalization_198', 'LeakyRelu_199']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('activation', 'leaky'),
#                                          ('elementwise_add', False)]))])),
#              ('yolov5s/conv69',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/batch_norm8']),
#                            ('output', ['yolov5s/conv70']),
#                            ('input_shapes', [[-1, 20, 20, 512]]),
#                            ('output_shapes', [[-1, 20, 20, 512]]),
#                            ('original_names', ['Conv_200', 'LeakyRelu_201']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 512, 512]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'leaky')]))])),
#              ('yolov5s/conv70',
#               OrderedDict([('type', 'conv'),
#                            ('input', ['yolov5s/conv69']),
#                            ('output', ['yolov5s/output_layer3']),
#                            ('input_shapes', [[-1, 20, 20, 512]]),
#                            ('output_shapes', [[-1, 20, 20, 24]]),
#                            ('original_names',
#                             ['Conv_234', 'Reshape_248', 'Transpose_249']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('params',
#                             OrderedDict([('kernel_shape', [1, 1, 512, 24]),
#                                          ('strides', [1, 1, 1, 1]),
#                                          ('dilations', [1, 1, 1, 1]),
#                                          ('padding', 'VALID'),
#                                          ('groups', 1),
#                                          ('layer_disparity', 1),
#                                          ('input_disparity', 1),
#                                          ('batch_norm', False),
#                                          ('elementwise_add', False),
#                                          ('activation', 'linear')]))])),
#              ('yolov5s/output_layer1',
#               OrderedDict([('type', 'output_layer'),
#                            ('input', ['yolov5s/conv55']),
#                            ('output', []),
#                            ('input_shapes', [[-1, 80, 80, 24]]),
#                            ('output_shapes', [[-1, 80, 80, 24]]),
#                            ('original_names', ['output']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('transposed', False),
#                            ('engine', 'nn_core'),
#                            ('io_type', 'standard')])),
#              ('yolov5s/output_layer2',
#               OrderedDict([('type', 'output_layer'),
#                            ('input', ['yolov5s/conv63']),
#                            ('output', []),
#                            ('input_shapes', [[-1, 40, 40, 24]]),
#                            ('output_shapes', [[-1, 40, 40, 24]]),
#                            ('original_names', ['414']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('transposed', False),
#                            ('engine', 'nn_core'),
#                            ('io_type', 'standard')])),
#              ('yolov5s/output_layer3',
#               OrderedDict([('type', 'output_layer'),
#                            ('input', ['yolov5s/conv70']),
#                            ('output', []),
#                            ('input_shapes', [[-1, 20, 20, 24]]),
#                            ('output_shapes', [[-1, 20, 20, 24]]),
#                            ('original_names', ['434']),
#                            ('compilation_params', {}),
#                            ('quantization_params', {}),
#                            ('transposed', False),
#                            ('engine', 'nn_core'),
#                            ('io_type', 'standard')]))])
#
# ================================================================================

# %%
# model_name = "yolo11n_visdrone"
# fp_model_har_path = 'yolo11n_visdrone_fp32_singlecls_bestmodel.har'
# runner.save_har(fp_model_har_path)

# # quant_model_har_path = f"{model_name}_visdrone2class_quantized_lvl2_opt.har" 
# quant_model_har_path = "yolo11n_visdrone_quant_singlecls_optlvl2_ds3k_816_1e5_singlecls_bestmodel_nocolorconv.har"
# # quant_model_har_path = "yolo11n_visdrone_quant_singlecls_exp_1_.har"
# runner.save_har(quant_model_har_path)


model_name = "yolov5s_visdrone"
quant_model_har_path = f"{model_name}_fp_model.har"
runner.save_har(quant_model_har_path)

# %%
# load the model
# quant_model_har_path = 'yolo11n_visdrone_quant_singlecls_optlvl2_ds3k_816_1e5_singlecls_bestmodel_nocolorconv.har'
# quant_model_har_path = quant_model_har_path
# quant_model_har_path = "yolov5s_visdrone_singlecls_quant_model.har"
runner = ClientRunner(har=quant_model_har_path, hw_arch=chosen_hw_arch)


# fp_opt_model_har_path = 'yolo11n_visdrone_fp_opt_model_visdrone.har'
# runner = ClientRunner(har=fp_opt_model_har_path, hw_arch=chosen_hw_arch)

# %% [markdown]
# ## Model Inference and Evaluation

# %%
# get a list of images (filename) and the corresponding image_id from annotations file

annotations_file = '/local/shared_with_docker/visdrone/annotations_VisDroneHumans_val.json'
images_path = "/local/shared_with_docker/visdrone/VisDrone2019-DET-val/images"

with open(annotations_file, 'r') as f:
    val_gt = json.load(f)
    f.close()
    
images = val_gt['images']
image_list = [(x['file_name'],x['id']) for x in images]

# %%
def run_inference(runner, sdk_type, input_data ):
    if sdk_type == 'quantized':
        with runner.infer_context(InferenceContext.SDK_QUANTIZED) as ctx:
            output = runner.infer(ctx, input_data)
    elif sdk_type == 'native':
        with runner.infer_context(InferenceContext.SDK_NATIVE) as ctx:
            output = runner.infer(ctx, input_data)
    elif sdk_type == 'optimized':
        with runner.infer_context(InferenceContext.SDK_FP_OPTIMIZED) as ctx:
            output = runner.infer(ctx, input_data)
    else:
        print(f"Invalid sky type: {sdk_type}")
    return output  

def remove_zero_padding(output, imgid):
    # remove zero-padding and transpose detections into single array
    combined = np.empty((7, 0)) # 1 classid, xywh, score
    for i in range(output.shape[1]):
        valid_mask = np.any(output[0,i,:,:] != 0, axis=(0))  # Check if any non-zero values exist in each column
        last_valid_indices = np.argmax(~valid_mask, axis=0) # First occurrence of zero padding
        if last_valid_indices==0:
            last_valid_indices=-1
        dets = output[0, i, :, :last_valid_indices]
        class_col = np.full_like(dets[0,None], i) # add the classID into the array
        imgid_col = np.full_like(dets[0,None], imgid)
        dets = np.vstack((dets, class_col, imgid_col))
        combined = np.concatenate((combined, dets), axis=1)

    dets = combined.T
    return dets


def swap_columns(detections):
    detections[:, [0, 1,2,3]] = detections[:, [1, 0, 3, 2]]
    return detections


def ltxy2xywh(xywh):
    xywh[:,0] = xywh[:,0] # x
    xywh[:,1] = xywh[:,1] # y
    xywh[:,2] = xywh[:,2] - xywh[:,0] # x2 - x1
    xywh[:,3] = xywh[:,3] - xywh[:,1] # y2 - y1

    return xywh

def rescale_bbox(detections, w, h):
    w_arr = np.full_like(detections[:,0], w)
    h_arr = np.full_like(detections[:,0], h)
    
    detections[:,0] = detections[:,0] * w_arr
    detections[:,1] = detections[:,1] * h_arr
    detections[:,2] = detections[:,2] * w_arr
    detections[:,3] = detections[:,3] * h_arr
    
    return detections

def add_metadata_to_dict(data, data_dict):
    idx, imgid, lb_scale, lb_pad_top, lb_pad_left = data
    metadata = {
                "image_id" : imgid,
                "lbox_scale": lb_scale,
                "lbox_pad_top": lb_pad_top, 
                "lbox_pad_left": lb_pad_left
    }


    data_dict[idx]["rescale_data"] = metadata
    


def get_image_metadata(images_dict, img_id):
    for img in images_dict:
        if img['id'] == img_id:
            orig_w, orig_h = img['width'], img['height']
            name = img["file_name"]
            lb_scale = img["rescale_data"]["lbox_scale"]
            lb_pad_top = img["rescale_data"]["lbox_pad_top"]
            lb_pad_left = img["rescale_data"]["lbox_pad_left"]

    return orig_w, orig_h, name, lb_scale, lb_pad_top, lb_pad_left

# %% [markdown]
# Function below is mostly copy paste from Shashi on Hailo Community, see [here](https://community.hailo.ai/t/user-guide-2-running-your-first-object-detection-model-on-a-hailo-device-using-degirum-pysdk/9728)

# %%
# function below mostly copy paste from shashi on hailo community guide:
def reverse_rescale_bboxes(annotations, scale, pad_top, pad_left, original_shape):
    """
    Reverse rescales bounding boxes from the letterbox image to the original image, returning new annotations.

    Parameters:
        annotations (list of dicts): List of dictionaries, each containing a 'bbox' (x1, y1, x2, y2) and other fields.
        scale (float): The scale factor used for resizing the image.
        pad_top (int): The padding added to the top of the image.
        pad_left (int): The padding added to the left of the image.
        original_shape (tuple): The shape (height, width) of the original image before resizing.

    Returns:
        new_annotations (list of dicts): New annotations with rescaled bounding boxes adjusted back to the original image.
    """
    orig_h, orig_w = original_shape  # original image height and width
    
    new_annotations = []
    
    for annotation in annotations:
        bbox = annotation  # Bounding box as (x1, y1, x2, y2)
        
        # Reverse padding
        x1, y1, x2, y2 = bbox
        x1 -= pad_left
        y1 -= pad_top
        x2 -= pad_left
        y2 -= pad_top
        
        # Reverse scaling
        x1 = int(x1 / scale)
        y1 = int(y1 / scale)
        x2 = int(x2 / scale)
        y2 = int(y2 / scale)
        
        # Clip the bounding box to make sure it fits within the original image dimensions
        x1 = max(0, min(x1, orig_w))
        y1 = max(0, min(y1, orig_h))
        x2 = max(0, min(x2, orig_w))
        y2 = max(0, min(y2, orig_h))
        
        new_annotations.append([x1,y1, x2, y2])
        
    
    return new_annotations

# %%
# create a copy of the images dict so additional datapoints can be added
image_rescale_metadata = images.copy()

# %%
dataset_sz = len(image_list)
val_dataset = np.zeros((dataset_sz, 640, 640, 3))
val_imageids = np.zeros((dataset_sz,1))
for idx, imagename_id in enumerate(image_list):
    imgname, imgid = imagename_id
    image_file = os.path.join(images_path, imgname)
    if idx==dataset_sz:
        break
    img_preproc, lb_scale, lb_pad_top, lb_pad_left = resize_with_letterbox(image_file, (1,640,640,3))
    val_dataset[idx, :, :, :] = img_preproc
    val_imageids[idx] = imgid
    
    # the scaled image needs to be restored to orig size later, so these fields are saved here
    metadata = (idx, imgid, lb_scale, lb_pad_top, lb_pad_left)
    add_metadata_to_dict(metadata, image_rescale_metadata)

# %%
print(f"Created validation dataset, of shape: {val_dataset.shape}")
print(f"Created validation metadata, of length: {len(image_rescale_metadata)}")
# Out:
# Created validation dataset, of shape: (532, 640, 640, 3)
# Created validation metadata, of length: 532

# %%
# check a single image to ensure letterboxing worked as expected
img = val_dataset[13,:,:,:].astype('uint8')
pilimg = Image.fromarray(img)
display(pilimg)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
def detections_batch_generation(dataset, dataset_id, images_dict, sdk_type='quantized'):
    batch_dets = run_inference(runner=runner, sdk_type=sdk_type, input_data=dataset)
    all_dets = []
    for idx, output in enumerate(batch_dets):
        imgid = dataset_id[idx]
        
        # postprocessing steps
        # remove zero padding
        output = output.reshape(1,1,5,80) # expects a batch
        detections = remove_zero_padding(output, imgid)

        if detections.shape[0] == 0:
            print(f"No detections found for image: {int(imgid[0])}\n")
            continue
        # convert to xyxy and denormalise
        yxyx = np.full_like(detections, detections)
        xyxy = swap_columns(yxyx) # annoyingly, it is in yx, ont xy, what misery
        dets_scaled = rescale_bbox(xyxy, 640, 640)

        # get metadata to remove letterbox and rescale back to original size
        w,h, name, lb_scale, lb_pad_top, lb_pad_left = get_image_metadata(image_rescale_metadata, imgid)

        # reverse letterboxing and convert to xywh
        xyxy_orig = reverse_rescale_bboxes(dets_scaled[:, :4],lb_scale, lb_pad_top, lb_pad_left, (h,w))
        dets_scaled[:, :4] = ltxy2xywh(np.array(xyxy_orig))
        all_dets.append(dets_scaled)
        
    return(all_dets)


def batch_detections_to_json(batch):
    class_remap = {0: 1, 1: 2}
    res = []
    annId = 1
    for detections in batch:
        for el in detections:
            x,y,w,h,conf,classid,imgid = el
            imgid = int(imgid)
            res.append({"image_id": imgid, "category_id": class_remap[classid], "bbox": [x,y,w,h], "score": conf, "id": annId, "segmentation": []}) 
            annId +=1
    return res


def save_json_file(filename, data):
    with open(outputfile, 'w') as outf:
        json.dump(data, outf)
        outf.close()

    print(f"Total of {len(data)} annotations saved to {outputfile}")
    
def get_annotations_dict():
    result = {
        "bbox": [x_min, y_min, x_max, y_max],  # Bounding box in pixel coordinates
        "score": score,  # Confidence score of the detection
        "category_id": class_id,  # Class ID of the detected object
        "label": label_dictionary.get(str(class_id), f"class_{class_id}"),  # Class label or fallback
    }
    return result

# %%
quant_model_har_path
# Out:
# 'exp_1_yolov5sv6_singlecls_quant_model.har'

# %%
batch_detections = detections_batch_generation(val_dataset, val_imageids, images)
processed_outputs = batch_detections_to_json(batch_detections)
variation = quant_model_har_path.split(".")[0]
# variation = fp_model_har_path.split(".")[0]
outputfile = f"/local/shared_with_docker/visdrone/detections_{variation}.json" 
save_json_file(outputfile, processed_outputs)
# Out:
# 2025-04-18 21:07:35.356852: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 21:07:35.372028: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 21:07:35.372135: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 21:07:35.372915: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 21:07:35.372997: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 21:07:35.373047: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 21:07:35.414241: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 21:07:35.414346: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 21:07:35.414403: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-18 21:07:35.414444: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-04-18 21:07:35.414459: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13902 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2025-04-18 21:07:35.640704: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:1279] could not retrieve CUDA device count: CUDA_ERROR_NOT_INITIALIZED: initialization error
# [info] Using 1 GPU for inference
# Inference: 0entries [00:00, ?entries/s]2025-04-18 21:07:37.375011: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-18 21:07:59.128769: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8906
# 2025-04-18 21:07:59.348594: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Inference: 536entries [00:30, 17.80entries/s]
# Total of 37384 annotations saved to /local/shared_with_docker/visdrone/detections_exp_1_yolov5sv6_singlecls_quant_model.json

# %% [markdown]
# #### Plot annotations on a single image

# %%
import cv2
import os
import json
import warnings

def xywh2xyxy(xywh):
    x,y,w,h = xywh
    x1 = x
    y1 = y
    x2 = x + w
    y2 = y + h

    return x1, y1, x2, y2

def xywhn2xyxy(xywh):
    x,y,w,h = xywh
    x1 = x - w / 2
    y1 = y - h / 2
    x2 = x + w / 2
    y2 = y + h / 2

    return x1, y1, x2, y2

def x1y1whn2xcywh(xywh):
    x,y,w,h = xywh
    x1 = x - w / 2
    y1 = y - h / 2


    return x1, y1, w, h

def get_annotations(annotations_path, img_id):
    with open(annotations_path, 'r') as file:
        gt_data = json.load(file)
        file.close()
    annotations = gt_data['annotations']
    images = gt_data['images']
    gt = []
    for ann in annotations:
        if ann['image_id'] == img_id:
            gt.append([ann['category_id'], *ann['bbox']])
    for img in images:
        if img['id'] == img_id:
            file_name = img['file_name']
    return gt, file_name

def get_detections(results_path, img_id=None):
    with open(results_path, 'r') as file:
        results = json.load(file)
        file.close()
    preds = []
    for res in results:
        if img_id is not None:
            if res['image_id'] != img_id:
                continue
        img_id = res['image_id']
        preds.append([res['category_id'], *res['bbox'], res['score'], img_id])
        assert img_id is not None, f"Image ID has not been found in {results}"
    return preds

def plot_annotations(image, predictions, color_map, label_map, gt=False):
    for idx, labels in enumerate(predictions):
        # Unpack the labels
        if gt:
            clsid, x1, y1, w, h = labels
            conf = 1
        else:
            clsid, x1, y1, w, h, conf, _ = labels
            
        x1, y1, x2, y2 = xywh2xyxy([x1, y1, w, h])
        x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
        
        if clsid not in [1,2]:
            warnings.warn(f"Class id {clsid} has been found in dataset")
            continue

        
        # Filter by confidence threshold
        if conf > 0.2:
            # Select color based on class
            color = color_map[clsid]  # Default to white if unknown class

            # Draw bounding box
            cv2.rectangle(img, (x1, y1), (x2, y2), color, thickness)

            # Display class name and confidence
            text = f"{label_map[clsid]}: {conf:.2f}"
            cv2.putText(img, text, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.4, color, 1, cv2.LINE_AA)
    return img

# %%
annotations_path = "/local/shared_with_docker/visdrone/annotations_VisDroneHumans_val.json"
results_path = outputfile
images_dir = "/local/shared_with_docker/visdrone/VisDrone2019-DET-val/images"


img_id = 34 # known imageid as per the dataset
gt, file_name = get_annotations(annotations_path, img_id=img_id)
detections = get_detections(results_path, img_id=img_id)

# Load the image
imagefilename = file_name 
imgpth = os.path.join(images_dir, imagefilename)
print(f"\n\nreading image at {imgpth}...\n\n")
img = cv2.imread(imgpth)
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

img_name = os.path.basename(imgpth).split('.')[0]

colorgt = {
    1: (66, 75, 245),
    2: (36, 45, 215)
}

thickness = 1

class_colors = {
    1: (0, 251, 255),  # Cyan
    2: (255, 201, 205)  # pinkish
}

class_names = {
    1: 'pedestrian',
    2: 'person'
}

img = plot_annotations(img, detections, class_colors, class_names)
# img = plot_annotations(img, gt, colorgt, class_names, gt=True)


pilimg = Image.fromarray(img)
display(pilimg)
# Out:
# reading image at /local/shared_with_docker/visdrone/VisDrone2019-DET-val/images/0000069_00001_d_0000001.jpg...
# <PIL.Image.Image image mode=RGB size=1360x765>

# %%
# need to add an annotation ID and segmentation to json output from ultralytics to compare with original model
def map_imageid_to_json(detection_file, yolo5=False):
    with open(detection_file, 'r') as f:
        annotations = json.load(f)
        f.close()


    # Create a mapping from images using file_name as key and image_id as value
    mapping = {item["file_name"].split('.')[0]: item["id"] for item in images}

    # Update predictions dict by mapping image_id
    for item in annotations:
        item["image_id"] = mapping.get(item["image_id"], item["image_id"])
        
        if yolo5:
            if item["category_id"]==0:
                item["category_id"]=1
        
    return annotations

        
preds_file = '/local/shared_with_docker/visdrone/yolov5n_exp13_best_preds.json'
remapped_file = map_imageid_to_json(preds_file, yolo5=True)
with open("/local/shared_with_docker/visdrone/yolov5n_exp13_best_preds_ul.json", 'w') as f:
    json.dump(remapped_file, f)
    f.close()

# %%
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
import pylab

import json
import os

pylab.rcParams['figure.figsize'] = (10.0, 8.0)

annType = ['segm','bbox','keypoints']
annType = annType[1]      #specify type here
prefix = 'person_keypoints' if annType=='keypoints' else 'instances'
print('Running demo for *%s* results.'%(annType))

#initialize COCO ground truth api
rootdir = '/local/shared_with_docker/visdrone/'
annFile = os.path.join(rootdir, 'annotations_VisDroneHumans_val.json')
cocoGt=COCO(annFile)

#initialize COCO detections api
# resFile= os.path.join(rootdir, 'detections_exp_5_yolo5n_dev_quant_model.json')
resFile = outputfile
cocoDt=cocoGt.loadRes(resFile)

imgIds=sorted(cocoGt.getImgIds())
imgIds = imgIds[0:]
catIDs = [1,2] # 81 for all IDs
useCats = 0
maxDets = [1, 10, 100]


# running evaluation
cocoEval = COCOeval(cocoGt,cocoDt,annType)
cocoEval.params.imgIds  = imgIds
cocoEval.params.catIds = catIDs
cocoEval.params.maxDets = maxDets
cocoEval.params.useCats = useCats
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()
# Out:
# Running demo for *bbox* results.
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.40s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=5.96s).
# Accumulating evaluation results...
# DONE (t=0.14s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.185
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.471
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.166
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.331
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.437
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.136
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.252
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.427
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.514

# %%
stats = cocoEval.stats

# %%
stats

# %%
import os
import json
import csv
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval

# Configs
annType = 'bbox'  # change to 'segm' or 'keypoints' if needed
rootdir = '/local/shared_with_docker/visdrone/'
annFile = os.path.join(rootdir, 'annotations_VisDroneHumans_val.json')
detections_dir = os.path.join(rootdir, 'model_eval')  # where all your detection JSONs are
output_csv = os.path.join(rootdir, 'evaluation_results.csv')

# Get list of detection files (adjust pattern if needed)
detection_files = [f for f in os.listdir(detections_dir) if f.endswith('.json') and 'detections' in f]

# Load ground truth
cocoGt = COCO(annFile)

# Prepare CSV output
headers = [
    'File', 'AP', 'AP50', 'AP75', 'AP_small', 'AP_medium', 'AP_large',
    'AR_1', 'AR_10', 'AR_100', 'AR_small', 'AR_medium', 'AR_large'
]
rows = []

# Loop through detection files and evaluate
for det_file in detection_files:
    print(f"Evaluating: {det_file}")
    resFile = os.path.join(detections_dir, det_file)
    cocoDt = cocoGt.loadRes(resFile)

    imgIds = sorted(cocoGt.getImgIds())
    catIDs = [1, 2]  # adjust as needed
    maxDets = [1, 10, 100]

    cocoEval = COCOeval(cocoGt, cocoDt, annType)
    cocoEval.params.imgIds = imgIds
    cocoEval.params.catIds = catIDs
    cocoEval.params.maxDets = maxDets
    cocoEval.params.useCats = 0
    cocoEval.evaluate()
    cocoEval.accumulate()
    cocoEval.summarize()

    # Redirect summarize output to variables
    stats = cocoEval.stats  # 12 metrics

    # Save to CSV row
    rows.append([det_file] + list(stats))
    print(list(stats))

# Write CSV
with open(output_csv, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(headers)
    writer.writerows(rows)

print(f"Done! Results saved to: {output_csv}")

# %%
def generate_output_grids_np(height, width, strides=[8,16,32]):
    """
    Generate a numpy array containing grid coordinates and strides for a given height and width.

    Args:
        height (int): The height of the image.
        width (int): The width of the image.

    Returns:
        np.ndarray: A numpy array containing grid coordinates and strides.
    """

    all_coordinates = []

    for stride in strides:
        # Calculate the grid height and width
        grid_height = height // stride
        grid_width = width // stride

        # Generate grid coordinates
        g1, g0 = np.meshgrid(np.arange(grid_height), np.arange(grid_width), indexing='ij')

        # Create an array of strides
        s = np.full((grid_height, grid_width), stride)

        # Stack the coordinates along with the stride
        coordinates = np.stack((g0.flatten(), g1.flatten(), s.flatten()), axis=-1)

        # Append to the list
        all_coordinates.append(coordinates)

    # Concatenate all arrays in the list along the first dimension
    output_grids = np.concatenate(all_coordinates, axis=0)

    return output_grids

def calculate_boxes_and_probs(model_output:np.ndarray, output_grids:np.ndarray) -> np.ndarray:
    """
    Calculate the bounding boxes and their probabilities.

    Parameters:
    model_output (numpy.ndarray): The output of the model.
    output_grids (numpy.ndarray): The output grids.

    Returns:
    numpy.ndarray: The array containing the bounding box coordinates, class labels, and maximum probabilities.
    """
    # Calculate the bounding box coordinates
    box_centroids = (model_output[..., :2] + output_grids[..., :2]) * output_grids[..., 2:]
    box_sizes = np.exp(model_output[..., 2:4]) * output_grids[..., 2:]

    x0, y0 = [t.squeeze(axis=2) for t in np.split(box_centroids - box_sizes / 2, 2, axis=2)]
    w, h = [t.squeeze(axis=2) for t in np.split(box_sizes, 2, axis=2)]

    # Calculate the probabilities for each class
    box_objectness = model_output[..., 4]
    box_cls_scores = model_output[..., 5:]
    box_probs = np.expand_dims(box_objectness, -1) * box_cls_scores

    # Get the maximum probability and corresponding class for each proposal
    max_probs = np.max(box_probs, axis=-1)
    labels = np.argmax(box_probs, axis=-1)

    return np.array([x0, y0, w, h, labels, max_probs]).transpose((1, 2, 0))

def process_outputs(outputs:np.ndarray, input_dims:tuple, bbox_conf_thresh:float):

    """
    Process the model outputs to generate bounding box proposals filtered by confidence threshold.
    
    Parameters:
    - outputs (numpy.ndarray): The raw output from the model, which will be processed to calculate boxes and probabilities.
    - input_dims (tuple of int): Dimensions (height, width) of the input image to the model.
    - bbox_conf_thresh (float): Threshold for the bounding box confidence/probability. Bounding boxes with a confidence
                                score below this threshold will be discarded.
    
    Returns:
    - numpy.array: An array of proposals where each proposal is an array containing bounding box coordinates
                   and its associated probability, sorted in descending order by probability.
    """

    # Process the model output
    outputs = calculate_boxes_and_probs(outputs, generate_output_grids_np(*input_dims))
    # Filter the proposals based on the confidence threshold
    max_probs = outputs[:, :, -1]
    mask = max_probs > bbox_conf_thresh
    proposals = outputs[mask]
    # Sort the proposals by probability in descending order
    proposals = proposals[proposals[..., -1].argsort()][::-1]
    return proposals


def calc_iou(proposals:np.ndarray) -> np.ndarray:
    """
    Calculates the Intersection over Union (IoU) for all pairs of bounding boxes (x,y,w,h) in 'proposals'.

    The IoU is a measure of overlap between two bounding boxes. It is calculated as the area of
    intersection divided by the area of union of the two boxes.

    Parameters:
    proposals (2D np.array): A NumPy array of bounding boxes, where each box is an array [x, y, width, height].

    Returns:
    iou (2D np.array): The IoU matrix where each element i,j represents the IoU of boxes i and j.
    """

    # Calculate coordinates for the intersection rectangles
    x1 = np.maximum(proposals[:, 0], proposals[:, 0][:, None])
    y1 = np.maximum(proposals[:, 1], proposals[:, 1][:, None])
    x2 = np.minimum(proposals[:, 0] + proposals[:, 2], (proposals[:, 0] + proposals[:, 2])[:, None])
    y2 = np.minimum(proposals[:, 1] + proposals[:, 3], (proposals[:, 1] + proposals[:, 3])[:, None])
    
    # Calculate intersection areas
    intersections = np.maximum(x2 - x1, 0) * np.maximum(y2 - y1, 0)

    # Calculate union areas
    areas = proposals[:, 2] * proposals[:, 3]
    unions = areas[:, None] + areas - intersections

    # Calculate IoUs
    iou = intersections / unions

    # Return the iou matrix
    return iou


def nms_sorted_boxes(iou:np.ndarray, iou_thresh:float=0.45) -> np.ndarray:
    """
    Applies non-maximum suppression (NMS) to sorted bounding boxes.

    It suppresses boxes that have high overlap (as defined by the IoU threshold) with a box that 
    has a higher score.

    Parameters:
    iou (np.ndarray): An IoU matrix where each element i,j represents the IoU of boxes i and j.
    iou_thresh (float): The IoU threshold for suppression. Boxes with IoU > iou_thresh are suppressed.

    Returns:
    keep (np.ndarray): The indices of the boxes to keep after applying NMS.
    """

    # Create a boolean mask to keep track of boxes
    mask = np.ones(iou.shape[0], dtype=bool)

    # Apply non-max suppression
    for i in range(iou.shape[0]):
        if mask[i]:
            # Suppress boxes with higher index and IoU > threshold
            mask[(iou[i] > iou_thresh) & (np.arange(iou.shape[0]) > i)] = False

    # Return the indices of the boxes to keep
    return np.arange(iou.shape[0])[mask]

# %%
outputs = batch_dets[0][3]

# Process the model output to get object proposals
proposals = process_outputs(outputs, (640,640), 0.2)

# Apply non-max suppression to filter overlapping proposals
proposal_indices = nms_sorted_boxes(calc_iou(proposals[:, :-2]), iou_thresh)
proposals = proposals[proposal_indices]

# %%
#    val_dataset, val_imageids, images
# batch_dets = run_inference(runner=runner, sdk_type='native', input_data=val_dataset)
output_array = outputs[0].reshape(-1)
outputs.shape

# %% [markdown]
# ## Compile

# %%
runner = ClientRunner(har=quant_model_har_path, hw_arch=chosen_hw_arch)
hef_model_name = quant_model_har_path.replace(".har", ".hef")
print(f"compiling har model to {quant_model_har_path}\nto {hef_model_name}\nhardware arch: {chosen_hw_arch}")
hef = runner.compile()
# Out:
# compiling har model to exp_1_yolov5sv6_singlecls_quant_model.har
# to exp_1_yolov5sv6_singlecls_quant_model.hef
# hardware arch: hailo8l
# [info] To achieve optimal performance, set the compiler_optimization_level to "max" by adding performance_param(compiler_optimization_level=max) to the model script. Note that this may increase compilation time.
# [info] Loading network parameters
# [info] Starting Hailo allocation and compilation flow
# [info] Adding an output layer after conv47
# [info] Adding an output layer after conv54
# [info] Adding an output layer after conv60
# [info] Finding the best partition to contexts...
# [info] Iteration #1 - Contexts: 3
# [info] Iteration #1 - Contexts: 3,
# [info] Iteration #2 - Contexts: 3
# [info] Iteration #2 - Contexts: 3,
# [info] Iteration #3 - Contexts: 3
# [info] Iteration #3 - Contexts: 3,
# [info] Iteration #4 - Contexts: 3
# [info] Iteration #4 - Contexts: 3,
# [info] Iteration #5 - Contexts: 3
# [info] Iteration #5 - Contexts: 3,
# [info] Iteration #6 - Contexts: 3
# [info] Iteration #6 - Contexts: 3,
# [info] Iteration #7 - Contexts: 3
# [info] Iteration #7 - Contexts: 3,
# [info] Iteration #8 - Contexts: 3
# [info] Iteration #8 - Contexts: 3,
# [info] Iteration #9 - Contexts: 3
# [info] Iteration #9 - Contexts: 3,
# [info] Iteration #10 - Contexts: 3
# [info] Iteration #10 - Contexts: 3,
# [info] Iteration #11 - Contexts: 3
# [info] Iteration #11 - Contexts: 3,
# [info] Iteration #12 - Contexts: 3
# [info] Iteration #12 - Contexts: 3,
# [info] Iteration #13 - Contexts: 3
# [info] Iteration #13 - Contexts: 3,
# [info] Iteration #14 - Contexts: 3
# [info] Iteration #14 - Contexts: 3,
# [info] Iteration #15 - Contexts: 3
# [info] Iteration #15 - Contexts: 3,
# [info] Iteration #16 - Contexts: 3
# [info] Iteration #16 - Contexts: 3,
# [info] Iteration #17 - Contexts: 3
# [info] Iteration #17 - Contexts: 3,
# [info] Iteration #18 - Contexts: 3
# [info] Iteration #18 - Contexts: 3,
# [info] Iteration #19 - Contexts: 3
# [info] Iteration #19 - Contexts: 3,
# [info] Iteration #20 - Contexts: 3
# [info] Iteration #20 - Contexts: 3,
# [info] Iteration #21 - Contexts: 3
# [info] Iteration #21 - Contexts: 3,
# [info] Iteration #22 - Contexts: 3
# [info] Iteration #22 - Contexts: 3,
# [info] Iteration #23 - Contexts: 3
# [info] Iteration #23 - Contexts: 3,
# [info] Iteration #24 - Contexts: 3
# [info] Iteration #24 - Contexts: 3,
# [info] Iteration #25 - Contexts: 3
# [info] Iteration #25 - Contexts: 3,
# [info] Iteration #26 - Contexts: 3
# [info] Iteration #26 - Contexts: 3,
# [info] Iteration #27 - Contexts: 3
# [info] Iteration #27 - Contexts: 3,
# [info] Iteration #28 - Contexts: 3
# [info] Iteration #28 - Contexts: 3,
# [info] Iteration #29 - Contexts: 3
# [info] Iteration #29 - Contexts: 3,
# [info] Iteration #30 - Contexts: 3
# [info] Iteration #30 - Contexts: 3,
# [info] Iteration #31 - Contexts: 3
# [info] Iteration #31 - Contexts: 3,
# [info] Iteration #32 - Contexts: 3
# [info] Iteration #32 - Contexts: 3,
# [info] Iteration #33 - Contexts: 3
# [info] Iteration #33 - Contexts: 3,
# [info] Iteration #34 - Contexts: 3
# [info] Iteration #34 - Contexts: 3,
# [info] Iteration #35 - Contexts: 3
# [info] Iteration #35 - Contexts: 3,
# [info] Iteration #36 - Contexts: 3
# [info] Iteration #36 - Contexts: 3,
# [info] Iteration #37 - Contexts: 3
# [info] Iteration #37 - Contexts: 3,
# [info] Iteration #38 - Contexts: 3
# [info] Iteration #38 - Contexts: 3,
# [info] Iteration #39 - Contexts: 3
# [info] Iteration #39 - Contexts: 3,
# [info] Iteration #40 - Contexts: 3
# [info] Iteration #40 - Contexts: 3,
# [info] Iteration #41 - Contexts: 3
# [info] Iteration #41 - Contexts: 3,
# [info] Iteration #42 - Contexts: 3
# [info] Iteration #42 - Contexts: 3,
# [info] Iteration #43 - Contexts: 3
# [info] Iteration #43 - Contexts: 3,
# [info] Iteration #44 - Contexts: 3
# [info] Iteration #44 - Contexts: 3,
# [info] Iteration #45 - Contexts: 3
# [info] Iteration #45 - Contexts: 3,
# [info] Iteration #46 - Contexts: 3
# [info] Iteration #46 - Contexts: 3,
# [info] Iteration #47 - Contexts: 3
# [info] Iteration #47 - Contexts: 3,
# [info] Iteration #48 - Contexts: 3
# [info] Iteration #48 - Contexts: 3,
# [info] Iteration #49 - Contexts: 3
# [info] Iteration #49 - Contexts: 3,
# [info] Iteration #50 - Contexts: 3
# [info] Iteration #50 - Contexts: 3,
# [info] Iteration #51 - Contexts: 3
# [info] Iteration #51 - Contexts: 3,
# [info] Iteration #52 - Contexts: 3
# [info] Iteration #52 - Contexts: 3,
# [info] Iteration #53 - Contexts: 3
# [info] Iteration #53 - Contexts: 3,
# [info] Iteration #54 - Contexts: 3
# [info] Iteration #54 - Contexts: 3,
# [info] Iteration #55 - Contexts: 3
# [info] Iteration #55 - Contexts: 3,
# [info] Iteration #56 - Contexts: 3
# [info] Iteration #56 - Contexts: 3,
# [info] Iteration #57 - Contexts: 3
# [info] Iteration #57 - Contexts: 3,
# [info] Iteration #58 - Contexts: 3
# [info] Iteration #58 - Contexts: 3,
# [info] Iteration #59 - Contexts: 3
# [info] Iteration #59 - Contexts: 3,
# [info] Iteration #60 - Contexts: 3
# [info] Iteration #60 - Contexts: 3,
# [info] Iteration #61 - Contexts: 3
# [info] Iteration #61 - Contexts: 3,
# [info] Iteration #62 - Contexts: 4
# [info] Iteration #62 - Contexts: 4,
# [info] Iteration #63 - Contexts: 4
# [info] Iteration #63 - Contexts: 4,
# [info] Iteration #64 - Contexts: 4
# [info] Iteration #64 - Contexts: 4,
# [info] Iteration #65 - Contexts: 4
# [info] Iteration #65 - Contexts: 4,
# [info] Iteration #66 - Contexts: 4
# [info] Iteration #66 - Contexts: 4,
# [info] Iteration #67 - Contexts: 4
# [info] Iteration #67 - Contexts: 4,
# [info] Iteration #68 - Contexts: 4
# [info] Iteration #68 - Contexts: 4,
# [info] Iteration #69 - Contexts: 4
# [info] Iteration #69 - Contexts: 4,
# [info] Iteration #70 - Contexts: 4
# [info] Iteration #70 - Contexts: 4,
# [info] Iteration #71 - Contexts: 4
# [info] Iteration #71 - Contexts: 4,
# [info] Iteration #72 - Contexts: 4
# [info] Iteration #72 - Contexts: 4,
# [info] Iteration #73 - Contexts: 4
# [info] Iteration #73 - Contexts: 4,
# [info] Iteration #74 - Contexts: 4
# [info] Iteration #74 - Contexts: 4,
# [info] Iteration #75 - Contexts: 4
# [info] Iteration #75 - Contexts: 4,
# [info] Iteration #76 - Contexts: 4
# [info] Iteration #76 - Contexts: 4,
# [info] Iteration #77 - Contexts: 4
# [info] Iteration #77 - Contexts: 4,
# [info] Iteration #78 - Contexts: 4
# [info] Iteration #78 - Contexts: 4,
# [info] Iteration #79 - Contexts: 4
# [info] Iteration #79 - Contexts: 4,
# [info] Iteration #80 - Contexts: 4
# [info] Iteration #80 - Contexts: 4,
# [info] Iteration #81 - Contexts: 4
# [info] Iteration #81 - Contexts: 4,
# [info] Iteration #82 - Contexts: 4
# [info] Iteration #82 - Contexts: 4,
# [info] Iteration #83 - Contexts: 4
# [info] Iteration #83 - Contexts: 4,
# [info] Iteration #84 - Contexts: 4
# [info] Iteration #84 - Contexts: 4,
# [info] Iteration #85 - Contexts: 4
# [info] Iteration #85 - Contexts: 4,
# [info] Iteration #86 - Contexts: 4
# [info] Iteration #86 - Contexts: 4,
# [info] Iteration #87 - Contexts: 4
# [info] Iteration #87 - Contexts: 4,
# [info] Iteration #88 - Contexts: 4
# [info] Iteration #88 - Contexts: 4,
# [info] Iteration #89 - Contexts: 4
# [info] Iteration #89 - Contexts: 4,
# [info] Iteration #90 - Contexts: 4
# [info] Iteration #90 - Contexts: 4,
# [info] Iteration #91 - Contexts: 4
# [info] Iteration #91 - Contexts: 4,
# [info] Iteration #92 - Contexts: 4
# [info] Iteration #92 - Contexts: 4,
# [info] Iteration #93 - Contexts: 4
# [info] Iteration #93 - Contexts: 4,
# [info] Iteration #94 - Contexts: 4
# [info] Iteration #94 - Contexts: 4,
# [info] Iteration #95 - Contexts: 4
# [info] Iteration #95 - Contexts: 4,
# [info] Iteration #96 - Contexts: 4
# [info] Iteration #96 - Contexts: 4,
# [info] Iteration #97 - Contexts: 4
# [info] Iteration #97 - Contexts: 4,
# [info] Iteration #98 - Contexts: 4
# [info] Iteration #98 - Contexts: 4,
# [info] Iteration #99 - Contexts: 4
# [info] Iteration #99 - Contexts: 4,
# [info] Iteration #100 - Contexts: 4
# [info] Iteration #100 - Contexts: 4,
# [info] Iteration #101 - Contexts: 4
# [info] Iteration #101 - Contexts: 4,
# [info] Iteration #102 - Contexts: 4
# [info] Iteration #102 - Contexts: 4,
# [info] Iteration #103 - Contexts: 4
# [info] Iteration #103 - Contexts: 4,
# [info] Iteration #104 - Contexts: 4
# [info] Iteration #104 - Contexts: 4,
# [info] Iteration #105 - Contexts: 4
# [info] Iteration #105 - Contexts: 4,
# [info] Iteration #106 - Contexts: 4
# [info] Iteration #106 - Contexts: 4,
# [info] Iteration #107 - Contexts: 4
# [info] Iteration #107 - Contexts: 4,
# [info] Iteration #108 - Contexts: 4
# [info] Iteration #108 - Contexts: 4,
# [info] Iteration #109 - Contexts: 4
# [info] Iteration #109 - Contexts: 4,
# [info] Iteration #110 - Contexts: 4
# [info] Iteration #110 - Contexts: 4,
# [info] Iteration #111 - Contexts: 4
# [info] Iteration #111 - Contexts: 4,
# [info] Iteration #112 - Contexts: 4
# [info] Iteration #112 - Contexts: 4,
# [info] Iteration #113 - Contexts: 4
# [info] Iteration #113 - Contexts: 4,
# [info] Iteration #114 - Contexts: 4
# [info] Iteration #114 - Contexts: 4,
# [info] Iteration #115 - Contexts: 4
# [info] Iteration #115 - Contexts: 4,
# [info] Iteration #116 - Contexts: 4
# [info] Iteration #116 - Contexts: 4,
# [info] Iteration #117 - Contexts: 4
# [info] Iteration #117 - Contexts: 4,
# [info] Iteration #118 - Contexts: 4
# [info] Iteration #118 - Contexts: 4,
# [info] Iteration #119 - Contexts: 4
# [info] Iteration #119 - Contexts: 4,
# [info] Iteration #120 - Contexts: 4
# [info] Iteration #120 - Contexts: 4,
# [info] Iteration #121 - Contexts: 4
# [info] Iteration #121 - Contexts: 4,
# [info] Iteration #122 - Contexts: 4
# [info] Iteration #122 - Contexts: 4,
# [info] Iteration #123 - Contexts: 5
# [info] Iteration #123 - Contexts: 5,
# [info] Iteration #124 - Contexts: 5
# [info] Iteration #124 - Contexts: 5,
# [info] Iteration #125 - Contexts: 5
# [info] Iteration #125 - Contexts: 5,
# [info] Iteration #126 - Contexts: 5
# [info] Iteration #126 - Contexts: 5,
# [info] Iteration #127 - Contexts: 5
# [info] Iteration #127 - Contexts: 5,
# [info] Iteration #128 - Contexts: 5
# [info] Iteration #128 - Contexts: 5,
# [info] Iteration #129 - Contexts: 5
# [info] Iteration #129 - Contexts: 5,
# [info] Iteration #130 - Contexts: 5
# [info] Iteration #130 - Contexts: 5,
# [info] Iteration #131 - Contexts: 5
# [info] Iteration #131 - Contexts: 5,
# [info] Iteration #132 - Contexts: 5
# [info] Iteration #132 - Contexts: 5,
# [info] Iteration #133 - Contexts: 5
# [info] Iteration #133 - Contexts: 5,
# [info] Iteration #134 - Contexts: 5
# [info] Iteration #134 - Contexts: 5,
# [info] Iteration #135 - Contexts: 5
# [info] Iteration #135 - Contexts: 5,
# [info] Iteration #136 - Contexts: 5
# [info] Iteration #136 - Contexts: 5,
# [info] Iteration #137 - Contexts: 5
# [info] Iteration #137 - Contexts: 5,
# [info] Iteration #138 - Contexts: 5
# [info] Iteration #138 - Contexts: 5,
# [info] Iteration #139 - Contexts: 5
# [info] Iteration #139 - Contexts: 5,
# [info] Iteration #140 - Contexts: 5
# [info] Iteration #140 - Contexts: 5,
# [info] Iteration #141 - Contexts: 5
# [info] Iteration #141 - Contexts: 5,
# [info] Iteration #142 - Contexts: 5
# [info] Iteration #142 - Contexts: 5,
# [info] Iteration #143 - Contexts: 5
# [info] Iteration #143 - Contexts: 5,
# [info] Iteration #144 - Contexts: 5
# [info] Iteration #144 - Contexts: 5,
# [info] Iteration #145 - Contexts: 5
# [info] Iteration #145 - Contexts: 5,
# [info] Iteration #146 - Contexts: 5
# [info] Iteration #146 - Contexts: 5,
# [info] Iteration #147 - Contexts: 5
# [info] Iteration #147 - Contexts: 5,
# [info] Iteration #148 - Contexts: 5
# [info] Iteration #148 - Contexts: 5,
# [info] Iteration #149 - Contexts: 5
# [info] Iteration #149 - Contexts: 5,
# [info] Iteration #150 - Contexts: 5
# [info] Iteration #150 - Contexts: 5,
# [info] Iteration #151 - Contexts: 5
# [info] Iteration #151 - Contexts: 5,
# [info] Iteration #152 - Contexts: 5
# [info] Iteration #152 - Contexts: 5,
# [info] Iteration #153 - Contexts: 5
# [info] Iteration #153 - Contexts: 5,
# [info] Iteration #154 - Contexts: 5
# [info] Iteration #154 - Contexts: 5,
# [info] Iteration #155 - Contexts: 5
# [info] Iteration #155 - Contexts: 5,
# [info] Iteration #156 - Contexts: 5
# [info] Iteration #156 - Contexts: 5,
# [info] Iteration #157 - Contexts: 5
# [info] Iteration #157 - Contexts: 5,
# [info] Iteration #158 - Contexts: 5
# [info] Iteration #158 - Contexts: 5,
# [info] Iteration #159 - Contexts: 5
# [info] Iteration #159 - Contexts: 5,
# [info] Iteration #160 - Contexts: 5
# [info] Iteration #160 - Contexts: 5,
# [info] Iteration #161 - Contexts: 5
# [info] Iteration #161 - Contexts: 5,
# [info] Iteration #162 - Contexts: 5
# [info] Iteration #162 - Contexts: 5,
# [info] Iteration #163 - Contexts: 5
# [info] Iteration #163 - Contexts: 5,
# [info] Iteration #164 - Contexts: 5
# [info] Iteration #164 - Contexts: 5,
# [info] Iteration #165 - Contexts: 5
# [info] Iteration #165 - Contexts: 5,
# [info] Iteration #166 - Contexts: 5
# [info] Iteration #166 - Contexts: 5,
# [info] Iteration #167 - Contexts: 5
# [info] Iteration #167 - Contexts: 5,
# [info] Iteration #168 - Contexts: 5
# [info] Iteration #168 - Contexts: 5,
# [info] Iteration #169 - Contexts: 5
# [info] Iteration #169 - Contexts: 5,
# [info] Iteration #170 - Contexts: 5
# [info] Iteration #170 - Contexts: 5,
# [info] Iteration #171 - Contexts: 5
# [info] Iteration #171 - Contexts: 5,
# [info] Iteration #172 - Contexts: 5
# [info] Iteration #172 - Contexts: 5,
# [info] Iteration #173 - Contexts: 5
# [info] Iteration #173 - Contexts: 5,
# [info] Iteration #174 - Contexts: 5
# [info] Iteration #174 - Contexts: 5,
# [info] Iteration #175 - Contexts: 5
# [info] Iteration #175 - Contexts: 5,
# [info] Iteration #176 - Contexts: 5
# [info] Iteration #176 - Contexts: 5,
# [info] Iteration #177 - Contexts: 5
# [info] Iteration #177 - Contexts: 5,
# [info] Iteration #178 - Contexts: 5
# [info] Iteration #178 - Contexts: 5,
# [info] Iteration #179 - Contexts: 5
# [info] Iteration #179 - Contexts: 5,
# [info] Iteration #180 - Contexts: 5
# [info] Iteration #180 - Contexts: 5,
# [info] Iteration #181 - Contexts: 6
# [info] Iteration #181 - Contexts: 6,
# [info] Iteration #182 - Contexts: 6
# [info] Iteration #182 - Contexts: 6,
# [info] Iteration #183 - Contexts: 6
# [info] Iteration #183 - Contexts: 6,
# [info] Iteration #184 - Contexts: 6
# [info] Iteration #184 - Contexts: 6,
# [info] Iteration #185 - Contexts: 6
# [info] Iteration #185 - Contexts: 6,
# [info] Iteration #186 - Contexts: 6
# [info] Iteration #186 - Contexts: 6,
# [info] Iteration #187 - Contexts: 6
# [info] Iteration #187 - Contexts: 6,
# [info] Iteration #188 - Contexts: 6
# [info] Iteration #188 - Contexts: 6,
# [info] Iteration #189 - Contexts: 6
# [info] Iteration #189 - Contexts: 6,
# [info] Iteration #190 - Contexts: 6
# [info] Iteration #190 - Contexts: 6,
# [info] Iteration #191 - Contexts: 6
# [info] Iteration #191 - Contexts: 6,
# [info] Iteration #192 - Contexts: 6
# [info] Iteration #192 - Contexts: 6,
# [info] Iteration #193 - Contexts: 6
# [info] Iteration #193 - Contexts: 6,
# [info] Iteration #194 - Contexts: 6
# [info] Iteration #194 - Contexts: 6,
# [info] Iteration #195 - Contexts: 6
# [info] Iteration #195 - Contexts: 6,
# [info] Iteration #196 - Contexts: 6
# [info] Iteration #196 - Contexts: 6,
# [info] Iteration #197 - Contexts: 6
# [info] Iteration #197 - Contexts: 6,
# [info] Iteration #198 - Contexts: 6
# [info] Iteration #198 - Contexts: 6,
# [info] Iteration #199 - Contexts: 6
# [info] Iteration #199 - Contexts: 6,
# [info] Iteration #200 - Contexts: 6
# [info] Iteration #200 - Contexts: 6,
# [info] Iteration #201 - Contexts: 6
# [info] Iteration #201 - Contexts: 6,
# [info] Iteration #202 - Contexts: 6
# [info] Iteration #202 - Contexts: 6,
# [info] Iteration #203 - Contexts: 6
# [info] Iteration #203 - Contexts: 6,
# [info] Iteration #204 - Contexts: 6
# [info] Iteration #204 - Contexts: 6,
# [info] Iteration #205 - Contexts: 6
# [info] Iteration #205 - Contexts: 6,
# [info] Iteration #206 - Contexts: 6
# [info] Iteration #206 - Contexts: 6,
# [info] Iteration #207 - Contexts: 6
# [info] Iteration #207 - Contexts: 6,
# [info] Iteration #208 - Contexts: 6
# [info] Iteration #208 - Contexts: 6,
# [info] Iteration #209 - Contexts: 6
# [info] Iteration #209 - Contexts: 6,
# [info] Iteration #210 - Contexts: 6
# [info] Iteration #210 - Contexts: 6,
# [info] Iteration #211 - Contexts: 6
# [info] Iteration #211 - Contexts: 6,
# [info] Iteration #212 - Contexts: 6
# [info] Iteration #212 - Contexts: 6,
# [info] Iteration #213 - Contexts: 6
# [info] Iteration #213 - Contexts: 6,
# [info] Iteration #214 - Contexts: 6
# [info] Iteration #214 - Contexts: 6,
# [info] Iteration #215 - Contexts: 6
# [info] Iteration #215 - Contexts: 6,
# [info] Iteration #216 - Contexts: 6
# [info] Iteration #216 - Contexts: 6,
# [info] Iteration #217 - Contexts: 6
# [info] Iteration #217 - Contexts: 6,
# [info] Iteration #218 - Contexts: 6
# [info] Iteration #218 - Contexts: 6,
# [info] Iteration #219 - Contexts: 6
# [info] Iteration #219 - Contexts: 6,
# [info] Iteration #220 - Contexts: 6
# [info] Iteration #220 - Contexts: 6,
# [info] Iteration #221 - Contexts: 6
# [info] Iteration #221 - Contexts: 6,
# [info] Iteration #222 - Contexts: 6
# [info] Iteration #222 - Contexts: 6,
# [info] Iteration #223 - Contexts: 6
# [info] Iteration #223 - Contexts: 6,
# [info] Iteration #224 - Contexts: 6
# [info] Iteration #224 - Contexts: 6,
# [info] Iteration #225 - Contexts: 6
# [info] Iteration #225 - Contexts: 6,
# [info] Iteration #226 - Contexts: 6
# [info] Iteration #226 - Contexts: 6,
# [info] Iteration #227 - Contexts: 7
# [info] Iteration #227 - Contexts: 7,
# [info] Iteration #228 - Contexts: 7
# [info] Iteration #228 - Contexts: 7,
# [info] Iteration #229 - Contexts: 7
# [info] Iteration #229 - Contexts: 7,
# [info] Iteration #230 - Contexts: 7
# [info] Iteration #230 - Contexts: 7,
# [info] Iteration #231 - Contexts: 7
# [info] Iteration #231 - Contexts: 7,
# [info] Iteration #232 - Contexts: 7
# [info] Iteration #232 - Contexts: 7,
# [info] Iteration #233 - Contexts: 7
# [info] Iteration #233 - Contexts: 7,
# [info] Iteration #234 - Contexts: 7
# [info] Iteration #234 - Contexts: 7,
# [info] Iteration #235 - Contexts: 7
# [info] Iteration #235 - Contexts: 7,
# [info] Iteration #236 - Contexts: 7
# [info] Iteration #236 - Contexts: 7,
# [info] Iteration #237 - Contexts: 7
# [info] Iteration #237 - Contexts: 7,
# [info] Iteration #238 - Contexts: 7
# [info] Iteration #238 - Contexts: 7,
# [info] Iteration #239 - Contexts: 7
# [info] Iteration #239 - Contexts: 7,
# [info] Iteration #240 - Contexts: 7
# [info] Iteration #240 - Contexts: 7,
# [info] Iteration #241 - Contexts: 7
# [info] Iteration #241 - Contexts: 7,
# [info] Iteration #242 - Contexts: 7
# [info] Iteration #242 - Contexts: 7,
# [info] Iteration #243 - Contexts: 7
# [info] Iteration #243 - Contexts: 7,
# [info] Iteration #244 - Contexts: 7
# [info] Iteration #244 - Contexts: 7,
# [info] Iteration #245 - Contexts: 7
# [info] Iteration #245 - Contexts: 7,
# [info] Iteration #246 - Contexts: 7
# [info] Iteration #246 - Contexts: 7,
# [info] Iteration #247 - Contexts: 7
# [info] Iteration #247 - Contexts: 7,
# [info] Iteration #248 - Contexts: 7
# [info] Iteration #248 - Contexts: 7,
# [info] Iteration #249 - Contexts: 7
# [info] Iteration #249 - Contexts: 7,
# [info] Iteration #250 - Contexts: 7
# [info] Iteration #250 - Contexts: 7,
# [info] Iteration #251 - Contexts: 7
# [info] Iteration #251 - Contexts: 7,
# [info] Iteration #252 - Contexts: 7
# [info] Iteration #252 - Contexts: 7,
# [info] Iteration #253 - Contexts: 7
# [info] Iteration #253 - Contexts: 7,
# [info] Iteration #254 - Contexts: 7
# [info] Iteration #254 - Contexts: 7,
# [info] Iteration #255 - Contexts: 7
# [info] Iteration #255 - Contexts: 7,
# [info] Iteration #256 - Contexts: 7
# [info] Iteration #256 - Contexts: 7,
# [info] Iteration #257 - Contexts: 7
# [info] Iteration #257 - Contexts: 7,
# [info] Iteration #258 - Contexts: 7
# [info] Iteration #258 - Contexts: 7,
# [info] Iteration #259 - Contexts: 7
# [info] Iteration #259 - Contexts: 7,
# [info] Iteration #260 - Contexts: 7
# [info] Iteration #260 - Contexts: 7,
# [info] Iteration #261 - Contexts: 7
# [info] Iteration #261 - Contexts: 7,
# [info] Iteration #262 - Contexts: 7
# [info] Iteration #262 - Contexts: 7,
# [info] Iteration #263 - Contexts: 7
# [info] Iteration #263 - Contexts: 7,
# [info] Iteration #264 - Contexts: 7
# [info] Iteration #264 - Contexts: 7,
# [<==>....................................]
# [info] Using Multi-context flow
# [info] Resources optimization guidelines: Strategy -> GREEDY Objective -> MAX_FPS
# [info] Resources optimization params: max_control_utilization=60%, max_compute_utilization=60%, max_compute_16bit_utilization=60%, max_memory_utilization (weights)=60%, max_input_aligner_utilization=60%, max_apu_utilization=60%
# [info] input_layer1: Pass
# [info] conv3: Pass
# [info] ew_add1: Pass
# [info] conv4: Pass
# [info] concat1: Pass
# [info] conv1_sd0_defuse_width_feature_reshape: Pass
# [info] conv1_sd1_defuse_width_feature_reshape: Pass
# [info] conv11: Pass
# [info] normalization1: Pass
# [info] conv9: Pass
# [info] conv7: Pass
# [info] conv1_sd0_defuse_reshape_hxf_to_w_transposed: Pass
# [info] conv1_sdc: Pass
# [info] conv1_sd0_defuse_1x1: Pass
# [info] conv5: Pass
# [info] conv1_sd1_defuse_1x1: Pass
# [info] conv10: Pass
# [info] conv1_sd1_defuse_reshape_hxf_to_w_transposed: Pass
# [info] conv1_sd2_defuse_width_feature_reshape: Pass
# [info] conv1_sd4_defuse_width_feature_reshape: Pass
# [info] conv1_sd3_defuse_reshape_hxf_to_w_transposed: Pass
# [info] context_0_to_context_1_0: Pass
# [info] conv6: Pass
# [info] conv1_sd3_defuse_width_feature_reshape: Pass
# [info] context_0_to_context_1_2: Pass
# [info] sh_from_normalization1_to_conv1_sd0_defuse_width_feature_reshape_conv1_sd1_defuse_width_feature_reshape_conv1_sd2_defuse_wid_84: Pass
# [info] context_0_to_context_1_4: Pass
# [info] conv1_sd4_defuse_reshape_hxf_to_w_transposed: Pass
# [info] conv1_sd5_defuse_1x1: Pass
# [info] conv1_sd2_defuse_1x1: Pass
# [info] conv1_sd3_defuse_1x1: Pass
# [info] conv1_sd2_defuse_reshape_hxf_to_w_transposed: Pass
# [info] conv1_sd4_defuse_1x1: Pass
# [info] conv1_sd5_defuse_reshape_hxf_to_w_transposed: Pass
# [info] conv1_sd5_defuse_width_feature_reshape: Pass
# [info] concat_from_conv1_sd0_defuse_1x1_conv1_sd1_defuse_1x1_conv1_sd2_defuse_1x1_conv1_sd3_defuse_1x1_to_conv1_sdc: Pass
# [info] conv2_sdc: Pass
# [info] conv8_sd1: Pass
# [info] conv2_sd2: Pass
# [info] conv8_sdc: Pass
# [info] conv8_sd0: Pass
# [info] conv2_sd1: Pass
# [info] conv2_sd0: Pass
# [info] conv19: Pass
# [info] conv13: Pass
# [info] ew_add3: Pass
# [info] concat2: Pass
# [info] conv21: Pass
# [info] ew_add2: Pass
# [info] conv15: Pass
# [info] ew_add4: Pass
# [info] conv23: Pass
# [info] ew_add6: Pass
# [info] conv12: Pass
# [info] conv17: Pass
# [info] ew_add5: Pass
# [info] conv18: Pass
# [info] conv14: Pass
# [info] conv24: Pass
# [info] conv22: Pass
# [info] concat3: Pass
# [info] conv29: Pass
# [info] conv28: Pass
# [info] concat4: Pass
# [info] conv25: Pass
# [info] maxpool1: Pass
# [info] maxpool2: Pass
# [info] ew_add7: Pass
# [info] context_1_to_context_2_8: Pass
# [info] context_1_to_context_2_10: Pass
# [info] context_1_to_context_2_6: Pass
# [info] conv27: Pass
# [info] maxpool3: Pass
# [info] conv20: Pass
# [info] conv32: Pass
# [info] concat5: Pass
# [info] context_0_to_context_1_in_1: Pass
# [info] conv16_d1: Pass
# [info] conv16_d0: Pass
# [info] context_0_to_context_1_in_5: Pass
# [info] context_0_to_context_1_in_3: Pass
# [info] conv31: Pass
# [info] conv16_dc: Pass
# [info] conv26_dc: Pass
# [info] conv30: Pass
# [info] conv26_d1: Pass
# [info] conv26_d0: Pass
# [info] conv33: Pass
# [info] output_from_conv54_to_yolov5_nms_postprocess: Pass
# [info] output_from_conv60_to_yolov5_nms_postprocess: Pass
# [info] output_from_conv47_to_yolov5_nms_postprocess: Pass
# [info] conv37: Pass
# [info] concat6: Pass
# [info] resize1: Pass
# [info] resize2: Pass
# [info] concat9: Pass
# [info] concat8: Pass
# [info] conv35: Pass
# [info] conv42: Pass
# [info] conv43: Pass
# [info] conv40: Pass
# [info] concat7: Pass
# [info] concat10: Pass
# [info] conv45: Pass
# [info] conv44: Pass
# [info] conv34: Pass
# [info] conv38: Pass
# [info] conv46: Pass
# [info] conv39: Pass
# [info] conv48: Pass
# [info] context_1_to_context_2_in_11: Pass
# [info] conv54: Pass
# [info] conv49: Pass
# [info] concat12: Pass
# [info] conv41: Pass
# [info] conv36: Pass
# [info] context_1_to_context_2_in_7: Pass
# [info] concat13: Pass
# [info] context_1_to_context_2_in_9: Pass
# [info] conv59: Pass
# [info] conv52: Pass
# [info] conv57: Pass
# [info] conv58_d0: Pass
# [info] conv58_d1: Pass
# [info] conv51: Pass
# [info] conv60: Pass
# [info] conv55: Pass
# [info] conv56: Pass
# [info] conv47: Pass
# [info] conv50: Pass
# [info] conv58_dc: Pass
# [info] concat11: Pass
# [info] conv53: Pass
# [info] Solving the allocation (Mapping), time per context: 59m 59s
#
#
# [info] Context:0/0 Iteration 0: Mapping prepost...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2
#  worker3
#
#   00:00
# [info] Context:0/2 Iteration 0: Trying parallel splits...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0
#  worker1
#  worker2
#  worker3
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2
#  worker3
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  *          *          *          *          *          *          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  *          *          *          *          *          *          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          *          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  V          V          *          *          V          V          *          *          V
#
#   00:01
# [info] Context:0/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  V          V          *          *          V          V          *          *          V
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  V          V          *          *          V          V          *          *          V
#
#   00:02
#
#
# [info] Context:1/2 Iteration 0: Trying parallel splits...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0
#  worker1
#  worker2
#  worker3
#
#   00:02
# [info] Context:1/2 Iteration 0: Trying parallel splits...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0
#  worker1
#  worker2
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:02
# [info] Context:1/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:02
# [info] Context:1/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:02
# [info] Context:1/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:02
# [info] Context:1/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  *          *          *          *          *          *          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:02
# [info] Context:1/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  *          *          *          *          *          *          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:02
# [info] Context:1/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2  V          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:02
# [info] Context:1/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          *          V          *          *          V
#  worker1
#  worker2  V          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:02
# [info] Context:1/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          *          V          *          *          V
#  worker1
#  worker2  V          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:03
# [info] Context:1/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          *          V          *          *          V
#  worker1
#  worker2  V          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:03
# [info] Context:1/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          *          V          *          *          V
#  worker1
#  worker2  V          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:03
# [info] Context:1/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          *          V          *          *          V
#  worker1
#  worker2  V          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:03
# [info] Context:1/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          *          V          *          *          V
#  worker1
# ...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2
#  worker3
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2
#  worker3
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2
#  worker3
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2
#  worker3  V          *          *          *          *          *          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2
#  worker3  V          *          *          *          *          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2
#  worker3  V          V          *          *          *          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  V          V          *          *          *          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  V          V          *          *          *          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  V          V          *          *          *          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  V          V          *          *          *          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  V          V          *          *          *          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  V          V          *          *          V          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  V          V          *          *          V          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  V          V          *          *          V          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  V          V          *          *          V          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  V          V          *          *          V          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  V          V          *          *          V          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  V          V          *          *          V          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  V          *          *          *          V          V          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  V          V          *          *          V          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          V          V          *          *          V
#  worker1  V          *          *          *          V          V          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  V          V          *          *          V          V          *          *          V
#
#   00:05
# [info] Context:2/2 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          V          V          *          *          V
#  worker1  V          *          *          *          V          V          *          *          V
#  worker2  V          *          *          *          V          V          *          *          V
#  worker3  V          V          *          *          V          V          *          *          V
#
#   00:07
#
# [info] context_0 (context_0):
# Iterations: 4
# Reverts on cluster mapping: 0
# Reverts on inter-cluster connectivity: 0
# Reverts on pre-mapping validation: 0
# Reverts on split failed: 0
# [info] context_1 (context_1):
# Iterations: 4
# Reverts on cluster mapping: 0
# Reverts on inter-cluster connectivity: 0
# Reverts on pre-mapping validation: 0
# Reverts on split failed: 0
# [info] context_2 (context_2):
# Iterations: 4
# Reverts on cluster mapping: 0
# Reverts on inter-cluster connectivity: 0
# Reverts on pre-mapping validation: 0
# Reverts on split failed: 0
# [info] context_0 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 18.8%               | 15.6%               | 12.5%              |
# [info] | cluster_1 | 93.8%               | 46.9%               | 31.3%              |
# [info] | cluster_4 | 100%                | 76.6%               | 60.2%              |
# [info] | cluster_5 | 31.3%               | 15.6%               | 10.9%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 60.9%               | 38.7%               | 28.7%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_1 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 81.3%               | 42.2%               | 60.9%              |
# [info] | cluster_1 | 43.8%               | 54.7%               | 36.7%              |
# [info] | cluster_4 | 93.8%               | 82.8%               | 93%                |
# [info] | cluster_5 | 25%                 | 20.3%               | 16.4%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 60.9%               | 50%                 | 51.8%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_2 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 56.3%               | 28.1%               | 31.3%              |
# [info] | cluster_1 | 62.5%               | 59.4%               | 48.4%              |
# [info] | cluster_4 | 93.8%               | 64.1%               | 78.1%              |
# [info] | cluster_5 | 31.3%               | 25%                 | 21.9%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 60.9%               | 44.1%               | 44.9%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] Successful Mapping (allocation time: 7m 41s)
# [info] Compiling context_0...
# [info] Compiling context_1...

# %%
with open(hef_model_name, "wb") as f:
    f.write(hef)
    
# !cp {quant_model_har_path} /local/shared_with_docker/visdrone/models/best/har/{quant_model_har_path}
# !cp {hef_model_name} /local/shared_with_docker/visdrone/models/best/hef/{hef_model_name}

# %% [markdown]
# ## Redundant functions and code
# This was used for single image inference, e.g. for iterating over each image

# %%
# these functions are used for single image evaluation
# intented for use when iterating over the dataset
def get_input_data(image_dataset, image_id):
    assert image_id >0, f"Image id should be >0 as per coco formatting"

    imgname, imgid = image_dataset[image_id-1]
    imgfile = os.path.join(images_path, imgname)
    print(f"opening image at {imgfile}")
    img = Image.open(imgfile).convert('RGB')
    img_preproc = preproc(img)
    img_input = img_preproc.reshape(1,640,640,3)
    
    return img_input, imgid, img

def get_single_image(image_rootpath, image_file):
    imgfile = os.path.join(image_rootpath, imgname)
    print(f"opening image at {imgfile}")
    img = Image.open(imgfile).convert('RGB')
    img_preproc = preproc(img)
    img_input = img_preproc.reshape(1,640,640,3)
    
    return img_input, img

def detections_to_json(detections):
    class_remap = {0: 1, 1: 2}
    res = []
    annId = 1
    for el in detections:
        x,y,w,h,conf,classid,imgid = el
        imgid = int(imgid)
        res.append({"image_id": imgid, "category_id": class_remap[classid], "bbox": [x,y,w,h], "score": conf, "id": annId, "segmentation": []}) 
        annId +=1
    return res

def get_single_image(image_rootpath, image_file):
    imgfile = os.path.join(image_rootpath, image_file)
    print(f"opening image at {imgfile}")
    img = Image.open(imgfile).convert('RGB')
    img_preproc = preproc(img)
    img_input = img_preproc.reshape(1,640,640,3)
    
    return img_input, img

def generate_detections_file(image_list, image_dir):
    all_dets = []
    for idx, imgdata in enumerate(image_list):
        imgname, imgid = imgdata
        img_input, img = get_single_image(image_dir, imgname)
        
        output = run_inference(runner=runner, sdk_type='x', input_data=img_input)
        detections = remove_zero_padding(output, imgid)

        xywh = np.full_like(detections, detections)
        xywh = swap_columns(xywh) # annoyingly, it is in yx, ont xy, what misery
        xywh = ltxy2xywh(xywh) # convert x2/y2 to w/h


        w,h, name = get_image_metadata(images, imgid)

        dets_scaled = rescale_bbox(xywh, w, h)
        all_dets.append(dets_scaled)
    return(all_dets)
# full_data_dets = generate_detections_file(image_list, images_path)

    

# img_input, imgid, img = get_input_data(image_list, 1)
# output = run_inference(runner=runner, sdk_type='opt', input_data=img_input)
# detections = remove_zero_padding(output, imgid)

# xywh = np.full_like(detections, detections)
# xywh = swap_columns(xywh) # annoyingly, it is in yx, ont xy, what misery
# xywh = ltxy2xywh(xywh) # convert x2/y2 to w/h


# w,h, name = get_image_metadata(images, imgid)

# dets_scaled = rescale_bbox(xywh, w, h)

# processed_outputs = detections_to_json(dets_scaled)
# outputfile = f"/local/shared_with_docker/visdrone/detections_VisDrone_quant_dets.json" 
# with open(outputfile, 'w') as outf:
#     json.dump(processed_outputs, outf)
#     outf.close()
    
# print(f"Total of {len(processed_outputs)} annotations saved to {outputfile}")
